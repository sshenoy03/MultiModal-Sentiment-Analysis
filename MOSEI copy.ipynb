# %%
from constants import SDK_PATH, DATA_PATH, WORD_EMB_PATH, CACHE_PATH
import sys
import os
import requests
import numpy as np
from mmsdk import mmdatasdk as md
from subprocess import check_call, CalledProcessError

# Append the SDK path
if SDK_PATH is None:
    print("SDK path is not specified! Please specify first in constants/paths.py")
    exit(0)
else:
    sys.path.append(SDK_PATH)

# Create folder for storing data if it doesn't exist
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH, exist_ok=True)

# Helper function to download a file from a URL
def download_file(url, dest):
    try:
        print(f"Downloading from {url}...")
        response = requests.get(url, stream=True)
        response.raise_for_status()
        with open(dest, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"Downloaded: {dest}")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading {url}: {e}")

# Function to get the filename from the URL (last segment)
def get_filename_from_url(url):
    return url.split('/')[-1]  # Extract the last part of the URL

# Download function that iterates over dataset features
def download_dataset_features(feature_dict, feature_type):
    for feature_name, url in feature_dict.items():
        print(f"\nProcessing {feature_type} feature: {feature_name}")
        
        # Use the filename derived from the URL instead of the dictionary key
        filename = get_filename_from_url(url)
        dest_path = os.path.join(DATA_PATH, filename)

        if not os.path.exists(dest_path):
            download_file(url, dest_path)
        else:
            print(f"{feature_type} feature '{feature_name}' already downloaded at {dest_path}")

# Dataset initialization
DATASET = md.cmu_mosei
SETUP = True
# Process high-level, raw, and label features
# try:
#     print("\nStarting download of high-level features...")
#     download_dataset_features(DATASET.highlevel, "High-level")
# except Exception as e:
#     print(f"Error downloading high-level features: {e}")

# try:
#     print("\nStarting download of raw features...")
#     download_dataset_features(DATASET.raw, "Raw")
# except Exception as e:
#     print(f"Error downloading raw features: {e}")

# try:
#     print("\nStarting download of labels...")
#     download_dataset_features(DATASET.labels, "Label")
# except Exception as e:
#     print(f"Error downloading labels: {e}")

# %%
# list the directory contents... let's see what features there are
data_files = os.listdir(DATA_PATH)
print('\n'.join(data_files))
# Out:
# CMU_MOSEI_COVAREP.csd
# CMU_MOSEI_Labels.csd
# CMU_MOSEI_TimestampedWords.csd
# CMU_MOSEI_TimestampedWordVectors.csd
# CMU_MOSEI_VisualFacet42.csd

# %% [markdown]
# We have multiple files which can be broadly classified into three categories, highlevel, raw and labels.
#
# <strong>Highlevel</strong> contains the extracted features for each modality (e.g OpenFace facial landmarks, openSMILE acoustic features) while <strong>raw</strong> contains the raw transctripts, phonemes.
#
# We have multiple files with the .csd extension. This stands for <strong>computational sequences</strong>, which is the underlying data structure for all features in the SDK.
#
# <strong> Highlevel features: </strong>
# - CMU_MOSEI_VisualFacet42.csd (Video modality)
# - CMU_MOSEI_VisualOpenFace2.csd (Video Modality)
# - CMU_MOSEI_COVAREP.csd (Audio Modality)
# - CMU_MOSEI_TimestampedWordVectors.csd (Text Modality)

# %% [markdown]
# ## Loading the data

# %%
visual_field = 'CMU_MOSEI_VisualFacet42'
acoustic_field = 'CMU_MOSEI_COVAREP'
word_field = 'CMU_MOSEI_TimestampedWords'
text_field = 'CMU_MOSEI_TimestampedWordVectors'

features = [
    # text_field, 
    visual_field, 
    acoustic_field
]

raw_features = [word_field]

# recipe = {feat: os.path.join(DATA_PATH, feat) + '.csd' for feat in features}
# dataset = md.mmdataset(recipe)

recipe = {feat: os.path.join(DATA_PATH, feat) + '.csd' for feat in features}
recipe[word_field] = os.path.join(DATA_PATH, word_field) + '.csd'
print(recipe)
dataset = md.mmdataset(recipe)
# Out:
# {'CMU_MOSEI_VisualFacet42': './data/CMU_MOSEI_VisualFacet42.csd', 'CMU_MOSEI_COVAREP': './data/CMU_MOSEI_COVAREP.csd', 'CMU_MOSEI_TimestampedWords': './data/CMU_MOSEI_TimestampedWords.csd'}
# [2024-11-04 14:24:35.659] | Success | Computational sequence read from file ./data/CMU_MOSEI_VisualFacet42.csd ...
# [2024-11-04 14:24:36.424] | Status  | Checking the integrity of the <FACET 4.2> computational sequence ...
# [2024-11-04 14:24:36.424] | Status  | Checking the format of the data in <FACET 4.2> computational sequence ...
# [2024-11-04 14:24:38.993] | Success | <FACET 4.2> computational sequence data in correct format.
# [2024-11-04 14:24:38.993] | Status  | Checking the format of the metadata in <FACET 4.2> computational sequence ...
# [2024-11-04 14:24:38.993] | Warning | <FACET 4.2> computational sequence does not have all the required metadata ... continuing
# [2024-11-04 14:24:39.003] | Success | Computational sequence read from file ./data/CMU_MOSEI_COVAREP.csd ...
# [2024-11-04 14:24:39.644] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2024-11-04 14:24:39.645] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2024-11-04 14:24:41.791] | Success | <COVAREP> computational sequence data in correct format.
# [2024-11-04 14:24:41.791] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2024-11-04 14:24:41.791] | Warning | <COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-11-04 14:24:41.800] | Success | Computational sequence read from file ./data/CMU_MOSEI_TimestampedWords.csd ...
# [2024-11-04 14:24:42.617] | Status  | Checking the integrity of the <words> computational sequence ...
# [2024-11-04 14:24:42.617] | Status  | Checking the format of the data in <words> computational sequence ...
# [2024-11-04 14:24:44.702] | Success | <words> computational sequence data in correct format.
# [2024-11-04 14:24:44.702] | Status  | Checking the format of the metadata in <words> computational sequence ...
# [2024-11-04 14:24:44.702] | Warning | <words> computational sequence does not have all the required metadata ... continuing
# [2024-11-04 14:24:44.702] | Success | Dataset initialized successfully ...

# %% [markdown]
# To load the dataset, we need to tell the SDK which features we need and where they exist. Thus, we construct a dictionary with format {feature_name: csd_path} and feed it to mmdataset object in the SDK.
#
# From the highlevel features, VisualFacet is used for video modality since this file stores facial expression data extracted using the FACET tool. FACET analyzes microexpressions, including movements of facial muscles (like eyebrow raises or smiles) and emotional states (e.g., joy, anger). Thus, making it more suitable for emotion detection than openFace since it
# tracks facial landmarks, head poses, and eye gaze, offering detailed spatial and motion-related facial features across video frames.
#
# COVAREP is used for audio related features and TimeStampedWordVectors provides Pre-trained embeddings using GLoVe capture semantic relationships and contextual meaning between words.

# %%
print(list(dataset.keys()))
print("=" * 80)

print(list(dataset[visual_field].keys())[:10])
print("=" * 80)

some_id = list(dataset[visual_field].keys())[15]
print(list(dataset[visual_field][some_id].keys()))
print("=" * 80)

word_id = list(dataset[word_field].keys())[15]
print(list(dataset[word_field][word_id].keys()))
print("=" * 80)
print(dataset[word_field].keys())

print('Intervals')
print(list(dataset[visual_field][some_id]['intervals'].shape))
#print(list(dataset[text_field][some_id]['intervals'].shape))
print(list(dataset[word_field][word_id]['intervals'].shape))
print(list(dataset[acoustic_field][some_id]['intervals'].shape))
print("=" * 80)

print('Features')
print(list(dataset[visual_field][some_id]['features'].shape))
#print(list(dataset[text_field][some_id]['features'].shape))
print(list(dataset[word_field][word_id]['features'].shape))
print(list(dataset[acoustic_field][some_id]['features'].shape))
print("Different modalities have different number of time steps!")
# Out:
# ['CMU_MOSEI_VisualFacet42', 'CMU_MOSEI_COVAREP', 'CMU_MOSEI_TimestampedWords']
# ================================================================================
# ['--qXJuDtHPw', '-3g5yACwYnA', '-3nNcZdcdvU', '-571d8cVauQ', '-6rXp3zJ3kc', '-9YyBTjo1zo', '-9y-fZ3swSY', '-AUZQgSxyPQ', '-Alixo7euuU', '-Eqdz5y4pEY']
# ================================================================================
# ['features', 'intervals']
# ================================================================================
# ['features', 'intervals']
# ================================================================================
# dict_keys(['--qXJuDtHPw', '-3g5yACwYnA', '-3nNcZdcdvU', '-571d8cVauQ', '-6rXp3zJ3kc', '-9YyBTjo1zo', '-9y-fZ3swSY', '-AUZQgSxyPQ', '-Alixo7euuU', '-Eqdz5y4pEY', '-HeZS2-Prhc', '-HvKLjmsO5U', '-HwX2H8Z4hY', '-IUUR2yyNbw', '-I_e4mIh0yE', '-IqSFQePnpU', '-KCahx2qBOI', '-LnuDPiuuZw', '-MeTTeMJBNc', '-NFrJFQijFE', '-RfYyzHpjk4', '-RpZEe4w4fY', '-SYSVSQnTnA', '-THoVjtIkeU', '-UUCSKoHeMA', '-UacrmKiTn4', '-UuX1xuaiiE', '-VmheDA92mM', '-WXXTNIJcVM', '-ZgjBOA1Yhw', '-a55Q6RWvTA', '-aNfi7CP8vM', '-aqamKhZ1Ec', '-bl5PfNIYrk', '-cEhr0cQcDM', '-cmk6cfUeMs', '-dZ1TCboxcQ', '-dxfTGcXJoc', '-egA8-b7-3M', '-hPfPhUIzfA', '-hnBHBN8p5A', '-iRBcNs9oI8', '-l_53IwQoj0', '-lqc32Zpr7M', '-lzEya4AM_4', '-m9KtvCk_L8', '-mJ2ud6oKI8', '-mqbVkbCndg', '-o_667Ny7RM', '-qDkUB0GgYY', '-qMhGeJkp5o', '-ri04Z7vwnc', '-rxZxtG0xmY', '-s9qJ7ATP7w', '-t217m2on-s', '-tANM6ETl_M', '-tPCytz4rww', '-uywlfIYOS8', '-vxjVxOeScU', '-wMB_hJL-3o', '-wdUIwjDMfg', '-wny0OAz3g8', '-yRb-Jum7EQ', '03X1FwF6udc', '06st0Ez_E_I', '07Z16yRBFUQ', '08d4NTXkSxw', '0AA-wmk8WdA', '0AkGtPzl7D8', '0BVed2nBq1g', '0DBfvvIVmqY', '0EAAfLCQabY', '0EphpADwdPg', '0FA32bEZ6xI', '0Fqav67TDEw', '0JaYazphxfM', '0JuRmhhgMw8', '0K7dCp80n9c', '0OC3wf9x3zQ', '0OXeN3MhFeA', '0PlQc98SccA', '0SfejBuLgFo', '0Svu5BldR5A', '0W4WsjhDgUI', '0WIwQgH4lKg', '0Xs8wJrAmxs', '0YdYFtVdlWE', '0YiAKqU36KE', '0bsTzavb-AE', '0bxhZ-LIfZY', '0cBmQ_ItVUc', '0eTibWQdO5M', '0hCOCt6fWas', '0hCihQ5Kep0', '0jtdrsmVzYQ', '0mXv97u2OCM', '0nJrksJ7azM', '0p9XKC_J3hU', '0r8KVXUCV6c', '0rE8jEvQW_I', '0tkWa2skSmA', '0uftSGdwo0Q', '0utROiKxejc', '0vXaXWx7Rvo', '0y022OlZ3W0', '0zl_GDVzykw', '100178', '100232', '100367', '100446', '100499', '100961', '10124', '101281', '101513', '101635', '101708', '101733', '101747', '101787', '101851', '101880', '102168', '102184', '10219', '102213', '10223', '102389', '102408', '102424', '102534', '102858', '103114', '103311', '10397', '104739', '104741', '105507', '105537', '105553', '105906', '105963', '106037', '106077', '106514', '106941', '106973', '107182', '107456', '107551', '107585', '108146', '108573', '108793', '109524', '109909', '110003', '110203', '110209', '110543', '110565', '110690', '110754', '110766', '110788', '110794', '110824', '110983', '111104', '111363', '111734', '111881', '112029', '112148', '112169', '112172', '112223', '112425', '112433', '112509', '112604', '112631', '112674', '112903', '113162', '113265', '113369', '113491', '114006', '114016', '114419', '114624', '114845', '114945', '115134', '116202', '116213', '116219', '116221', '116461', '116481', '11650', '117tQqLjza4', '118354', '118573', '118583', '118639', '119348', '119397', '11UtTaDYgII', '11j7EfglCAs', '120342', '120363', '120vnZnmhq4', '121117', '121128', '121358', '121400', '121427', '121584', '121759', '122439', '122581', '122602', '122842', '123986', '124190', '125344', '125676', '125698', '125708', '125726', '125730', '125845', '125868', '125895', '126505', '126542', '126831', '126872', '127470', '127490', '127539', '127622', '127908', '128059', '12812', '128258', '128600', '128752', '128763', '128949', '129728', '129733', '130149', '130366', '130426', '130448', '130456', '130633', '131650', '131871', '131936', '132028', '132476', '132570', '133201', '133888', '134252', '134298', '135623', '135658', '136196', '136205', '136211', '136215', '136234', '136416', '136647', '137455', '137827', '137920', '139006', '139032', '13JpsLvddoY', '140293', '140315', '140317', '154449', '15837', '158832', '158855', '159031', '15Wu4U2VPLw', '15ktF-6wutk', '160225', '16145', '16530', '167521', '172044', '172048', '172050', '172060', '172075', '173CpFb3clw', '17622', '176266', '176541', '17769', '17811', '178163', '17874', '178941', '179797', '179875', '180923', '180971', '181978', '183364', '184784', '186631', '186643', '187033', '187566', '187775', '188004', '188062', '188122', '188343', '188815', '188825', '18938', '189856', '189966', '18JTkk8JbeU', '18QjfdhJEM4', '190599', '190726', '190740', '190743', '191616', '191941', '19 ...
# Intervals
# [3658, 2]
# [321, 2]
# [12209, 2]
# ================================================================================
# Features
# [3658, 35]
# [321, 1]
# [12209, 74]
# Different modalities have different number of time steps!

# %%
if SETUP:
# we define a simple averaging function that does not depend on intervals
    def avg(intervals: np.array, features: np.array) -> np.array:
        try:
            return np.average(features, axis=0)
        except:
            return features

    # first we align to words with averaging, collapse_function receives a list of functions
    dataset.align(word_field, collapse_functions=[avg])
# Out:
# [2024-11-04 14:24:53.898] | Status  | Unify was called ...
# [2024-11-04 14:24:53.901] | Warning | PEBwwe0PLZ8 entry is not shared among all sequences, removing it ...
# [2024-11-04 14:24:53.902] | Success | Unify completed ...
# [2024-11-04 14:24:53.902] | Status  | Pre-alignment based on <CMU_MOSEI_TimestampedWords> computational sequence started ...
# [2024-11-04 14:25:21.871] | Status  | Pre-alignment done for <CMU_MOSEI_VisualFacet42> ...
# [2024-11-04 14:33:06.372] | Status  | Pre-alignment done for <CMU_MOSEI_COVAREP> ...
# [2024-11-04 14:35:31.209] | Status  | Alignment starting ...
# [2024-11-04 15:58:21.970] | Success | Alignment to <CMU_MOSEI_TimestampedWords> complete.
# [2024-11-04 15:58:21.970] | Status  | Replacing dataset content with aligned computational sequences
# [2024-11-04 15:58:25.724] | Success | Initialized empty <CMU_MOSEI_VisualFacet42> computational sequence.
# [2024-11-04 15:58:25.725] | Status  | Checking the format of the data in <CMU_MOSEI_VisualFacet42> computational sequence ...
# [2024-11-04 15:58:28.263] | Success | <CMU_MOSEI_VisualFacet42> computational sequence data in correct format.
# [2024-11-04 15:58:28.263] | Status  | Checking the format of the metadata in <CMU_MOSEI_VisualFacet42> computational sequence ...
# [2024-11-04 15:58:28.263] | Warning | <CMU_MOSEI_VisualFacet42> computational sequence does not have all the required metadata ... continuing
# [2024-11-04 15:58:28.263] | Success | Initialized empty <CMU_MOSEI_COVAREP> computational sequence.
# [2024-11-04 15:58:28.263] | Status  | Checking the format of the data in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-11-04 15:58:29.476] | Success | <CMU_MOSEI_COVAREP> computational sequence data in correct format.
# [2024-11-04 15:58:29.476] | Status  | Checking the format of the metadata in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-11-04 15:58:29.476] | Warning | <CMU_MOSEI_COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-11-04 15:58:29.476] | Success | Initialized empty <CMU_MOSEI_TimestampedWords> computational sequence.
# [2024-11-04 15:58:29.476] | Status  | Checking the format of the data in <CMU_MOSEI_TimestampedWords> computational sequence ...
# [2024-11-04 15:58:30.698] | Success | <CMU_MOSEI_TimestampedWords> computational sequence data in correct format.
# [2024-11-04 15:58:30.699] | Status  | Checking the format of the metadata in <CMU_MOSEI_TimestampedWords> computational sequence ...
# [2024-11-04 15:58:30.699] | Warning | <CMU_MOSEI_TimestampedWords> computational sequence does not have all the required metadata ... continuing

# %%
# if SETUP:
#     deploy_files={x:x for x in dataset.keys()}
#     dataset.deploy("hl1",deploy_files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 if SETUP:
#       2     deploy_files={x:x for x in dataset.keys()}
#       3     dataset.deploy("hl1",deploy_files)
#
# NameError: name 'SETUP' is not defined

# %%
label_field = 'CMU_MOSEI_Labels'

# we add and align to lables to obtain labeled segments
# this time we don't apply collapse functions so that the temporal sequences are preserved
label_recipe = {label_field: os.path.join(DATA_PATH, label_field + '.csd')}
dataset.add_computational_sequences(label_recipe, destination=None)
dataset.align(label_field)
# Out:
# [2024-11-04 16:39:33.228] | Success | Computational sequence read from file ./data/CMU_MOSEI_Labels.csd ...
# [2024-11-04 16:39:33.949] | Status  | Checking the integrity of the <All Labels> computational sequence ...
# [2024-11-04 16:39:33.950] | Status  | Checking the format of the data in <All Labels> computational sequence ...
# [2024-11-04 16:39:35.633] | Success | <All Labels> computational sequence data in correct format.
# [2024-11-04 16:39:35.633] | Status  | Checking the format of the metadata in <All Labels> computational sequence ...
# [2024-11-04 16:39:35.633] | Warning | <All Labels> computational sequence does not have all the required metadata ... continuing
# [2024-11-04 16:39:35.633] | Status  | Unify was called ...
# [2024-11-04 16:39:37.184] | Warning | 127490 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:37.720] | Warning | 199227 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:38.272] | Warning | 238858 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:38.830] | Warning | 270993 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:39.366] | Warning | 21285 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:39.897] | Warning | 57295 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:40.335] | Warning | 121117 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:40.786] | Warning | 96595 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:41.228] | Warning | 69268 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:41.675] | Warning | 294226 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:42.125] | Warning | 172060 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:42.569] | Warning | 191616 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:43.021] | Warning | 22719 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:43.469] | Warning | 44457 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:43.917] | Warning | 160225 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:44.360] | Warning | 262341 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:44.800] | Warning | 114845 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:45.252] | Warning | 98155 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:45.701] | Warning | 90008 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:46.150] | Warning | 59712 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:46.585] | Warning | 16145 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:47.020] | Warning | 49264 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:47.456] | Warning | 57231 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:47.898] | Warning | 96694 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:48.342] | Warning | 193514 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:48.783] | Warning | 7l3BNtSE0xc entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:49.221] | Warning | 58151 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:49.660] | Warning | 18938 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:50.104] | Warning | 245207 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:50.561] | Warning | 223338 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:51.011] | Warning | 60328 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:51.477] | Warning | 112172 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:51.939] | Warning | 116481 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:52.388] | Warning | 219620 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:52.850] | Warning | 91996 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:53.301] | Warning | 103311 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:53.752] | Warning | 95205 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:54.202] | Warning | 118354 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:54.658] | Warning | 247538 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:55.112] | Warning | 17769 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:55.565] | Warning | 219600 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:56.011] | Warning | 84670 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:56.447] | Warning | 33089 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:56.893] | Warning | 122581 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:57.329] | Warning | 224649 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:57.766] | Warning | 79858 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:58.211] | Warning | 22884 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:58.645] | Warning | 204792 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:59.085] | Warning | 61277 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:59.519] | Warning | 81707 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:39:59.958] | Warning | 218912 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:00.396] | Warning | 28182 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:00.837] | Warning | 93807 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:01.267] | Warning | 233940 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:01.702] | Warning | 134298 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:02.145] | Warning | 88077 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:02.578] | Warning | 91252 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:03.009] | Warning | 261052 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:03.453] | Warning | 22277 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:03.894] | Warning | 31392 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:04.330] | Warning | 125726 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:04.772] | Warning | 34984 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:05.211] | Warning | 93845 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:05.642] | Warning | 88792 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:06.077] | Warning | 47056 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:06.514] | Warning | 26690 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:06.948] | Warning | 89266 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:07.377] | Warning | 41026 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:07.816] | Warning | 49903 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:08.254] | Warning | 207118 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:08.691] | Warning | 203806 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:09.130] | Warning | 110209 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:09.566] | Warning | 218757 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:10.008] | Warning | FrS-6P6FdCM entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:10.426] | Warning | 209869 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:10.862] | Warning | 47797 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:11.292] | Warning | 49962 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:11.728] | Warning | 5jGUBcStsZs entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:12.153] | Warning | 73360 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:12.594] | Warning | 188815 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:13.031] | Warning | 48724 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:13.465] | Warning | 201980 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:13.897] | Warning | 41032 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:14.327] | Warning | 368460 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:14.763] | Warning | 126505 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:15.198] | Warning | dZFV0lyedX4 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:15.618] | Warning | 115134 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:16.057] | Warning | HK0U0bIN-cw entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:16.478] | Warning | 40970 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:16.911] | Warning | vi0FsBCqfRE entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:17.334] | Warning | 22785 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:17.771] | Warning | 79203 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:18.196] | Warning | 132476 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:18.633] | Warning | 238624 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:19.063] | Warning | 127622 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:19.491] | Warning | 91002 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:19.920] | Warning | 210240 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:20.348] | Warning | 101635 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:20.781] | Warning | 63841 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:21.209] | Warning | 19664 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:21.641] | Warning | 97463 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:22.069] | Warning | 26113 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:22.501] | Warning | 36116 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:22.935] | Warning | 254216 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:23.369] | Warning | 94525 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:23.801] | Warning | 27886 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:24.236] | Warning | 121427 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:24.668] | Warning | 341382 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:25.103] | Warning | 236108 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:25.537] | Warning | 50306 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:25.970] | Warning | 136416 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:26.400] | Warning | 24814 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:26.830] | Warning | 110824 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:27.259] | Warning | 29758 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:27.687] | Warning | 187566 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:28.122] | Warning | 112029 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:28.555] | Warning | 70299 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:28.976] | Warning | 57294 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:29.404] | Warning | 82666 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:29.825] | Warning | 105906 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:30.257] | Warning | 88881 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:30.678] | Warning | 236306 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:31.108] | Warning | 116219 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:31.539] | Warning | 61557 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:31.973] | Warning | 86494 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:32.397] | Warning | 27881 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:32.823] | Warning | 69307 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:33.244] | Warning | 217395 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:33.672] | Warning | 109909 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:34.108] | Warning | 65068 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:34.531] | Warning | 327282 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:34.963] | Warning | 61035 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:35.385] | Warning | 69234 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:35.809] | Warning | 107456 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:36.239] | Warning | 60983 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:36.661] | Warning | 58554 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:37.084] | Warning | 191941 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:37.504] | Warning | 188825 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:37.927] | Warning | 193093 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:38.355] | Warning | 128600 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:38.782] | Warning | 193924 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:39.213] | Warning | 260199 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:39.643] | Warning | 239242 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:40.075] | Warning | 57598 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:40.502] | Warning | 116221 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:40.926] | Warning | 102424 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:41.350] | Warning | 93843 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:41.776] | Warning | 66623 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:42.198] | Warning | 298459 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:42.622] | Warning | 30171 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:43.053] | Warning | 98649 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:43.474] | Warning | 65939 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:43.895] | Warning | 188062 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:44.324] | Warning | 101880 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:44.756] | Warning | 74115 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:45.181] | Warning | 370050 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:45.599] | Warning | 60402 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:46.016] | Warning | 40266 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:46.445] | Warning | 341983 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:46.867] | Warning | 37462 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:47.295] | Warning | 101281 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:47.715] | Warning | 21735 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:48.140] | Warning | 280584 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:48.569] | Warning | 105963 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:49.004] | Warning | 24602 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:49.423] | Warning | 42426 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:49.840] | Warning | 250343 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:50.272] | Warning | 35934 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:50.700] | Warning | 49073 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:51.120] | Warning | 21696 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:51.543] | Warning | 201497 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:51.965] | Warning | 229637 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:52.385] | Warning | 120342 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:52.811] | Warning | 229808 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:53.235] | Warning | 204085 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:53.654] | Warning | 101747 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:54.085] | Warning | 97289 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:54.516] | Warning | 36164 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:54.940] | Warning | 28191 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:55.377] | Warning | 78752 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:55.795] | Warning | 179875 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:56.223] | Warning | 34640 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:56.651] | Warning | 213375 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:57.074] | Warning | 120363 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:57.489] | Warning | 243797 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:57.917] | Warning | 203466 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:58.333] | Warning | 193322 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:58.755] | Warning | 205268 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:59.180] | Warning | 46503 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:40:59.600] | Warning | 342407 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:00.026] | Warning | 204378 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:00.444] | Warning | 223883 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:00.867] | Warning | 105507 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:01.291] | Warning | 270439 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:01.714] | Warning | 273510 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:02.137] | Warning | 247108 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:02.563] | Warning | 233431 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:02.988] | Warning | 176541 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:03.409] | Warning | 107182 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:03.836] | Warning | 98513 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:04.251] | Warning | 224325 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:04.668] | Warning | 10124 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:05.091] | Warning | 224238 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:05.517] | Warning | 91284 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:05.930] | Warning | 280794 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:06.354] | Warning | 60351 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:06.769] | Warning | 105537 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:07.187] | Warning | 17811 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:07.602] | Warning | 104739 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:08.021] | Warning | 101708 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:08.437] | Warning | 74532 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:08.851] | Warning | 63956 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:09.274] | Warning | 16530 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:09.686] | Warning | 105553 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:10.103] | Warning | rLNY4-FWt5c entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:10.506] | Warning | 46860 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:10.920] | Warning | 301321 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:11.344] | Warning | 7155 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:11.758] | Warning | 91166 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:12.172] | Warning | Jv4CxSgWP2k entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:12.577] | Warning | 102534 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:12.993] | Warning | 172075 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:13.406] | Warning | 90667 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:13.821] | Warning | 207964 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:14.238] | Warning | 22305 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:14.648] | Warning | 246117 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:15.070] | Warning | 268258 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:15.491] | Warning | 40129 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:15.909] | Warning | 76104 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:16.326] | Warning | 247764 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:16.742] | Warning | 110794 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:17.155] | Warning | 93828 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:17.565] | Warning | 21727 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:17.977] | Warning | 111734 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:18.387] | Warning | 80640 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:18.799] | Warning | 19915 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:19.223] | Warning | 114016 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:19.639] | Warning | 239180 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:20.051] | Warning | 253709 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:20.463] | Warning | 75892 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:20.870] | Warning | 84924 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:21.281] | Warning | 270771 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:21.697] | Warning | 97908 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:22.108] | Warning | 93116 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:22.520] | Warning | 224271 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:22.932] | Warning | 196364 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:23.340] | Warning | 290062 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:23.756] | Warning | 263889 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:24.173] | Warning | 259857 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:24.584] | Warning | 91292 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:24.991] | Warning | 224285 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:25.401] | Warning | 231412 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:25.815] | Warning | 52067 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:26.233] | Warning | 78398 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:26.648] | Warning | 43428 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:27.057] | Warning | 172050 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:27.471] | Warning | 69870 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:27.879] | Warning | 33272 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:28.296] | Warning | 221104 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:28.716] | Warning | 26808 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:29.131] | Warning | 274917 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:29.538] | Warning | 140315 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:29.953] | Warning | 30858 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:30.371] | Warning | 59302 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:30.780] | Warning | 220550 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:31.201] | Warning | 79019 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:31.605] | Warning | 224498 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:32.022] | Warning | 27857 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:32.436] | Warning | 43469 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:32.851] | Warning | 22360 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:33.263] | Warning | 46663 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:33.673] | Warning | 94532 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:34.083] | Warning | 100232 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:34.496] | Warning | 30762 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:34.909] | Warning | 52160 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:35.316] | Warning | 58096 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:35.729] | Warning | 89184 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:36.137] | Warning | 323217 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:36.563] | Warning | 74197 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:36.969] | Warning | 103114 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:37.384] | Warning | 26115 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:37.794] | Warning | 206148 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:38.205] | Warning | 279373 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:38.620] | Warning | 178163 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:39.027] | Warning | 238042 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:39.443] | Warning | 226602 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:39.848] | Warning | 40367 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:40.257] | Warning | 219605 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:40.667] | Warning | 27863 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:41.079] | Warning | 94439 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:41.480] | Warning | 135658 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:41.891] | Warning | 210098 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:42.303] | Warning | 158855 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:42.712] | Warning | 83119 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:43.115] | Warning | 100961 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:43.522] | Warning | 222510 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:43.928] | Warning | 207977 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:44.336] | Warning | 111363 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:44.737] | Warning | 98505 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:45.142] | Warning | 246789 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:45.554] | Warning | 238597 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:45.966] | Warning | 32459 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:46.376] | Warning | 228925 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:46.784] | Warning | 195575 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:47.195] | Warning | 230692 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:47.604] | Warning | 231453 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:48.004] | Warning | 535523 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:48.411] | Warning | 118573 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:48.814] | Warning | 275603 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:49.226] | Warning | 84772 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:49.628] | Warning | 19850 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:50.034] | Warning | 21844 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:50.435] | Warning | 232464 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:50.845] | Warning | 74268 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:51.245] | Warning | 48019 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:51.651] | Warning | 181978 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:52.059] | Warning | 268536 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:52.469] | Warning | 114945 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:52.877] | Warning | 229296 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:53.288] | Warning | 75393 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:53.686] | Warning | 213207 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:54.090] | Warning | 58795 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:54.492] | Warning | 79925 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:54.896] | Warning | 219614 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:55.297] | Warning | 219627 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:55.702] | Warning | 50302 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:56.107] | Warning | 280951 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:56.513] | Warning | 110690 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:56.929] | Warning | 28142 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:57.331] | Warning | 118639 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:57.732] | Warning | 137455 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:58.133] | Warning | 26110 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:58.536] | Warning | 34684 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:58.940] | Warning | 233405 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:59.345] | Warning | 224292 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:41:59.752] | Warning | 34989 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:00.162] | Warning | 23343 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:00.561] | Warning | 17622 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:00.960] | Warning | 96106 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:01.354] | Warning | 19573 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:01.758] | Warning | 208465 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:02.162] | Warning | 29771 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:02.563] | Warning | 220832 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:02.963] | Warning | 98562 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:03.362] | Warning | 265811 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:03.776] | Warning | 50479 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:04.176] | Warning | 238567 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:04.584] | Warning | 27888 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:04.985] | Warning | 48300 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:05.385] | Warning | 22798 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:05.787] | Warning | 124190 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:06.191] | Warning | 114006 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:06.592] | Warning | 206179 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:06.994] | Warning | 96700 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:07.389] | Warning | 42946 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:07.791] | Warning | 188004 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:08.191] | Warning | 106973 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:08.589] | Warning | 109524 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:08.989] | Warning | 301320 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:09.398] | Warning | 238545 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:09.804] | Warning | 56853 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:10.199] | Warning | 30646 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:10.603] | Warning | 187775 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:11.002] | Warning | 237385 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:11.400] | Warning | 46808 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:11.798] | Warning | 17874 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:12.195] | Warning | 91574 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:12.587] | Warning | 158832 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:12.980] | Warning | 222605 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:13.380] | Warning | 118583 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:13.773] | Warning | 234406 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:14.166] | Warning | 22901 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:14.564] | Warning | 228561 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:14.956] | Warning | 100367 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:15.351] | Warning | 136234 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:15.767] | Warning | 242166 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:16.170] | Warning | 127908 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:16.563] | Warning | 27880 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:16.964] | Warning | 224472 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:17.369] | Warning | 81371 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:17.760] | Warning | 241124 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:18.153] | Warning | 76819 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:18.555] | Warning | 47939 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:18.948] | Warning | 50307 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:19.358] | Warning | 74204 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:19.761] | Warning | 10397 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:20.159] | Warning | 29920 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:20.553] | Warning | 108573 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:20.945] | Warning | 219460 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:21.341] | Warning | 96377 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:21.732] | Warning | 33436 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:22.125] | Warning | 121584 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:22.522] | Warning | 100446 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:22.920] | Warning | 45860 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:23.319] | Warning | 248400 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:23.716] | Warning | 129728 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:24.123] | Warning | 49417 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:24.517] | Warning | 267354 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:24.915] | Warning | 190726 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:25.318] | Warning | 46826 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:25.721] | Warning | 61247 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:26.113] | Warning | 95887 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:26.502] | Warning | 199215 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:26.893] | Warning | 66505 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:27.284] | Warning | 35684 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:27.679] | Warning | 24157 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:28.076] | Warning | 207867 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:28.472] | Warning | 230422 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:28.865] | Warning | 68828 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:29.254] | Warning | 227556 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:29.651] | Warning | 31544 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:30.044] | Warning | 266861 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:30.441] | Warning | 132570 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:30.838] | Warning | 36060 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:31.228] | Warning | 268127 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:31.626] | Warning | 187033 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:32.025] | Warning | 97076 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:32.417] | Warning | 193921 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:32.814] | Warning | OPuu8EknNqk entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:33.197] | Warning | 125868 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:33.583] | Warning | 238803 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:33.981] | Warning | 248024 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:34.370] | Warning | 276771 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:34.764] | Warning | 74447 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:35.156] | Warning | 274073 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:35.553] | Warning | 123986 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:35.946] | Warning | 133888 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:36.346] | Warning | 50478 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:36.744] | Warning | 342197 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:37.134] | Warning | 196665 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:37.530] | Warning | 119397 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:37.922] | Warning | 207958 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:38.312] | Warning | 60308 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:38.708] | Warning | 38387 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:39.105] | Warning | 215343 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:39.497] | Warning | 133201 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:39.888] | Warning | 136647 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:40.281] | Warning | 22335 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:40.675] | Warning | 159031 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:41.066] | Warning | 370404 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:41.454] | Warning | 246798 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:41.850] | Warning | 211611 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:42.241] | Warning | 258802 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:42.631] | Warning | 252919 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:43.025] | Warning | 40247 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:43.421] | Warning | PEBwwe0PLZ8 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:43.801] | Warning | 110003 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:44.189] | Warning | 210555 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:44.572] | Warning | 254488 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:44.973] | Warning | jHB9kiH6Vas entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:45.355] | Warning | 28412 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:45.744] | Warning | 114419 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:46.134] | Warning | 178941 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:46.522] | Warning | 43444 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:46.903] | Warning | 189856 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:47.299] | Warning | 71987 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:47.682] | Warning | 113162 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:48.081] | Warning | 197232 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:48.467] | Warning | 60405 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:48.857] | Warning | 71736 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:49.246] | Warning | 306700 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:49.634] | Warning | 1nXhAjuICTA entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:50.017] | Warning | 299754 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:50.409] | Warning | eLjNLHkvxH4 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:50.788] | Warning | 113369 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:51.174] | Warning | 267092 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:51.569] | Warning | 255205 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:51.961] | Warning | 272817 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:52.357] | Warning | 224622 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:52.759] | Warning | 193894 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:53.143] | Warning | 60428 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:53.531] | Warning | 58097 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:53.916] | Warning | 186643 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:54.302] | Warning | 341763 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:54.689] | Warning | 106037 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:55.070] | Warning | 93119 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:55.458] | Warning | 204519 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:55.843] | Warning | 111104 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:56.228] | Warning | 190599 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:56.616] | Warning | 99331 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:56.998] | Warning | 223885 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:57.385] | Warning | 121759 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:57.772] | Warning | 50444 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:58.154] | Warning | 81563 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:58.535] | Warning | 192978 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:58.925] | Warning | 243056 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:59.313] | Warning | 223377 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:42:59.706] | Warning | 98636 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:00.088] | Warning | 223333 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:00.471] | Warning | 176266 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:00.853] | Warning | 35692 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:01.242] | Warning | 95388 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:01.624] | Warning | 116202 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:02.009] | Warning | 258672 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:02.391] | Warning | 282985 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:02.785] | Warning | 251251 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:03.171] | Warning | 53233 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:03.552] | Warning | 96337 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:03.930] | Warning | 219350 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:04.327] | Warning | 68721 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:04.709] | Warning | 71459 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:05.093] | Warning | 302220 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:05.478] | Warning | 22344 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:05.858] | Warning | 113491 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:06.239] | Warning | 224648 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:06.625] | Warning | 125698 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:07.010] | Warning | 273032 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:07.407] | Warning | 233880 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:07.787] | Warning | 245926 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:08.182] | Warning | 101733 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:08.558] | Warning | 116461 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:08.942] | Warning | 192827 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:09.331] | Warning | 23289 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:09.716] | Warning | 265302 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:10.107] | Warning | 183364 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:10.485] | Warning | 112674 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:10.867] | Warning | 216831 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:11.254] | Warning | 87434 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:11.629] | Warning | 38154 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:12.013] | Warning | 179797 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:12.387] | Warning | 7156 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:12.768] | Warning | 43342 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:13.147] | Warning | 49029 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:13.534] | Warning | 101513 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:13.914] | Warning | 30036 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:14.294] | Warning | 234641 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:14.671] | Warning | 246216 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:15.050] | Warning | 75441 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:15.426] | Warning | 263444 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:15.815] | Warning | 206621 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:16.201] | Warning | 24508 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:16.585] | Warning | 87163 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:16.959] | Warning | 137920 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:17.341] | Warning | 172048 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:17.716] | Warning | 220809 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:18.095] | Warning | 48219 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:18.473] | Warning | 62438 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:18.852] | Warning | 110983 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:19.231] | Warning | 172044 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:19.608] | Warning | 110543 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:19.984] | Warning | 46592 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:20.366] | Warning | 22649 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:20.738] | Warning | 274185 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:21.111] | Warning | 241178 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:21.487] | Warning | 95147 entry is not shared among all sequences, removing it ...
# [2024-11-04 16:43:21.861] | Success | Unify completed ...
# [2024-11-04 16:43:21.892] | Status  | Pre-alignment based on <CMU_MOSEI_Labels> computational sequence started ...
# [2024-11-04 16:43:24.335] | Status  | Pre-alignment done for <CMU_MOSEI_VisualFacet42> ...
# [2024-11-04 16:43:26.565] | Status  | Pre-alignment done for <CMU_MOSEI_TimestampedWords> ...
# [2024-11-04 16:43:28.880] | Status  | Pre-alignment done for <CMU_MOSEI_COVAREP> ...
# [2024-11-04 16:43:28.950] | Status  | Alignment starting ...
# [2024-11-04 16:44:00.940] | Success | Alignment to <CMU_MOSEI_Labels> complete.
# [2024-11-04 16:44:00.940] | Status  | Replacing dataset content with aligned computational sequences
# [2024-11-04 16:44:03.762] | Success | Initialized empty <CMU_MOSEI_VisualFacet42> computational sequence.
# [2024-11-04 16:44:03.762] | Status  | Checking the format of the data in <CMU_MOSEI_VisualFacet42> computational sequence ...
# [2024-11-04 16:44:03.793] | Success | <CMU_MOSEI_VisualFacet42> computational sequence data in correct format.
# [2024-11-04 16:44:03.793] | Status  | Checking the format of the metadata in <CMU_MOSEI_VisualFacet42> computational sequence ...
# [2024-11-04 16:44:03.793] | Warning | <CMU_MOSEI_VisualFacet42> computational sequence does not have all the required metadata ... continuing
# [2024-11-04 16:44:03.793] | Success | Initialized empty <CMU_MOSEI_COVAREP> computational sequence.
# [2024-11-04 16:44:03.793] | Status  | Checking the format of the data in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-11-04 16:44:03.821] | Success | <CMU_MOSEI_COVAREP> computational sequence data in correct format.
# [2024-11-04 16:44:03.822] | Status  | Checking the format of the metadata in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-11-04 16:44:03.822] | Warning | <CMU_MOSEI_COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-11-04 16:44:03.822] | Success | Initialized empty <CMU_MOSEI_TimestampedWords> computational sequence.
# [2024-11-04 16:44:03.822] | Status  | Checking the format of the data in <CMU_MOSEI_TimestampedWords> computational sequence ...
# [2024-11-04 16:44:03.851] | Success | <CMU_MOSEI_TimestampedWords> computational sequence data in correct format.
# [2024-11-04 16:44:03.851] | Status  | Checking the format of the metadata in <CMU_MOSEI_TimestampedWords> computational sequence ...
# [2024-11-04 16:44:03.851] | Warning | <CMU_MOSEI_TimestampedWords> computational sequence does not have all the required metadata ... continuing
# [2024-11-04 16:44:03.851] | Success | Initialized empty <CMU_MOSEI_Labels> computational sequence.
# [2024-11-04 16:44:03.851] | Status  | Checking the format of the data in <CMU_MOSEI_Labels> computational sequence ...
# [2024-11-04 16:44:03.886] | Success | <CMU_MOSEI_Labels> computational sequence data in correct format.
# [2024-11-04 16:44:03.886] | Status  | Checking the format of the metadata in <CMU_MOSEI_Labels> computational sequence ...
# [2024-11-04 16:44:03.886] | Warning | <CMU_MOSEI_Labels> computational sequence does not have all the required metadata ... continuing

# %%
# Print some keys to see the segmentation structure
print(list(dataset[label_field].keys())[:10])

# Pick a specific segmented key to explore further
some_segmented_key = list(dataset[label_field].keys())[0]

# Check the aligned features and intervals for this segment
print("Label intervals:", dataset[label_field][some_segmented_key]['intervals'].shape)
print("Label features:", dataset[label_field][some_segmented_key]['features'].shape)

print("Text features:", dataset[word_field][some_segmented_key]['features'].shape)
print("Visual features:", dataset[visual_field][some_segmented_key]['features'].shape)
print("Acoustic features:", dataset[acoustic_field][some_segmented_key]['features'].shape)
# Out:
# ['--qXJuDtHPw[0]', '-3g5yACwYnA[0]', '-3g5yACwYnA[1]', '-3g5yACwYnA[2]', '-3g5yACwYnA[3]', '-3g5yACwYnA[4]', '-3g5yACwYnA[5]', '-3nNcZdcdvU[0]', '-3nNcZdcdvU[1]', '-3nNcZdcdvU[2]']
# Label intervals: (1, 2)
# Label features: (1, 7)
# Text features: (22, 1)
# Visual features: (22, 35)
# Acoustic features: (22, 74)

# %%
# check out what the keys look like now
print(list(dataset[word_field].keys())[55])
# Out:
# -HwX2H8Z4hY[4]

# %%
# Define the label field where the emotions are stored
label_field = 'CMU_MOSEI_Labels'

# Emotion mapping (assuming order is [happy, sad, anger, surprise, disgust, fear])
emotions = ["happy", "sad", "anger", "surprise", "disgust", "fear"]

# Print emotion labels for each segment with additional checks
print("Emotion Labels for each segment:")

for segment in dataset[label_field].keys():
    # Access emotion labels for this segment
    emotion_data = dataset[label_field][segment]['features']
    
    # Print shape of emotion_data for debugging purposes
    print(f"Segment: {segment}, Emotion Data Shape: {emotion_data.shape}")

    # Flatten emotion data and ensure it aligns with the number of defined emotions
    emotion_data_flat = emotion_data.flatten()
    emotion_labels = []
    
    # Only iterate up to the length of `emotions` to prevent out-of-range errors
    for idx in range(min(len(emotion_data_flat), len(emotions))):
        if emotion_data_flat[idx] == 1:
            emotion_labels.append(emotions[idx])
    
    print(f"Segment: {segment} -> Emotions: {emotion_labels}")

# Count occurrences of each emotion
emotion_count = {emotion: 0 for emotion in emotions}
for segment in dataset[label_field].keys():
    emotion_data = dataset[label_field][segment]['features']
    emotion_data_flat = emotion_data.flatten()
    for idx in range(min(len(emotion_data_flat), len(emotions))):
        if emotion_data_flat[idx] == 1:
            emotion_count[emotions[idx]] += 1

print("\nEmotion Distribution in Dataset:", emotion_count)
# Out:
# Emotion Labels for each segment:
# Segment: --qXJuDtHPw[0], Emotion Data Shape: (1, 7)
# Segment: --qXJuDtHPw[0] -> Emotions: ['happy']
# Segment: -3g5yACwYnA[0], Emotion Data Shape: (1, 7)
# Segment: -3g5yACwYnA[0] -> Emotions: ['happy']
# Segment: -3g5yACwYnA[1], Emotion Data Shape: (1, 7)
# Segment: -3g5yACwYnA[1] -> Emotions: []
# Segment: -3g5yACwYnA[2], Emotion Data Shape: (1, 7)
# Segment: -3g5yACwYnA[2] -> Emotions: []
# Segment: -3g5yACwYnA[3], Emotion Data Shape: (1, 7)
# Segment: -3g5yACwYnA[3] -> Emotions: []
# Segment: -3g5yACwYnA[4], Emotion Data Shape: (1, 7)
# Segment: -3g5yACwYnA[4] -> Emotions: ['happy']
# Segment: -3g5yACwYnA[5], Emotion Data Shape: (1, 7)
# Segment: -3g5yACwYnA[5] -> Emotions: []
# Segment: -3nNcZdcdvU[0], Emotion Data Shape: (1, 7)
# Segment: -3nNcZdcdvU[0] -> Emotions: []
# Segment: -3nNcZdcdvU[1], Emotion Data Shape: (1, 7)
# Segment: -3nNcZdcdvU[1] -> Emotions: ['happy']
# Segment: -3nNcZdcdvU[2], Emotion Data Shape: (1, 7)
# Segment: -3nNcZdcdvU[2] -> Emotions: []
# Segment: -571d8cVauQ[0], Emotion Data Shape: (1, 7)
# Segment: -571d8cVauQ[0] -> Emotions: []
# Segment: -571d8cVauQ[1], Emotion Data Shape: (1, 7)
# Segment: -571d8cVauQ[1] -> Emotions: []
# Segment: -571d8cVauQ[2], Emotion Data Shape: (1, 7)
# Segment: -571d8cVauQ[2] -> Emotions: []
# Segment: -6rXp3zJ3kc[0], Emotion Data Shape: (1, 7)
# Segment: -6rXp3zJ3kc[0] -> Emotions: []
# Segment: -6rXp3zJ3kc[1], Emotion Data Shape: (1, 7)
# Segment: -6rXp3zJ3kc[1] -> Emotions: []
# Segment: -6rXp3zJ3kc[2], Emotion Data Shape: (1, 7)
# Segment: -6rXp3zJ3kc[2] -> Emotions: []
# Segment: -9YyBTjo1zo[0], Emotion Data Shape: (1, 7)
# Segment: -9YyBTjo1zo[0] -> Emotions: []
# Segment: -9YyBTjo1zo[1], Emotion Data Shape: (1, 7)
# Segment: -9YyBTjo1zo[1] -> Emotions: []
# Segment: -9YyBTjo1zo[2], Emotion Data Shape: (1, 7)
# Segment: -9YyBTjo1zo[2] -> Emotions: []
# Segment: -9YyBTjo1zo[3], Emotion Data Shape: (1, 7)
# Segment: -9YyBTjo1zo[3] -> Emotions: []
# Segment: -9YyBTjo1zo[4], Emotion Data Shape: (1, 7)
# Segment: -9YyBTjo1zo[4] -> Emotions: ['sad', 'fear']
# Segment: -9y-fZ3swSY[0], Emotion Data Shape: (1, 7)
# Segment: -9y-fZ3swSY[0] -> Emotions: ['happy']
# Segment: -9y-fZ3swSY[1], Emotion Data Shape: (1, 7)
# Segment: -9y-fZ3swSY[1] -> Emotions: ['sad']
# Segment: -9y-fZ3swSY[2], Emotion Data Shape: (1, 7)
# Segment: -9y-fZ3swSY[2] -> Emotions: []
# Segment: -9y-fZ3swSY[3], Emotion Data Shape: (1, 7)
# Segment: -9y-fZ3swSY[3] -> Emotions: ['sad', 'disgust']
# Segment: -9y-fZ3swSY[4], Emotion Data Shape: (1, 7)
# Segment: -9y-fZ3swSY[4] -> Emotions: []
# Segment: -9y-fZ3swSY[5], Emotion Data Shape: (1, 7)
# Segment: -9y-fZ3swSY[5] -> Emotions: ['surprise']
# Segment: -9y-fZ3swSY[6], Emotion Data Shape: (1, 7)
# Segment: -9y-fZ3swSY[6] -> Emotions: []
# Segment: -9y-fZ3swSY[7], Emotion Data Shape: (1, 7)
# Segment: -9y-fZ3swSY[7] -> Emotions: []
# Segment: -AUZQgSxyPQ[0], Emotion Data Shape: (1, 7)
# Segment: -AUZQgSxyPQ[0] -> Emotions: []
# Segment: -Alixo7euuU[0], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[0] -> Emotions: []
# Segment: -Alixo7euuU[1], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[1] -> Emotions: []
# Segment: -Alixo7euuU[2], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[2] -> Emotions: ['happy']
# Segment: -Alixo7euuU[3], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[3] -> Emotions: []
# Segment: -Alixo7euuU[4], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[4] -> Emotions: []
# Segment: -Alixo7euuU[5], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[5] -> Emotions: []
# Segment: -Alixo7euuU[6], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[6] -> Emotions: []
# Segment: -Alixo7euuU[7], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[7] -> Emotions: []
# Segment: -Alixo7euuU[8], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[8] -> Emotions: []
# Segment: -Alixo7euuU[9], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[9] -> Emotions: []
# Segment: -Alixo7euuU[10], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[10] -> Emotions: []
# Segment: -Alixo7euuU[11], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[11] -> Emotions: ['sad']
# Segment: -Alixo7euuU[12], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[12] -> Emotions: ['happy']
# Segment: -Alixo7euuU[13], Emotion Data Shape: (1, 7)
# Segment: -Alixo7euuU[13] -> Emotions: []
# Segment: -Eqdz5y4pEY[0], Emotion Data Shape: (1, 7)
# Segment: -Eqdz5y4pEY[0] -> Emotions: []
# Segment: -HeZS2-Prhc[0], Emotion Data Shape: (1, 7)
# Segment: -HeZS2-Prhc[0] -> Emotions: []
# Segment: -HeZS2-Prhc[1], Emotion Data Shape: (1, 7)
# Segment: -HeZS2-Prhc[1] -> Emotions: []
# Segment: -HeZS2-Prhc[2], Emotion Data Shape: (1, 7)
# Segment: -HeZS2-Prhc[2] -> Emotions: ['happy']
# Segment: -HeZS2-Prhc[3], Emotion Data Shape: (1, 7)
# Segment: -HeZS2-Prhc[3] -> Emotions: []
# Segment: -HvKLjmsO5U[0], Emotion Data Shape: (1, 7)
# Segment: -HvKLjmsO5U[0] -> Emotions: []
# Segment: -HvKLjmsO5U[1], Emotion Data Shape: (1, 7)
# Segment: -HvKLjmsO5U[1] -> Emotions: ['happy', 'sad']
# Segment: -HwX2H8Z4hY[0], Emotion Data Shape: (1, 7)
# Segment: -HwX2H8Z4hY[0] -> Emotions: []
# Segment: -HwX2H8Z4hY[1], Emotion Data Shape: (1, 7)
# Segment: -HwX2H8Z4hY[1] -> Emotions: []
# Segment: -HwX2H8Z4hY[2], Emotion Data Shape: (1, 7)
# Segment: -HwX2H8Z4hY[2] -> Emotions: []
# Segment: -HwX2H8Z4hY[3], Emotion Data Shape: (1, 7)
# Segment: -HwX2H8Z4hY[3] -> Emotions: []
# Segment: -HwX2H8Z4hY[4], Emotion Data Shape: (1, 7)
# Segment: -HwX2H8Z4hY[4] -> Emotions: []
# Segment: -HwX2H8Z4hY[5], Emotion Data Shape: (1, 7)
# Segment: -HwX2H8Z4hY[5] -> Emotions: []
# Segment: -HwX2H8Z4hY[6], Emotion Data Shape: (1, 7)
# Segment: -HwX2H8Z4hY[6] -> Emotions: []
# Segment: -HwX2H8Z4hY[7], Emotion Data Shape: (1, 7)
# Segment: -HwX2H8Z4hY[7] -> Emotions: []
# Segment: -HwX2H8Z4hY[8], Emotion Data Shape: (1, 7)
# Segment: -HwX2H8Z4hY[8] -> Emotions: []
# Segment: -HwX2H8Z4hY[9], Emotion Data Shape: (1, 7)
# Segment: -HwX2H8Z4hY[9] -> Emotions: []
# Segment: -IUUR2yyNbw[0], Emotion Data Shape: (1, 7)
# Segment: -IUUR2yyNbw[0] -> Emotions: []
# Segment: -IUUR2yyNbw[1], Emotion Data Shape: (1, 7)
# Segment: -IUUR2yyNbw[1] -> Emotions: ['sad']
# Segment: -IUUR2yyNbw[2], Emotion Data Shape: (1, 7)
# Segment: -IUUR2yyNbw[2] -> Emotions: []
# Segment: -IUUR2yyNbw[3], Emotion Data Shape: (1, 7)
# Segment: -IUUR2yyNbw[3] -> Emotions: []
# Segment: -IUUR2yyNbw[4], Emotion Data Shape: (1, 7)
# Segment: -IUUR2yyNbw[4] -> Emotions: []
# Segment: -I_e4mIh0yE[0], Emotion Data Shape: (1, 7)
# Segment: -I_e4mIh0yE[0] -> Emotions: []
# Segment: -I_e4mIh0yE[1], Emotion Data Shape: (1, 7)
# Segment: -I_e4mIh0yE[1] -> Emotions: []
# Segment: -I_e4mIh0yE[2], Emotion Data Shape: (1, 7)
# Segment: -I_e4mIh0yE[2] -> Emotions: []
# Segment: -IqSFQePnpU[0], Emotion Data Shape: (1, 7)
# Segment: -IqSFQePnpU[0] -> Emotions: []
# Segment: -KCahx2qBOI[0], Emotion Data Shape: (1, 7)
# Segment: -KCahx2qBOI[0] -> Emotions: []
# Segment: -KCahx2qBOI[1], Emotion Data Shape: (1, 7)
# Segment: -KCahx2qBOI[1] -> Emotions: []
# Segment: -KCahx2qBOI[2], Emotion Data Shape: (1, 7)
# Segment: -KCahx2qBOI[2] -> Emotions: []
# Segment: -LnuDPiuuZw[0], Emotion Data Shape: (1, 7)
# Segment: -LnuDPiuuZw[0] -> Emotions: []
# Segment: -LnuDPiuuZw[1], Emotion Data Shape: (1, 7)
# Segment: -LnuDPiuuZw[1] -> Emotions: []
# Segment: -LnuDPiuuZw[2], Emotion Data Shape: (1, 7)
# Segment: -LnuDPiuuZw[2] -> Emotions: ['happy', 'sad']
# Segment: -LnuDPiuuZw[3], Emotion Data Shape: (1, 7)
# Segment: -LnuDPiuuZw[3] -> Emotions: []
# Segment: -MeTTeMJBNc[0], Emotion Data Shape: (1, 7)
# Segment: -MeTTeMJBNc[0] -> Emotions: []
# Segment: -MeTTeMJBNc[1], Emotion Data Shape: (1, 7)
# Segment: -MeTTeMJBNc[1] -> Emotions: []
# Segment: -MeTTeMJBNc[2], Emotion Data Shape: (1, 7)
# Segment: -MeTTeMJBNc[2] -> Emotions: []
# Segment: -MeTTeMJBNc[3], Emotion Data Shape: (1, 7)
# Segment: -MeTTeMJBNc[3] -> Emotions: []
# Segment: -NFrJFQijFE[0], Emotion Data Shape: (1, 7)
# Segment: -NFrJFQijFE[0] -> Emotions: []
# Segment: -NFrJFQijFE[1], Emotion Data Shape: (1, 7)
# Segment: -NFrJFQijFE[1] -> Emotions: []
# Segment: -NFrJFQijFE[2], Emotion Data Shape: (1, 7)
# Segment: -NFrJFQijFE[2] -> Emotions: []
# Segment: -NFrJFQijFE[3], Emotion Data Shape: (1, 7)
# Segment: -NFrJFQijFE[3] -> Emotions: []
# Segment: -RfYyzHpjk4[0], Emotion Data Shape: (1, 7)
# Segment: -RfYyzHpjk4[0] -> Emotions: ['sad']
# Segment: -RfYyzHpjk4[1], Emotion Data Shape: (1, 7)
# Segment: -RfYyzHpjk4[1] -> Emotions: []
# Segment: -RfYyzHpjk4[2], Emotion Data Shape: (1, 7)
# Segment: -RfYyzHpjk4[2] -> Emotions: []
# Segment: -RfYyzHpjk4[3], Emotion Data Shape: (1, 7)
# Segment: -RfYyzHpjk4[3] -> Emotions: []
# Segment: -RpZEe4w4fY[0], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[0] -> Emotions: []
# Segment: -RpZEe4w4fY[1], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[1] -> Emotions: ['surprise']
# Segment: -RpZEe4w4fY[2], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[2] -> Emotions: []
# Segment: -RpZEe4w4fY[3], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[3] -> Emotions: []
# Segment: -RpZEe4w4fY[4], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[4] -> Emotions: []
# Segment: -RpZEe4w4fY[5], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[5] -> Emotions: ['surprise']
# Segment: -RpZEe4w4fY[6], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[6] -> Emotions: []
# Segment: -RpZEe4w4fY[7], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[7] -> Emotions: []
# Segment: -RpZEe4w4fY[8], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[8] -> Emotions: []
# Segment: -RpZEe4w4fY[9], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[9] -> Emotions: []
# Segment: -RpZEe4w4fY[10], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[10] -> Emotions: []
# Segment: -RpZEe4w4fY[11], Emotion Data Shape: (1, 7)
# Segment: -RpZEe4w4fY[11] -> Emotions: []
# Segment: -SYSVSQnTnA[0], Emotion Data Shape: (1, 7)
# Segment: -SYSVSQnTnA[0] -> Emotions: []
# Segment: -SYSVSQnTnA[1], Emotion Data Shape: (1, 7)
# Segment: -SYSVSQnTnA[1] -> Emotions: []
# Segment: -SYSVSQnTnA[2], Emotion Data Shape: (1, 7)
# Segment: -SYSVSQnTnA[2] -> Emotions: ['happy']
# Segment: -THoVjtIkeU[0], Emotion Data Shape: (1, 7)
# Segment: -THoVjtIkeU[0] -> Emotions: []
# Segment: -THoVjtIkeU[1], Emotion Data Shape: (1, 7)
# Segment: -THoVjtIkeU[1] -> Emotions: []
# Segment: -THoVjtIkeU[2], Emotion Data Shape: (1, 7)
# Segment: -THoVjtIkeU[2] -> Emotions: []
# Segment: -THoVjtIkeU[3], Emotion Data Shape: (1, 7)
# Segment: -THoVjtIkeU[3] -> Emotions: []
# Segment: -THoVjtIkeU[4], Emotion Data Shape: (1, 7)
# Segment: -THoVjtIkeU[4] -> Emotions: []
# Segment: -THoVjtIkeU[5], Emotion Data Shape: (1, 7)
# Segment: -THoVjtIkeU[5] -> Emotions: ['sad']
# Segment: -THoVjtIkeU[6], Emotion Data Shape: (1, 7)
# Segment: -THoVjtIkeU[6] -> Emotions: ['sad']
# Segment: -THoVjtIkeU[7], Emotion Data Shape: (1, 7)
# Segment: -THoVjtIkeU[7] -> Emotions: ['happy']
# Segment: -UUCSKoHeMA[0], Emotion Data Shape: (1, 7)
# Segment: -UUCSKoHeMA[0] -> Emotions: []
# Segment: -UUCSKoHeMA[1], Emotion Data Shape: (1, 7)
# Segment: -UUCSKoHeMA[1] -> Emotions: []
# Segment: -UUCSKoHeMA[2], Emotion Data Shape: (1, 7)
# Segment: -UUCSKoHeMA[2] -> Emotions: []
# Segment: -UUCSKoHeMA[3], Emotion Data Shape: (1, 7)
# Segment: -UUCSKoHeMA[3] -> Emotions: []
# Segment: -UacrmKiTn4[0], Emotion Data Shape: (1, 7)
# Segment: -UacrmKiTn4[0] -> Emotions: []
# Segment: -UacrmKiTn4[1], Emotion Data Shape: (1, 7)
# Segment: -UacrmKiTn4[1] -> Emotions: []
# Segment: -UacrmKiTn4[2], Emotion Data Shape: (1, 7)
# Segment: -UacrmKiTn4[2] -> Emotions: []
# Segment: -UacrmKiTn4[3], Emotion Data Shape: (1, 7)
# Segment: -UacrmKiTn4[3] -> Emotions: []
# Segment: -UuX1xuaiiE[0], Emotion Data Shape: (1, 7)
# Segment: -UuX1xuaiiE[0] -> Emotions: []
# Segment: -UuX1xuaiiE[1], Emotion Data Shape: (1, 7)
# Segment: -UuX1xuaiiE[1] -> Emotions: ['sad']
# Segment: -UuX1xuaiiE[2], Emotion Data Shape: (1, 7)
# Segment: -UuX1xuaiiE[2] -> Emotions: []
# Segment: -UuX1xuaiiE[3], Emotion Data Shape: (1, 7)
# Segment: -UuX1xuaiiE[3] -> Emotions: []
# Segment: -UuX1xuaiiE[4], Emotion Data Shape: (1, 7)
# Segment: -UuX1xuaiiE[4] -> Emotions: []
# Segment: -UuX1xuaiiE[5], Emotion Data Shape: (1, 7)
# Segment: -UuX1xuaiiE[5] -> Emotions: ['happy']
# Segment: -UuX1xuaiiE[6], Emotion Data Shape: (1, 7)
# Segment: -UuX1xuaiiE[6] -> Emotions: []
# Segment: -UuX1xuaiiE[7], Emotion Data Shape: (1, 7)
# Segment: -UuX1xuaiiE[7] -> Emotions: ['fear']
# Segment: -UuX1xuaiiE[8], Emotion Data Shape: (1, 7)
# Segment: -UuX1xuaiiE[8] -> Emotions: []
# Segment: -UuX1xuaiiE[9], Emotion Data Shape: (1, 7)
# Segment: -UuX1xuaiiE[9] -> Emotions: []
# Segment: -VmheDA92mM[0], Emotion Data Shape: (1, 7)
# Segment: -VmheDA92mM[0] -> Emotions: ['surprise', 'fear']
# Segment: -VmheDA92mM[1], Emotion Data Shape: (1, 7)
# Segment: -VmheDA92mM[1] -> Emotions: ['surprise']
# Segment: -VmheDA92mM[2], Emotion Data Shape: (1, 7)
# Segment: -VmheDA92mM[2] -> Emotions: []
# Segment: -VmheDA92mM[3], Emotion Data Shape: (1, 7)
# Segment: -VmheDA92mM[3] -> Emotions: []
# Segment: -VmheDA92mM[4], Emotion Data Shape: (1, 7)
# Segment: -VmheDA92mM[4] -> Emotions: ['surprise']
# Segment: -WXXTNIJcVM[0], Emotion Data Shape: (1, 7)
# Segment: -WXXTNIJcVM[0] -> Emotions: ['sad']
# Segment: -WXXTNIJcVM[1], Emotion Data Shape: (1, 7)
# Segment: -WXXTNIJcVM[1] -> Emotions: []
# Segment: -WXXTNIJcVM[2], Emotion Data Shape: (1, 7)
# Segment: -WXXTNIJcVM[2] -> Emotions: []
# Segment: -WXXTNIJcVM[3], Emotion Data Shape: (1, 7)
# Segment: -WXXTNIJcVM[3] -> Emotions: []
# Segment: -WXXTNIJcVM[4], Emotion Data Shape: (1, 7)
# Segment: -WXXTNIJcVM[4] -> Emotions: []
# Segment: -ZgjBOA1Yhw[0], Emotion Data Shape: (1, 7)
# Segment: -ZgjBOA1Yhw[0] -> Emotions: []
# Segment: -ZgjBOA1Yhw[1], Emotion Data Shape: (1, 7)
# Segment: -ZgjBOA1Yhw[1] -> Emotions: []
# Segment: -ZgjBOA1Yhw[2], Emotion Data Shape: (1, 7)
# Segment: -ZgjBOA1Yhw[2] -> Emotions: []
# Segment: -ZgjBOA1Yhw[3], Emotion Data Shape: (1, 7)
# Segment: -ZgjBOA1Yhw[3] -> Emotions: []
# Segment: -ZgjBOA1Yhw[4], Emotion Data Shape: (1, 7)
# Segment: -ZgjBOA1Yhw[4] -> Emotions: []
# Segment: -ZgjBOA1Yhw[5], Emotion Data Shape: (1, 7)
# Segment: -ZgjBOA1Yhw[5] -> Emotions: []
# Segment: -a55Q6RWvTA[0], Emotion Data Shape: (1, 7)
# Segment: -a55Q6RWvTA[0] -> Emotions: []
# Segment: -aNfi7CP8vM[0], Emotion Data Shape: (1, 7)
# Segment: -aNfi7CP8vM[0] -> Emotions: []
# Segment: -aNfi7CP8vM[1], Emotion Data Shape: (1, 7)
# Segment: -aNfi7CP8vM[1] -> Emotions: []
# Segment: -aqamKhZ1Ec[0], Emotion Data Shape: (1, 7)
# Segment: -aqamKhZ1Ec[0] -> Emotions: ['anger']
# Segment: -aqamKhZ1Ec[1], Emotion Data Shape: (1, 7)
# Segment: -aqamKhZ1Ec[1] -> Emotions: []
# Segment: -aqamKhZ1Ec[2], Emotion Data Shape: (1, 7)
# Segment: -aqamKhZ1Ec[2] -> Emotions: ['sad']
# Segment: -bl5PfNIYrk[0], Emotion Data Shape: (1, 7)
# Segment: -bl5PfNIYrk[0] -> Emotions: ['happy']
# Segment: -bl5PfNIYrk[1], Emotion Data Shape: (1, 7)
# Segment: -bl5PfNIYrk[1] -> Emotions: []
# Segment: -bl5PfNIYrk[2], Emotion Data Shape: (1, 7)
# Segment: -bl5PfNIYrk[2] -> Emotions: ['sad']
# Segment: -bl5PfNIYrk[3], Emotion Data Shape: (1, 7)
# Segment: -bl5PfNIYrk[3] -> Emotions: ['happy']
# Segment: -bl5PfNIYrk[4], Emotion Data Shape: (1, 7)
# Segment: -bl5PfNIYrk[4] -> Emotions: []
# Segment: -bl5PfNIYrk[5], Emotion Data Shape: (1, 7)
# Segment: -bl5PfNIYrk[5] -> Emotions: []
# Segment: -bl5PfNIYrk[6], Emotion Data Shape: (1, 7)
# Segment: -bl5PfNIYrk[6] -> Emotions: []
# Segment: -cEhr0cQcDM[0], Emotion Data Shape: (1, 7)
# Segment: -cEhr0cQcDM[0] -> Emotions: []
# Segment: -cEhr0cQcDM[1], Emotion Data Shape: (1, 7)
# Segment: -cEhr0cQcDM[1] -> Emotions: []
# Segment: -cmk6cfUeMs[0], Emotion Data Shape: (1, 7)
# Segment: -cmk6cfUeMs[0] -> Emotions: []
# Segment: -cmk6cfUeMs[1], Emotion Data Shape: (1, 7)
# Segment: -cmk6cfUeMs[1] -> Emotions: []
# Segment: -dZ1TCboxcQ[0], Emotion Data Shape: (1, 7)
# Segment: -dZ1TCboxcQ[0] -> Emotions: []
# Segment: -dZ1TCboxcQ[1], Emotion Data Shape: (1, 7)
# Segment: -dZ1TCboxcQ[1] -> Emotions: []
# Segment: -dZ1TCboxcQ[2], Emotion Data Shape: (1, 7)
# Segment: -dZ1TCboxcQ[2] -> Emotions: ['anger']
# Segment: -dZ1TCboxcQ[3], Emotion Data Shape: (1, 7)
# Segment: -dZ1TCboxcQ[3] -> Emotions: ['anger', 'surprise']
# Segment: -dxfTGcXJoc[0], Emotion Data Shape: (1, 7)
# Segment: -dxfTGcXJoc[0] -> Emotions: ['happy', 'surprise']
# Segment: -dxfTGcXJoc[1], Emotion Data Shape: (1, 7)
# Segment: -dxfTGcXJoc[1] -> Emotions: []
# Segment: -dxfTGcXJoc[2], Emotion Data Shape: (1, 7)
# Segment: -dxfTGcXJoc[2] -> Emotions: ['surprise']
# Segment: -dxfTGcXJoc[3], Emotion Data Shape: (1, 7)
# Segment: -dxfTGcXJoc[3] -> Emotions: ['surprise']
# Segment: -dxfTGcXJoc[4], Emotion Data Shape: (1, 7)
# Segment: -dxfTGcXJoc[4] -> Emotions: []
# Segment: -dxfTGcXJoc[5], Emotion Data Shape: (1, 7)
# Segment: -dxfTGcXJoc[5] -> Emotions: []
# Segment: -dxfTGcXJoc[6], Emotion Data Shape: (1, 7)
# Segment: -dxfTGcXJoc[6] -> Emotions: []
# Segment: -dxfTGcXJoc[7], Emotion Data Shape: (1, 7)
# Segment: -dxfTGcXJoc[7] -> Emotions: ['happy', 'surprise']
# Segment: -egA8-b7-3M[0], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[0] -> Emotions: []
# Segment: -egA8-b7-3M[1], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[1] -> Emotions: []
# Segment: -egA8-b7-3M[2], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[2] -> Emotions: []
# Segment: -egA8-b7-3M[3], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[3] -> Emotions: []
# Segment: -egA8-b7-3M[4], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[4] -> Emotions: []
# Segment: -egA8-b7-3M[5], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[5] -> Emotions: []
# Segment: -egA8-b7-3M[6], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[6] -> Emotions: ['happy']
# Segment: -egA8-b7-3M[7], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[7] -> Emotions: []
# Segment: -egA8-b7-3M[8], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[8] -> Emotions: []
# Segment: -egA8-b7-3M[9], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[9] -> Emotions: []
# Segment: -egA8-b7-3M[10], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[10] -> Emotions: []
# Segment: -egA8-b7-3M[11], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[11] -> Emotions: []
# Segment: -egA8-b7-3M[12], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[12] -> Emotions: []
# Segment: -egA8-b7-3M[13], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[13] -> Emotions: []
# Segment: -egA8-b7-3M[14], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[14] -> Emotions: []
# Segment: -egA8-b7-3M[15], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[15] -> Emotions: []
# Segment: -egA8-b7-3M[16], Emotion Data Shape: (1, 7)
# Segment: -egA8-b7-3M[16] -> Emotions: []
# Segment: -hPfPhUIzfA[0], Emotion Data Shape: (1, 7)
# Segment: -hPfPhUIzfA[0] -> Emotions: []
# Segment: -hPfPhUIzfA[1], Emotion Data Shape: (1, 7)
# Segment: -hPfPhUIzfA[1] -> Emotions: []
# Segment: -hPfPhUIzfA[2], Emotion Data Shape: (1, 7)
# Segment: -hPfPhUIzfA[2] -> Emotions: []
# Segment: -hPfPhUIzfA[3], Emotion Data Shape: (1, 7)
# Segment: -hPfPhUIzfA[3] -> Emotions: ['happy']
# Segment: -hnBHBN8p5A[0], Emotion Data Shape: (1, 7)
# Segment: -hnBHBN8p5A[0] -> Emotions: []
# Segment: -hnBHBN8p5A[1], Emotion Data Shape: (1, 7)
# Segment: -hnBHBN8p5A[1] -> Emotions: ['happy']
# Segment: -hnBHBN8p5A[2], Emotion Data Shape: (1, 7)
# Segment: -hnBHBN8p5A[2] -> Emotions: []
# Segment: -hnBHBN8p5A[3], Emotion Data Shape: (1, 7)
# Segment: -hnBHBN8p5A[3] -> Emotions: []
# Segment: -hnBHBN8p5A[4], Emotion Data Shape: (1, 7)
# Segment: -hnBHBN8p5A[4] -> Emotions: ['sad']
# Segment: -iRBcNs9oI8[0], Emotion Data Shape: (1, 7)
# Segment: -iRBcNs9oI8[0] -> Emotions: []
# Segment: -iRBcNs9oI8[1], Emotion Data Shape: (1, 7)
# Segment: -iRBcNs9oI8[1] -> Emotions: []
# Segment: -iRBcNs9oI8[2], Emotion Data Shape: (1, 7)
# Segment: -iRBcNs9oI8[2] -> Emotions: []
# Segment: -iRBcNs9oI8[3], Emotion Data Shape: (1, 7)
# Segment: -iRBcNs9oI8[3] -> Emotions: ['happy']
# Segment: -iRBcNs9oI8[4], Emotion Data Shape: (1, 7)
# Segment: -iRBcNs9oI8[4] -> Emotions: []
# Segment: -iRBcNs9oI8[5], Emotion Data Shape: (1, 7)
# Segment: -iRBcNs9oI8[5] -> Emotions: []
# Segment: -iRBcNs9oI8[6], Emotion Data Shape: (1, 7)
# Segment: -iRBcNs9oI8[6] -> Emotions: []
# Segment: -iRBcNs9oI8[7], Emotion Data Shape: (1, 7)
# Segment: -iRBcNs9oI8[7] -> Emotions: []
# Segment: -iRBcNs9oI8[8], Emotion Data Shape: (1, 7)
# Segment: -iRBcNs9oI8[8] -> Emotions: ['happy']
# Segment: -iRBcNs9oI8[9], Emotion Data Shape: (1, 7)
# Segment: -iRBcNs9oI8[9] -> Emotions: []
# Segment: -l_53IwQoj0[0], Emotion Data Shape: (1, 7)
# Segment: -l_53IwQoj0[0] -> Emotions: []
# Segment: -lqc32Zpr7M[0], Emotion Data Shape: (1, 7)
# Segment: -lqc32Zpr7M[0] -> Emotions: []
# Segment: -lqc32Zpr7M[1], Emotion Data Shape: (1, 7)
# Segment: -lqc32Zpr7M[1] -> Emotions: []
# Segment: -lqc32Zpr7M[2], Emotion Data Shape: (1, 7)
# Segment: -lqc32Zpr7M[2] -> Emotions: []
# Segment: -lqc32Zpr7M[3], Emotion Data Shape: (1, 7)
# Segment: -lqc32Zpr7M[3] -> Emotions: []
# Segment: -lzEya4AM_4[0], Emotion Data Shape: (1, 7)
# Segment: -lzEya4AM_4[0] -> Emotions: []
# Segment: -lzEya4AM_4[1], Emotion Data Shape: (1, 7)
# Segment: -lzEya4AM_4[1] -> Emotions: []
# Segment: -lzEya4AM_4[2], Emotion Data Shape: (1, 7)
# Segment: -lzEya4AM_4[2] -> Emotions: []
# Segment: -lzEya4AM_4[3], Emotion Data Shape: (1, 7)
# Segment: -lzEya4AM_4[3] -> Emotions: ['surprise']
# Segment: -lzEya4AM_4[4], Emotion Data Shape: (1, 7)
# Segment: -lzEya4AM_4[4] -> Emotions: ['surprise']
# Segment: -m9KtvCk_L8[0], Emotion Data Shape: (1, 7)
# Segment: -m9KtvCk_L8[0] -> Emotions: []
# Segment: -m9KtvCk_L8[1], Emotion Data Shape: (1, 7)
# Segment: -m9KtvCk_L8[1] -> Emotions: []
# Segment: -m9KtvCk_L8[2], Emotion Data Shape: (1, 7)
# Segment: -m9KtvCk_L8[2] -> Emotions: []
# Segment: -mJ2ud6oKI8[0], Emotion Data Shape: (1, 7)
# Segment: -mJ2ud6oKI8[0] -> Emotions: ['anger']
# Segment: -mJ2ud6oKI8[1], Emotion Data Shape: (1, 7)
# Segment: -mJ2ud6oKI8[1] -> Emotions: []
# Segment: -mJ2ud6oKI8[2], Emotion Data Shape: (1, 7)
# Segment: -mJ2ud6oKI8[2] -> Emotions: []
# Segment: -mJ2ud6oKI8[3], Emotion Data Shape: (1, 7)
# Segment: -mJ2ud6oKI8[3] -> Emotions: []
# Segment: -mJ2ud6oKI8[4], Emotion Data Shape: (1, 7)
# Segment: -mJ2ud6oKI8[4] -> Emotions: []
# Segment: -mJ2ud6oKI8[5], Emotion Data Shape: (1, 7)
# Segment: -mJ2ud6oKI8[5] -> Emotions: []
# Segment: -mJ2ud6oKI8[6], Emotion Data Shape: (1, 7)
# Segment: -mJ2ud6oKI8[6] -> Emotions: []
# Segment: -mJ2ud6oKI8[7], Emotion Data Shape: (1, 7)
# Segment: -mJ2ud6oKI8[7] -> Emotions: []
# Segment: -mJ2ud6oKI8[8], Emotion Data Shape: (1, 7)
# Segment: -mJ2ud6oKI8[8] -> Emotions: []
# Segment: -mqbVkbCndg[0], Emotion Data Shape: (1, 7)
# Segment: -mqbVkbCndg[0] -> Emotions: []
# Segment: -mqbVkbCndg[1], Emotion Data Shape: (1, 7)
# Segment: -mqbVkbCndg[1] -> Emotions: []
# Segment: -mqbVkbCndg[2], Emotion Data Shape: (1, 7)
# Segment: -mqbVkbCndg[2] -> Emotions: []
# Segment: -o_667Ny7RM[0], Emotion Data Shape: (1, 7)
# Segment: -o_667Ny7RM[0] -> Emotions: ['happy', 'sad']
# Segment: -qDkUB0GgYY[0], Emotion Data Shape: (1, 7)
# Segment: -qDkUB0GgYY[0] -> Emotions: []
# Segment: -qDkUB0GgYY[1], Emotion Data Shape: (1, 7)
# Segment: -qDkUB0GgYY[1] -> Emotions: []
# Segment: -qDkUB0GgYY[2], Emotion Data Shape: (1, 7)
# Segment: -qDkUB0GgYY[2] -> Emotions: []
# Segment: -qMhGeJkp5o[0], Emotion Data Shape: (1, 7)
# Segment: -qMhGeJkp5o[0] -> Emotions: []
# Segment: -qMhGeJkp5o[1], Emotion Data Shape: (1, 7)
# Segment: -qMhGeJkp5o[1] -> Emotions: []
# Segment: -qMhGeJkp5o[2], Emotion Data Shape: (1, 7)
# Segment: -qMhGeJkp5o[2] -> Emotions: ['happy']
# Segment: -qMhGeJkp5o[3], Emotion Data Shape: (1, 7)
# Segment: -qMhGeJkp5o[3] -> Emotions: []
# Segment: -qMhGeJkp5o[4], Emotion Data Shape: (1, 7)
# Segment: -qMhGeJkp5o[4] -> Emotions: []
# Segment: -qMhGeJkp5o[5], Emotion Data Shape: (1, 7)
# Segment: -qMhGeJkp5o[5] -> Emotions: []
# Segment: -qMhGeJkp5o[6], Emotion Data Shape: (1, 7)
# Segment: -qMhGeJkp5o[6] -> Emotions: ['surprise']
# Segment: -qMhGeJkp5o[7], Emotion Data Shape: (1, 7)
# Segment: -qMhGeJkp5o[7] -> Emotions: []
# Segment: -qMhGeJkp5o[8], Emotion Data Shape: (1, 7)
# Segment: -qMhGeJkp5o[8] -> Emotions: ['surprise']
# Segment: -ri04Z7vwnc[0], Emotion Data Shape: (1, 7)
# Segment: -ri04Z7vwnc[0] -> Emotions: []
# Segment: -ri04Z7vwnc[1], Emotion Data Shape: (1, 7)
# Segment: -ri04Z7vwnc[1] -> Emotions: []
# Segment: -ri04Z7vwnc[2], Emotion Data Shape: (1, 7)
# Segment: -ri04Z7vwnc[2] -> Emotions: []
# Segment: -ri04Z7vwnc[3], Emotion Data Shape: (1, 7)
# Segment: -ri04Z7vwnc[3] -> Emotions: ['anger']
# Segment: -ri04Z7vwnc[4], Emotion Data Shape: (1, 7)
# Segment: -ri04Z7vwnc[4] -> Emotions: ['happy', 'anger']
# Segment: -ri04Z7vwnc[5], Emotion Data Shape: (1, 7)
# Segment: -ri04Z7vwnc[5] -> Emotions: []
# Segment: -rxZxtG0xmY[0], Emotion Data Shape: (1, 7)
# Segment: -rxZxtG0xmY[0] -> Emotions: ['anger']
# Segment: -rxZxtG0xmY[1], Emotion Data Shape: (1, 7)
# Segment: -rxZxtG0xmY[1] -> Emotions: []
# Segment: -s9qJ7ATP7w[0], Emotion Data Shape: (1, 7)
# Segment: -s9qJ7ATP7w[0] -> Emotions: []
# Segment: -s9qJ7ATP7w[1], Emotion Data Shape: (1, 7)
# Segment: -s9qJ7ATP7w[1] -> Emotions: []
# Segment: -s9qJ7ATP7w[2], Emotion Data Shape: (1, 7)
# Segment: -s9qJ7ATP7w[2] -> Emotions: []
# Segment: -s9qJ7ATP7w[3], Emotion Data Shape: (1, 7)
# Segment: -s9qJ7ATP7w[3] -> Emotions: ['sad']
# Segment: -s9qJ7ATP7w[4], Emotion Data Shape: (1, 7)
# Segment: -s9qJ7ATP7w[4] -> Emotions: ['sad']
# Segment: -s9qJ7ATP7w[5], Emotion Data Shape: (1, 7)
# Segment: -s9qJ7ATP7w[5] -> Emotions: []
# Segment: -s9qJ7ATP7w[6], Emotion Data Shape: (1, 7)
# Segment: -s9qJ7ATP7w[6] -> Emotions: []
# Segment: -s9qJ7ATP7w[7], Emotion Data Shape: (1, 7)
# Segment: -s9qJ7ATP7w[7] -> Emotions: ['happy']
# Segment: -s9qJ7ATP7w[8], Emotion Data Shape: (1, 7)
# Segment: -s9qJ7ATP7w[8] -> Emotions: []
# Segment: -s9qJ7ATP7w[9], Emotion Data Shape: (1, 7)
# Segment: -s9qJ7ATP7w[9] -> Emotions: ['happy']
# Segment: -t217m2on-s[0], Emotion Data Shape: (1, 7)
# Segment: -t217m2on-s[0] -> Emotions: []
# Segment: -t217m2on-s[1], Emotion Data Shape: (1, 7)
# Segment: -t217m2on-s[1] -> Emotions: []
# Segment: -tANM6ETl_M[0], Emotion Data Shape: (1, 7)
# Segment: -tANM6ETl_M[0] -> Emotions: []
# Segment: -tANM6ETl_M[1], Emotion Data Shape: (1, 7)
# Segment: -tANM6ETl_M[1] -> Emotions: []
# Segment: -tANM6ETl_M[2], Emotion Data Shape: (1, 7)
# Segment: -tANM6ETl_M[2] -> Emotions: []
# Segment: -tPCytz4rww[0], Emotion Data Shape: (1, 7)
# Segment: -tPCytz4rww[0] -> Emotions: []
# Segment: -tPCytz4rww[1], Emotion Data Shape: (1, 7)
# Segment: -tPCytz4rww[1] -> Emotions: []
# Segment: -tPCytz4rww[2], Emotion Data Shape: (1, 7)
# Segment: -tPCytz4rww[2] -> Emotions: []
# Segment: -tPCytz4rww[3], Emotion Data Shape: (1, 7)
# Segment: -tPCytz4rww[3] -> Emotions: []
# Segment: -tPCytz4rww[4], Emotion Data Shape: (1, 7)
# Segment: -tPCytz4rww[4] -> Emotions: []
# Segment: -tPCytz4rww[5], Emotion Data Shape: (1, 7)
# Segment: -tPCytz4rww[5] -> Emotions: []
# Segment: -uywlfIYOS8[0], Emotion Data Shape: (1, 7)
# Segment: -uywlfIYOS8[0] -> Emotions: ['sad']
# Segment: -uywlfIYOS8[1], Emotion Data Shape: (1, 7)
# Segment: -uywlfIYOS8[1] -> Emotions: []
# Segment: -vxjVxOeScU[0], Emotion Data Shape: (1, 7)
# Segment: -vxjVxOeScU[0] -> Emotions: ['sad']
# Segment: -vxjVxOeScU[1], Emotion Data Shape: (1, 7)
# Segment: -vxjVxOeScU[1] -> Emotions: ['happy', 'sad']
# Segment: -vxjVxOeScU[2], Emotion Data Shape: (1, 7)
# Segment: -vxjVxOeScU[2] -> Emotions: ['sad']
# Segment: -wMB_hJL-3o[0], Emotion Data Shape: (1, 7)
# Segment: -wMB_hJL-3o[0] -> Emotions: ['happy']
# Segment: -wMB_hJL-3o[1], Emotion Data Shape: (1, 7)
# Segment: -wMB_hJL-3o[1] -> Emotions: []
# Segment: -wMB_hJL-3o[2], Emotion Data Shape: (1, 7)
# Segment: -wMB_hJL-3o[2] -> Emotions: []
# Segment: -wMB_hJL-3o[3], Emotion Data Shape: (1, 7)
# Segment: -wMB_hJL-3o[3] -> Emotions: []
# Segment: -wdUIwjDMfg[0], Emotion Data Shape: (1, 7)
# Segment: -wdUIwjDMfg[0] -> Emotions: []
# Segment: -wny0OAz3g8[0], Emotion Data Shape: (1, 7)
# Segment: -wny0OAz3g8[0] -> Emotions: []
# Segment: -wny0OAz3g8[1], Emotion Data Shape: (1, 7)
# Segment: -wny0OAz3g8[1] -> Emotions: []
# Segment: -wny0OAz3g8[2], Emotion Data Shape: (1, 7)
# Segment: -wny0OAz3g8[2] -> Emotions: []
# Segment: -wny0OAz3g8[3], Emotion Data Shape: (1, 7)
# Segment: -wny0OAz3g8[3] -> Emotions: ['fear']
# Segment: -wny0OAz3g8[4], Emotion Data Shape: (1, 7)
# Segment: -wny0OAz3g8[4] -> Emotions: []
# Segment: -wny0OAz3g8[5], Emotion Data Shape: (1, 7)
# Segment: -wny0OAz3g8[5] -> Emotions: ['happy']
# Segment: -wny0OAz3g8[6], Emotion Data Shape: (1, 7)
# Segment: -wny0OAz3g8[6] -> Emotions: []
# Segment: -wny0OAz3g8[7], Emotion Data Shape: (1, 7)
# Segment: -wny0OAz3g8[7] -> Emotions: []
# Segment: -wny0OAz3g8[8], Emotion Data Shape: (1, 7)
# Segment: -wny0OAz3g8[8] -> Emotions: ['sad']
# Segment: -yRb-Jum7EQ[0], Emotion Data Shape: (1, 7)
# Segment: -yRb-Jum7EQ[0] -> Emotions: []
# Segment: -yRb-Jum7EQ[1], Emotion Data Shape: (1, 7)
# Segment: -yRb-Jum7EQ[1] -> Emotions: ['anger']
# Segment: -yRb-Jum7EQ[2], Emotion Data Shape: (1, 7)
# Segment: -yRb-Jum7EQ[2] -> Emotions: []
# Segment: -yRb-Jum7EQ[3], Emotion Data Shape: (1, 7)
# Segment: -yRb-Jum7EQ[3] -> Emotions: []
# Segment: -yRb-Jum7EQ[4], Emotion Data Shape: (1, 7)
# Segment: -yRb-Jum7EQ[4] -> Emotions: ['surprise']
# Segment: 03X1FwF6udc[0], Emotion Data Shape: (1, 7)
# Segment: 03X1FwF6udc[0] -> Emotions: []
# Segment: 03X1FwF6udc[1], Emotion Data Shape: (1, 7)
# Segment: 03X1FwF6udc[1] -> Emotions: []
# Segment: 03X1FwF6udc[2], Emotion Data Shape: (1, 7)
# Segment: 03X1FwF6udc[2] -> Emotions: []
# Segment: 03X1FwF6udc[3], Emotion Data Shape: (1, 7)
# Segment: 03X1FwF6udc[3] -> Emotions: []
# Segment: 03X1FwF6udc[4], Emotion Data Shape: (1, 7)
# Segment: 03X1FwF6udc[4] -> Emotions: []
# Segment: 03X1FwF6udc[5], Emotion Data Shape: (1, 7)
# Segment: 03X1FwF6udc[5] -> Emotions: []
# Segment: 03X1FwF6udc[6], Emotion Data Shape: (1, 7)
# Segment: 03X1FwF6udc[6] -> Emotions: []
# Segment: 06st0Ez_E_I[0], Emotion Data Shape: (1, 7)
# Segment: 06st0Ez_E_I[0] -> Emotions: []
# Segment: 06st0Ez_E_I[1], Emotion Data Shape: (1, 7)
# Segment: 06st0Ez_E_I[1] -> Emotions: []
# Segment: 07Z16yRBFUQ[0], Emotion Data Shape: (1, 7)
# Segment: 07Z16yRBFUQ[0] -> Emotions: []
# Segment: 07Z16yRBFUQ[1], Emotion Data Shape: (1, 7)
# Segment: 07Z16yRBFUQ[1] -> Emotions: []
# Segment: 07Z16yRBFUQ[2], Emotion Data Shape: (1, 7)
# Segment: 07Z16yRBFUQ[2] -> Emotions: []
# Segment: 08d4NTXkSxw[0], Emotion Data Shape: (1, 7)
# Segment: 08d4NTXkSxw[0] -> Emotions: []
# Segment: 08d4NTXkSxw[1], Emotion Data Shape: (1, 7)
# Segment: 08d4NTXkSxw[1] -> Emotions: []
# Segment: 08d4NTXkSxw[2], Emotion Data Shape: (1, 7)
# Segment: 08d4NTXkSxw[2] -> Emotions: []
# Segment: 08d4NTXkSxw[3], Emotion Data Shape: (1, 7)
# Segment: 08d4NTXkSxw[3] -> Emotions: []
# Segment: 0AA-wmk8WdA[0], Emotion Data Shape: (1, 7)
# Segment: 0AA-wmk8WdA[0] -> Emotions: []
# Segment: 0AA-wmk8WdA[1], Emotion Data Shape: (1, 7)
# Segment: 0AA-wmk8WdA[1] -> Emotions: ['happy']
# Segment: 0AkGtPzl7D8[0], Emotion Data Shape: (1, 7)
# Segment: 0AkGtPzl7D8[0] -> Emotions: []
# Segment: 0BVed2nBq1g[0], Emotion Data Shape: (1, 7)
# Segment: 0BVed2nBq1g[0] -> Emotions: []
# Segment: 0BVed2nBq1g[1], Emotion Data Shape: (1, 7)
# Segment: 0BVed2nBq1g[1] -> Emotions: ['sad']
# Segment: 0BVed2nBq1g[2], Emotion Data Shape: (1, 7)
# Segment: 0BVed2nBq1g[2] -> Emotions: []
# Segment: 0BVed2nBq1g[3], Emotion Data Shape: (1, 7)
# Segment: 0BVed2nBq1g[3] -> Emotions: []
# Segment: 0BVed2nBq1g[4], Emotion Data Shape: (1, 7)
# Segment: 0BVed2nBq1g[4] -> Emotions: ['sad', 'disgust']
# Segment: 0BVed2nBq1g[5], Emotion Data Shape: (1, 7)
# Segment: 0BVed2nBq1g[5] -> Emotions: []
# Segment: 0BVed2nBq1g[6], Emotion Data Shape: (1, 7)
# Segment: 0BVed2nBq1g[6] -> Emotions: []
# Segment: 0DBfvvIVmqY[0], Emotion Data Shape: (1, 7)
# Segment: 0DBfvvIVmqY[0] -> Emotions: ['happy']
# Segment: 0DBfvvIVmqY[1], Emotion Data Shape: (1, 7)
# Segment: 0DBfvvIVmqY[1] -> Emotions: ['sad']
# Segment: 0DBfvvIVmqY[2], Emotion Data Shape: (1, 7)
# Segment: 0DBfvvIVmqY[2] -> Emotions: []
# Segment: 0DBfvvIVmqY[3], Emotion Data Shape: (1, 7)
# Segment: 0DBfvvIVmqY[3] -> Emotions: []
# Segment: 0DBfvvIVmqY[4], Emotion Data Shape: (1, 7)
# Segment: 0DBfvvIVmqY[4] -> Emotions: []
# Segment: 0DBfvvIVmqY[5], Emotion Data Shape: (1, 7)
# Segment: 0DBfvvIVmqY[5] -> Emotions: []
# Segment: 0DBfvvIVmqY[6], Emotion Data Shape: (1, 7)
# Segment: 0DBfvvIVmqY[6] -> Emotions: []
# Segment: 0DBfvvIVmqY[7], Emotion Data Shape: (1, 7)
# Segment: 0DBfvvIVmqY[7] -> Emotions: ['sad']
# Segment: 0DBfvvIVmqY[8], Emotion Data Shape: (1, 7)
# Segment: 0DBfvvIVmqY[8] -> Emotions: []
# Segment: 0DBfvvIVmqY[9], Emotion Data Shape: (1, 7)
# Segment: 0DBfvvIVmqY[9] -> Emotions: []
# Segment: 0DBfvvIVmqY[10], Emotion Data Shape: (1, 7)
# Segment: 0DBfvvIVmqY[10] -> Emotions: ['sad']
# Segment: 0EAAfLCQabY[0], Emotion Data Shape: (1, 7)
# Segment: 0EAAfLCQabY[0] -> Emotions: []
# Segment: 0EAAfLCQabY[1], Emotion Data Shape: (1, 7)
# Segment: 0EAAfLCQabY[1] -> Emotions: []
# Segment: 0EAAfLCQabY[2], Emotion Data Shape: (1, 7)
# Segment: 0EAAfLCQabY[2] -> Emotions: []
# Segment: 0EphpADwdPg[0], Emotion Data Shape: (1, 7)
# Segment: 0EphpADwdPg[0] -> Emotions: []
# Segment: 0EphpADwdPg[1], Emotion Data Shape: (1, 7)
# Segment: 0EphpADwdPg[1] -> Emotions: []
# Segment: 0EphpADwdPg[2], Emotion Data Shape: (1, 7)
# Segment: 0EphpADwdPg[2] -> Emotions: []
# Segment: 0EphpADwdPg[3], Emotion Data Shape: (1, 7)
# Segment: 0EphpADwdPg[3] -> Emotions: []
# Segment: 0EphpADwdPg[4], Emotion Data Shape: (1, 7)
# Segment: 0EphpADwdPg[4] -> Emotions: []
# Segment: 0EphpADwdPg[5], Emotion Data Shape: (1, 7)
# Segment: 0EphpADwdPg[5] -> Emotions: ['happy']
# Segment: 0FA32bEZ6xI[0], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[0] -> Emotions: []
# Segment: 0FA32bEZ6xI[1], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[1] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[2], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[2] -> Emotions: ['happy']
# Segment: 0FA32bEZ6xI[3], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[3] -> Emotions: []
# Segment: 0FA32bEZ6xI[4], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[4] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[5], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[5] -> Emotions: []
# Segment: 0FA32bEZ6xI[6], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[6] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[7], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[7] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[8], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[8] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[9], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[9] -> Emotions: []
# Segment: 0FA32bEZ6xI[10], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[10] -> Emotions: []
# Segment: 0FA32bEZ6xI[11], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[11] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[12], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[12] -> Emotions: []
# Segment: 0FA32bEZ6xI[13], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[13] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[14], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[14] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[15], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[15] -> Emotions: []
# Segment: 0FA32bEZ6xI[16], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[16] -> Emotions: []
# Segment: 0FA32bEZ6xI[17], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[17] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[18], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[18] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[19], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[19] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[20], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[20] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[21], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[21] -> Emotions: []
# Segment: 0FA32bEZ6xI[22], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[22] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[23], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[23] -> Emotions: []
# Segment: 0FA32bEZ6xI[24], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[24] -> Emotions: []
# Segment: 0FA32bEZ6xI[25], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[25] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[26], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[26] -> Emotions: ['surprise']
# Segment: 0FA32bEZ6xI[27], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[27] -> Emotions: []
# Segment: 0FA32bEZ6xI[28], Emotion Data Shape: (1, 7)
# Segment: 0FA32bEZ6xI[28] -> Emotions: []
# Segment: 0Fqav67TDEw[0], Emotion Data Shape: (1, 7)
# Segment: 0Fqav67TDEw[0] -> Emotions: []
# Segment: 0JaYazphxfM[0], Emotion Data Shape: (1, 7)
# Segment: 0JaYazphxfM[0] -> Emotions: ['happy']
# Segment: 0JaYazphxfM[1], Emotion Data Shape: (1, 7)
# Segment: 0JaYazphxfM[1] -> Emotions: []
# Segment: 0JuRmhhgMw8[0], Emotion Data Shape: (1, 7)
# Segment: 0JuRmhhgMw8[0] -> Emotions: ['happy']
# Segment: 0JuRmhhgMw8[1], Emotion Data Shape: (1, 7)
# Segment: 0JuRmhhgMw8[1] -> Emotions: []
# Segment: 0JuRmhhgMw8[2], Emotion Data Shape: (1, 7)
# Segment: 0JuRmhhgMw8[2] -> Emotions: []
# Segment: 0JuRmhhgMw8[3], Emotion Data Shape: (1, 7)
# Segment: 0JuRmhhgMw8[3] -> Emotions: []
# Segment: 0JuRmhhgMw8[4], Emotion Data Shape: (1, 7)
# Segment: 0JuRmhhgMw8[4] -> Emotions: []
# Segment: 0JuRmhhgMw8[5], Emotion Data Shape: (1, 7)
# Segment: 0JuRmhhgMw8[5] -> Emotions: []
# Segment: 0JuRmhhgMw8[6], Emotion Data Shape: (1, 7)
# Segment: 0JuRmhhgMw8[6] -> Emotions: []
# Segment: 0JuRmhhgMw8[7], Emotion Data Shape: (1, 7)
# Segment: 0JuRmhhgMw8[7] -> Emotions: []
# Segment: 0K7dCp80n9c[0], Emotion Data Shape: (1, 7)
# Segment: 0K7dCp80n9c[0] -> Emotions: []
# Segment: 0K7dCp80n9c[1], Emotion Data Shape: (1, 7)
# Segment: 0K7dCp80n9c[1] -> Emotions: []
# Segment: 0K7dCp80n9c[2], Emotion Data Shape: (1, 7)
# Segment: 0K7dCp80n9c[2] -> Emotions: []
# Segment: 0K7dCp80n9c[3], Emotion Data Shape: (1, 7)
# Segment: 0K7dCp80n9c[3] -> Emotions: []
# Segment: 0K7dCp80n9c[4], Emotion Data Shape: (1, 7)
# Segment: 0K7dCp80n9c[4] -> Emotions: []
# Segment: 0K7dCp80n9c[5], Emotion Data Shape: (1, 7)
# Segment: 0K7dCp80n9c[5] -> Emotions: []
# Segment: 0K7dCp80n9c[6], Emotion Data Shape: (1, 7)
# Segment: 0K7dCp80n9c[6] -> Emotions: []
# Segment: 0K7dCp80n9c[7], Emotion Data Shape: (1, 7)
# Segment: 0K7dCp80n9c[7] -> Emotions: ['happy']
# Segment: 0OC3wf9x3zQ[0], Emotion Data Shape: (1, 7)
# Segment: 0OC3wf9x3zQ[0] -> Emotions: []
# Segment: 0OC3wf9x3zQ[1], Emotion Data Shape: (1, 7)
# Segment: 0OC3wf9x3zQ[1] -> Emotions: []
# Segment: 0OC3wf9x3zQ[2], Emotion Data Shape: (1, 7)
# Segment: 0OC3wf9x3zQ[2] -> Emotions: []
# Segment: 0OC3wf9x3zQ[3], Emotion Data Shape: (1, 7)
# Segment: 0OC3wf9x3zQ[3] -> Emotions: []
# Segment: 0OC3wf9x3zQ[4], Emotion Data Shape: (1, 7)
# Segment: 0OC3wf9x3zQ[4] -> Emotions: []
# Segment: 0OC3wf9x3zQ[5], Emotion Data Shape: (1, 7)
# Segment: 0OC3wf9x3zQ[5] -> Emotions: []
# Segment: 0OC3wf9x3zQ[6], Emotion Data Shape: (1, 7)
# Segment: 0OC3wf9x3zQ[6] -> Emotions: []
# Segment: 0OC3wf9x3zQ[7], Emotion Data Shape: (1, 7)
# Segment: 0OC3wf9x3zQ[7] -> Emotions: []
# Segment: 0OC3wf9x3zQ[8], Emotion Data Shape: (1, 7)
# Segment: 0OC3wf9x3zQ[8] -> Emotions: []
# Segment: 0OC3wf9x3zQ[9], Emotion Data Shape: (1, 7)
# Segment: 0OC3wf9x3zQ[9] -> Emotions: []
# Segment: 0OC3wf9x3zQ[10], Emotion Data Shape: (1, 7)
# Segment: 0OC3wf9x3zQ[10] -> Emotions: []
# Segment: 0OXeN3MhFeA[0], Emotion Data Shape: (1, 7)
# Segment: 0OXeN3MhFeA[0] -> Emotions: ['happy']
# Segment: 0OXeN3MhFeA[1], Emotion Data Shape: (1, 7)
# Segment: 0OXeN3MhFeA[1] -> Emotions: []
# Segment: 0OXeN3MhFeA[2], Emotion Data Shape: (1, 7)
# Segment: 0OXeN3MhFeA[2] -> Emotions: []
# Segment: 0OXeN3MhFeA[3], Emotion Data Shape: (1, 7)
# Segment: 0OXeN3MhFeA[3] -> Emotions: []
# Segment: 0OXeN3MhFeA[4], Emotion Data Shape: (1, 7)
# Segment: 0OXeN3MhFeA[4] -> Emotions: []
# Segment: 0OXeN3MhFeA[5], Emotion Data Shape: (1, 7)
# Segment: 0OXeN3MhFeA[5] -> Emotions: []
# Segment: 0OXeN3MhFeA[6], Emotion Data Shape: (1, 7)
# Segment: 0OXeN3MhFeA[6] -> Emotions: []
# Segment: 0PlQc98SccA[0], Emotion Data Shape: (1, 7)
# Segment: 0PlQc98SccA[0] -> Emotions: []
# Segment: 0PlQc98SccA[1], Emotion Data Shape: (1, 7)
# Segment: 0PlQc98SccA[1] -> Emotions: ['sad']
# Segment: 0PlQc98SccA[2], Emotion Data Shape: (1, 7)
# Segment: 0PlQc98SccA[2] -> Emotions: []
# Segment: 0SfejBuLgFo[0], Emotion Data Shape: (1, 7)
# Segment: 0SfejBuLgFo[0] -> Emotions: []
# Segment: 0SfejBuLgFo[1], Emotion Data Shape: (1, 7)
# Segment: 0SfejBuLgFo[1] -> Emotions: ['anger']
# Segment: 0SfejBuLgFo[2], Emotion Data Shape: (1, 7)
# Segment: 0SfejBuLgFo[2] -> Emotions: []
# Segment: 0SfejBuLgFo[3], Emotion Data Shape: (1, 7)
# Segment: 0SfejBuLgFo[3] -> Emotions: []
# Segment: 0SfejBuLgFo[4], Emotion Data Shape: (1, 7)
# Segment: 0SfejBuLgFo[4] -> Emotions: []
# Segment: 0SfejBuLgFo[5], Emotion Data Shape: (1, 7)
# Segment: 0SfejBuLgFo[5] -> Emotions: []
# Segment: 0SfejBuLgFo[6], Emotion Data Shape: (1, 7)
# Segment: 0SfejBuLgFo[6] -> Emotions: []
# Segment: 0SfejBuLgFo[7], Emotion Data Shape: (1, 7)
# Segment: 0SfejBuLgFo[7] -> Emotions: []
# Segment: 0Svu5BldR5A[0], Emotion Data Shape: (1, 7)
# Segment: 0Svu5BldR5A[0] -> Emotions: []
# Segment: 0Svu5BldR5A[1], Emotion Data Shape: (1, 7)
# Segment: 0Svu5BldR5A[1] -> Emotions: []
# Segment: 0W4WsjhDgUI[0], Emotion Data Shape: (1, 7)
# Segment: 0W4WsjhDgUI[0] -> Emotions: []
# Segment: 0WIwQgH4lKg[0], Emotion Data Shape: (1, 7)
# Segment: 0WIwQgH4lKg[0] -> Emotions: []
# Segment: 0WIwQgH4lKg[1], Emotion Data Shape: (1, 7)
# Segment: 0WIwQgH4lKg[1] -> Emotions: []
# Segment: 0WIwQgH4lKg[2], Emotion Data Shape: (1, 7)
# Segment: 0WIwQgH4lKg[2] -> Emotions: []
# Segment: 0WIwQgH4lKg[3], Emotion Data Shape: (1, 7)
# Segment: 0WIwQgH4lKg[3] -> Emotions: []
# Segment: 0WIwQgH4lKg[4], Emotion Data Shape: (1, 7)
# Segment: 0WIwQgH4lKg[4] -> Emotions: []
# Segment: 0WIwQgH4lKg[5], Emotion Data Shape: (1, 7)
# Segment: 0WIwQgH4lKg[5] -> Emotions: []
# Segment: 0Xs8wJrAmxs[0], Emotion Data Shape: (1, 7)
# Segment: 0Xs8wJrAmxs[0] -> Emotions: ['sad', 'anger']
# Segment: 0Xs8wJrAmxs[1], Emotion Data Shape: (1, 7)
# Segment: 0Xs8wJrAmxs[1] -> Emotions: []
# Segment: 0Xs8wJrAmxs[2], Emotion Data Shape: (1, 7)
# Segment: 0Xs8wJrAmxs[2] -> Emotions: []
# Segment: 0Xs8wJrAmxs[3], Emotion Data Shape: (1, 7)
# Segment: 0Xs8wJrAmxs[3] -> Emotions: []
# Segment: 0YdYFtVdlWE[0], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[0] -> Emotions: []
# Segment: 0YdYFtVdlWE[1], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[1] -> Emotions: []
# Segment: 0YdYFtVdlWE[2], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[2] -> Emotions: []
# Segment: 0YdYFtVdlWE[3], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[3] -> Emotions: []
# Segment: 0YdYFtVdlWE[4], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[4] -> Emotions: ['sad']
# Segment: 0YdYFtVdlWE[5], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[5] -> Emotions: ['sad']
# Segment: 0YdYFtVdlWE[6], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[6] -> Emotions: []
# Segment: 0YdYFtVdlWE[7], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[7] -> Emotions: []
# Segment: 0YdYFtVdlWE[8], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[8] -> Emotions: []
# Segment: 0YdYFtVdlWE[9], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[9] -> Emotions: []
# Segment: 0YdYFtVdlWE[10], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[10] -> Emotions: []
# Segment: 0YdYFtVdlWE[11], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[11] -> Emotions: []
# Segment: 0YdYFtVdlWE[12], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[12] -> Emotions: []
# Segment: 0YdYFtVdlWE[13], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[13] -> Emotions: []
# Segment: 0YdYFtVdlWE[14], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[14] -> Emotions: []
# Segment: 0YdYFtVdlWE[15], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[15] -> Emotions: []
# Segment: 0YdYFtVdlWE[16], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[16] -> Emotions: ['happy']
# Segment: 0YdYFtVdlWE[17], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[17] -> Emotions: []
# Segment: 0YdYFtVdlWE[18], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[18] -> Emotions: []
# Segment: 0YdYFtVdlWE[19], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[19] -> Emotions: []
# Segment: 0YdYFtVdlWE[20], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[20] -> Emotions: []
# Segment: 0YdYFtVdlWE[21], Emotion Data Shape: (1, 7)
# Segment: 0YdYFtVdlWE[21] -> Emotions: []
# Segment: 0YiAKqU36KE[0], Emotion Data Shape: (1, 7)
# Segment: 0YiAKqU36KE[0] -> Emotions: []
# Segment: 0YiAKqU36KE[1], Emotion Data Shape: (1, 7)
# Segment: 0YiAKqU36KE[1] -> Emotions: ['sad']
# Segment: 0YiAKqU36KE[2], Emotion Data Shape: (1, 7)
# Segment: 0YiAKqU36KE[2] -> Emotions: []
# Segment: 0YiAKqU36KE[3], Emotion Data Shape: (1, 7)
# Segment: 0YiAKqU36KE[3] -> Emotions: ['happy', 'sad']
# Segment: 0YiAKqU36KE[4], Emotion Data Shape: (1, 7)
# Segment: 0YiAKqU36KE[4] -> Emotions: []
# Segment: 0YiAKqU36KE[5], Emotion Data Shape: (1, 7)
# Segment: 0YiAKqU36KE[5] -> Emotions: []
# Segment: 0YiAKqU36KE[6], Emotion Data Shape: (1, 7)
# Segment: 0YiAKqU36KE[6] -> Emotions: []
# Segment: 0YiAKqU36KE[7], Emotion Data Shape: (1, 7)
# Segment: 0YiAKqU36KE[7] -> Emotions: []
# Segment: 0YiAKqU36KE[8], Emotion Data Shape: (1, 7)
# Segment: 0YiAKqU36KE[8] -> Emotions: []
# Segment: 0bsTzavb-AE[0], Emotion Data Shape: (1, 7)
# Segment: 0bsTzavb-AE[0] -> Emotions: []
# Segment: 0bsTzavb-AE[1], Emotion Data Shape: (1, 7)
# Segment: 0bsTzavb-AE[1] -> Emotions: []
# Segment: 0bsTzavb-AE[2], Emotion Data Shape: (1, 7)
# Segment: 0bsTzavb-AE[2] -> Emotions: []
# Segment: 0bsTzavb-AE[3], Emotion Data Shape: (1, 7)
# Segment: 0bsTzavb-AE[3] -> Emotions: []
# Segment: 0bxhZ-LIfZY[0], Emotion Data Shape: (1, 7)
# Segment: 0bxhZ-LIfZY[0] -> Emotions: []
# Segment: 0bxhZ-LIfZY[1], Emotion Data Shape: (1, 7)
# Segment: 0bxhZ-LIfZY[1] -> Emotions: []
# Segment: 0cBmQ_ItVUc[0], Emotion Data Shape: (1, 7)
# Segment: 0cBmQ_ItVUc[0] -> Emotions: []
# Segment: 0cBmQ_ItVUc[1], Emotion Data Shape: (1, 7)
# Segment: 0cBmQ_ItVUc[1] -> Emotions: []
# Segment: 0cBmQ_ItVUc[2], Emotion Data Shape: (1, 7)
# Segment: 0cBmQ_ItVUc[2] -> Emotions: ['fear']
# Segment: 0cBmQ_ItVUc[3], Emotion Data Shape: (1, 7)
# Segment: 0cBmQ_ItVUc[3] -> Emotions: ['happy']
# Segment: 0cBmQ_ItVUc[4], Emotion Data Shape: (1, 7)
# Segment: 0cBmQ_ItVUc[4] -> Emotions: []
# Segment: 0cBmQ_ItVUc[5], Emotion Data Shape: (1, 7)
# Segment: 0cBmQ_ItVUc[5] -> Emotions: []
# Segment: 0cBmQ_ItVUc[6], Emotion Data Shape: (1, 7)
# Segment: 0cBmQ_ItVUc[6] -> Emotions: []
# Segment: 0cBmQ_ItVUc[7], Emotion Data Shape: (1, 7)
# Segment: 0cBmQ_ItVUc[7] -> Emotions: []
# Segment: 0cBmQ_ItVUc[8], Emotion Data Shape: (1, 7)
# Segment: 0cBmQ_ItVUc[8] -> Emotions: []
# Segment: 0cBmQ_ItVUc[9], Emotion Data Shape: (1, 7)
# Segment: 0cBmQ_ItVUc[9] -> Emotions: ['surprise']
# Segment: 0cBmQ_ItVUc[10], Emotion Data Shape: (1, 7)
# Segment: 0cBmQ_ItVUc[10] -> Emotions: ['surprise']
# Segment: 0eTibWQdO5M[0], Emotion Data Shape: (1, 7)
# Segment: 0eTibWQdO5M[0] -> Emotions: []
# Segment: 0hCOCt6fWas[0], Emotion Data Shape: (1, 7)
# Segment: 0hCOCt6fWas[0] -> Emotions: []
# Segment: 0hCOCt6fWas[1], Emotion Data Shape: (1, 7)
# Segment: 0hCOCt6fWas[1] -> Emotions: []
# Segment: 0hCOCt6fWas[2], Emotion Data Shape: (1, 7)
# Segment: 0hCOCt6fWas[2] -> Emotions: []
# Segment: 0hCOCt6fWas[3], Emotion Data Shape: (1, 7)
# Segment: 0hCOCt6fWas[3] -> Emotions: []
# Segment: 0hCOCt6fWas[4], Emotion Data Shape: (1, 7)
# Segment: 0hCOCt6fWas[4] -> Emotions: []
# Segment: 0hCOCt6fWas[5], Emotion Data Shape: (1, 7)
# Segment: 0hCOCt6fWas[5] -> Emotions: []
# Segment: 0hCihQ5Kep0[0], Emotion Data Shape: (1, 7)
# Segment: 0hCihQ5Kep0[0] -> Emotions: []
# Segment: 0hCihQ5Kep0[1], Emotion Data Shape: (1, 7)
# Segment: 0hCihQ5Kep0[1] -> Emotions: []
# Segment: 0hCihQ5Kep0[2], Emotion Data Shape: (1, 7)
# Segment: 0hCihQ5Kep0[2] -> Emotions: []
# Segment: 0jtdrsmVzYQ[0], Emotion Data Shape: (1, 7)
# Segment: 0jtdrsmVzYQ[0] -> Emotions: []
# Segment: 0jtdrsmVzYQ[1], Emotion Data Shape: (1, 7)
# Segment: 0jtdrsmVzYQ[1] -> Emotions: []
# Segment: 0mXv97u2OCM[0], Emotion Data Shape: (1, 7)
# Segment: 0mXv97u2OCM[0] -> Emotions: []
# Segment: 0mXv97u2OCM[1], Emotion Data Shape: (1, 7)
# Segment: 0mXv97u2OCM[1] -> Emotions: []
# Segment: 0nJrksJ7azM[0], Emotion Data Shape: (1, 7)
# Segment: 0nJrksJ7azM[0] -> Emotions: []
# Segment: 0nJrksJ7azM[1], Emotion Data Shape: (1, 7)
# Segment: 0nJrksJ7azM[1] -> Emotions: []
# Segment: 0nJrksJ7azM[2], Emotion Data Shape: (1, 7)
# Segment: 0nJrksJ7azM[2] -> Emotions: []
# Segment: 0nJrksJ7azM[3], Emotion Data Shape: (1, 7)
# Segment: 0nJrksJ7azM[3] -> Emotions: ['sad']
# Segment: 0nJrksJ7azM[4], Emotion Data Shape: (1, 7)
# Segment: 0nJrksJ7azM[4] -> Emotions: ['sad']
# Segment: 0nJrksJ7azM[5], Emotion Data Shape: (1, 7)
# Segment: 0nJrksJ7azM[5] -> Emotions: []
# Segment: 0p9XKC_J3hU[0], Emotion Data Shape: (1, 7)
# Segment: 0p9XKC_J3hU[0] -> Emotions: []
# Segment: 0r8KVXUCV6c[0], Emotion Data Shape: (1, 7)
# Segment: 0r8KVXUCV6c[0] -> Emotions: ['sad']
# Segment: 0r8KVXUCV6c[1], Emotion Data Shape: (1, 7)
# Segment: 0r8KVXUCV6c[1] -> Emotions: []
# Segment: 0r8KVXUCV6c[2], Emotion Data Shape: (1, 7)
# Segment: 0r8KVXUCV6c[2] -> Emotions: []
# ...
# Segment: zR62DCEMWgs[4], Emotion Data Shape: (1, 7)
# Segment: zR62DCEMWgs[4] -> Emotions: ['sad']
# Segment: zShw-E-yBqU[0], Emotion Data Shape: (1, 7)
# Segment: zShw-E-yBqU[0] -> Emotions: []
# Segment: zShw-E-yBqU[1], Emotion Data Shape: (1, 7)
# Segment: zShw-E-yBqU[1] -> Emotions: ['happy']
# Segment: zShw-E-yBqU[2], Emotion Data Shape: (1, 7)
# Segment: zShw-E-yBqU[2] -> Emotions: []
# Segment: zShw-E-yBqU[3], Emotion Data Shape: (1, 7)
# Segment: zShw-E-yBqU[3] -> Emotions: []
# Segment: zShw-E-yBqU[4], Emotion Data Shape: (1, 7)
# Segment: zShw-E-yBqU[4] -> Emotions: []
# Segment: zU2_X9lIcUM[0], Emotion Data Shape: (1, 7)
# Segment: zU2_X9lIcUM[0] -> Emotions: []
# Segment: zU2_X9lIcUM[1], Emotion Data Shape: (1, 7)
# Segment: zU2_X9lIcUM[1] -> Emotions: []
# Segment: zU2_X9lIcUM[2], Emotion Data Shape: (1, 7)
# Segment: zU2_X9lIcUM[2] -> Emotions: []
# Segment: zU2_X9lIcUM[3], Emotion Data Shape: (1, 7)
# Segment: zU2_X9lIcUM[3] -> Emotions: []
# Segment: zURYO3k8lW0[0], Emotion Data Shape: (1, 7)
# Segment: zURYO3k8lW0[0] -> Emotions: []
# Segment: zURYO3k8lW0[1], Emotion Data Shape: (1, 7)
# Segment: zURYO3k8lW0[1] -> Emotions: ['happy']
# Segment: zURYO3k8lW0[2], Emotion Data Shape: (1, 7)
# Segment: zURYO3k8lW0[2] -> Emotions: []
# Segment: zWfDRPy4lXQ[0], Emotion Data Shape: (1, 7)
# Segment: zWfDRPy4lXQ[0] -> Emotions: ['sad']
# Segment: zaTyjiyrHnk[0], Emotion Data Shape: (1, 7)
# Segment: zaTyjiyrHnk[0] -> Emotions: []
# Segment: zaTyjiyrHnk[1], Emotion Data Shape: (1, 7)
# Segment: zaTyjiyrHnk[1] -> Emotions: []
# Segment: zaTyjiyrHnk[2], Emotion Data Shape: (1, 7)
# Segment: zaTyjiyrHnk[2] -> Emotions: []
# Segment: zaTyjiyrHnk[3], Emotion Data Shape: (1, 7)
# Segment: zaTyjiyrHnk[3] -> Emotions: []
# Segment: zaTyjiyrHnk[4], Emotion Data Shape: (1, 7)
# Segment: zaTyjiyrHnk[4] -> Emotions: []
# Segment: zcG0ms7CdBE[0], Emotion Data Shape: (1, 7)
# Segment: zcG0ms7CdBE[0] -> Emotions: []
# Segment: zcG0ms7CdBE[1], Emotion Data Shape: (1, 7)
# Segment: zcG0ms7CdBE[1] -> Emotions: []
# Segment: zeQKU2L173M[0], Emotion Data Shape: (1, 7)
# Segment: zeQKU2L173M[0] -> Emotions: []
# Segment: zeQKU2L173M[1], Emotion Data Shape: (1, 7)
# Segment: zeQKU2L173M[1] -> Emotions: ['surprise']
# Segment: zeQKU2L173M[2], Emotion Data Shape: (1, 7)
# Segment: zeQKU2L173M[2] -> Emotions: ['happy', 'surprise']
# Segment: zeQKU2L173M[3], Emotion Data Shape: (1, 7)
# Segment: zeQKU2L173M[3] -> Emotions: []
# Segment: zeQKU2L173M[4], Emotion Data Shape: (1, 7)
# Segment: zeQKU2L173M[4] -> Emotions: []
# Segment: zeQKU2L173M[5], Emotion Data Shape: (1, 7)
# Segment: zeQKU2L173M[5] -> Emotions: []
# Segment: zeQKU2L173M[6], Emotion Data Shape: (1, 7)
# Segment: zeQKU2L173M[6] -> Emotions: []
# Segment: zfZUOvZZTuk[0], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[0] -> Emotions: []
# Segment: zfZUOvZZTuk[1], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[1] -> Emotions: []
# Segment: zfZUOvZZTuk[2], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[2] -> Emotions: []
# Segment: zfZUOvZZTuk[3], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[3] -> Emotions: []
# Segment: zfZUOvZZTuk[4], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[4] -> Emotions: []
# Segment: zfZUOvZZTuk[5], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[5] -> Emotions: []
# Segment: zfZUOvZZTuk[6], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[6] -> Emotions: []
# Segment: zfZUOvZZTuk[7], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[7] -> Emotions: []
# Segment: zfZUOvZZTuk[8], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[8] -> Emotions: []
# Segment: zfZUOvZZTuk[9], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[9] -> Emotions: []
# Segment: zfZUOvZZTuk[10], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[10] -> Emotions: []
# Segment: zfZUOvZZTuk[11], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[11] -> Emotions: []
# Segment: zfZUOvZZTuk[12], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[12] -> Emotions: []
# Segment: zfZUOvZZTuk[13], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[13] -> Emotions: []
# Segment: zfZUOvZZTuk[14], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[14] -> Emotions: []
# Segment: zfZUOvZZTuk[15], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[15] -> Emotions: []
# Segment: zfZUOvZZTuk[16], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[16] -> Emotions: []
# Segment: zfZUOvZZTuk[17], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[17] -> Emotions: ['happy']
# Segment: zfZUOvZZTuk[18], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[18] -> Emotions: []
# Segment: zfZUOvZZTuk[19], Emotion Data Shape: (1, 7)
# Segment: zfZUOvZZTuk[19] -> Emotions: []
# Segment: zg-ZIxVsBbQ[0], Emotion Data Shape: (1, 7)
# Segment: zg-ZIxVsBbQ[0] -> Emotions: []
# Segment: zhE_68GMJIk[0], Emotion Data Shape: (1, 7)
# Segment: zhE_68GMJIk[0] -> Emotions: []
# Segment: zhE_68GMJIk[1], Emotion Data Shape: (1, 7)
# Segment: zhE_68GMJIk[1] -> Emotions: []
# Segment: zhE_68GMJIk[2], Emotion Data Shape: (1, 7)
# Segment: zhE_68GMJIk[2] -> Emotions: []
# Segment: zhNksSReaQk[0], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[0] -> Emotions: []
# Segment: zhNksSReaQk[1], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[1] -> Emotions: []
# Segment: zhNksSReaQk[2], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[2] -> Emotions: []
# Segment: zhNksSReaQk[3], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[3] -> Emotions: ['happy']
# Segment: zhNksSReaQk[4], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[4] -> Emotions: []
# Segment: zhNksSReaQk[5], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[5] -> Emotions: []
# Segment: zhNksSReaQk[6], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[6] -> Emotions: []
# Segment: zhNksSReaQk[7], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[7] -> Emotions: []
# Segment: zhNksSReaQk[8], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[8] -> Emotions: []
# Segment: zhNksSReaQk[9], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[9] -> Emotions: []
# Segment: zhNksSReaQk[10], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[10] -> Emotions: []
# Segment: zhNksSReaQk[11], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[11] -> Emotions: []
# Segment: zhNksSReaQk[12], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[12] -> Emotions: []
# Segment: zhNksSReaQk[13], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[13] -> Emotions: []
# Segment: zhNksSReaQk[14], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[14] -> Emotions: []
# Segment: zhNksSReaQk[15], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[15] -> Emotions: []
# Segment: zhNksSReaQk[16], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[16] -> Emotions: []
# Segment: zhNksSReaQk[17], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[17] -> Emotions: []
# Segment: zhNksSReaQk[18], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[18] -> Emotions: []
# Segment: zhNksSReaQk[19], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[19] -> Emotions: []
# Segment: zhNksSReaQk[20], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[20] -> Emotions: []
# Segment: zhNksSReaQk[21], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[21] -> Emotions: []
# Segment: zhNksSReaQk[22], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[22] -> Emotions: []
# Segment: zhNksSReaQk[23], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[23] -> Emotions: []
# Segment: zhNksSReaQk[24], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[24] -> Emotions: []
# Segment: zhNksSReaQk[25], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[25] -> Emotions: []
# Segment: zhNksSReaQk[26], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[26] -> Emotions: []
# Segment: zhNksSReaQk[27], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[27] -> Emotions: []
# Segment: zhNksSReaQk[28], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[28] -> Emotions: []
# Segment: zhNksSReaQk[29], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[29] -> Emotions: []
# Segment: zhNksSReaQk[30], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[30] -> Emotions: []
# Segment: zhNksSReaQk[31], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[31] -> Emotions: ['happy']
# Segment: zhNksSReaQk[32], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[32] -> Emotions: []
# Segment: zhNksSReaQk[33], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[33] -> Emotions: []
# Segment: zhNksSReaQk[34], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[34] -> Emotions: []
# Segment: zhNksSReaQk[35], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[35] -> Emotions: []
# Segment: zhNksSReaQk[36], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[36] -> Emotions: []
# Segment: zhNksSReaQk[37], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[37] -> Emotions: []
# Segment: zhNksSReaQk[38], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[38] -> Emotions: []
# Segment: zhNksSReaQk[39], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[39] -> Emotions: []
# Segment: zhNksSReaQk[40], Emotion Data Shape: (1, 7)
# Segment: zhNksSReaQk[40] -> Emotions: []
# Segment: zi0a6r52ZlY[0], Emotion Data Shape: (1, 7)
# Segment: zi0a6r52ZlY[0] -> Emotions: []
# Segment: zi0a6r52ZlY[1], Emotion Data Shape: (1, 7)
# Segment: zi0a6r52ZlY[1] -> Emotions: ['sad']
# Segment: zj4PzGtFwJM[0], Emotion Data Shape: (1, 7)
# Segment: zj4PzGtFwJM[0] -> Emotions: ['sad']
# Segment: zj4PzGtFwJM[1], Emotion Data Shape: (1, 7)
# Segment: zj4PzGtFwJM[1] -> Emotions: []
# Segment: zj4PzGtFwJM[2], Emotion Data Shape: (1, 7)
# Segment: zj4PzGtFwJM[2] -> Emotions: []
# Segment: zj4PzGtFwJM[3], Emotion Data Shape: (1, 7)
# Segment: zj4PzGtFwJM[3] -> Emotions: []
# Segment: zj4PzGtFwJM[4], Emotion Data Shape: (1, 7)
# Segment: zj4PzGtFwJM[4] -> Emotions: []
# Segment: zjYEBwXGD8I[0], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[0] -> Emotions: []
# Segment: zjYEBwXGD8I[1], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[1] -> Emotions: []
# Segment: zjYEBwXGD8I[2], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[2] -> Emotions: []
# Segment: zjYEBwXGD8I[3], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[3] -> Emotions: []
# Segment: zjYEBwXGD8I[4], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[4] -> Emotions: []
# Segment: zjYEBwXGD8I[5], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[5] -> Emotions: []
# Segment: zjYEBwXGD8I[6], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[6] -> Emotions: ['happy']
# Segment: zjYEBwXGD8I[7], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[7] -> Emotions: []
# Segment: zjYEBwXGD8I[8], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[8] -> Emotions: ['happy']
# Segment: zjYEBwXGD8I[9], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[9] -> Emotions: []
# Segment: zjYEBwXGD8I[10], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[10] -> Emotions: ['happy']
# Segment: zjYEBwXGD8I[11], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[11] -> Emotions: []
# Segment: zjYEBwXGD8I[12], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[12] -> Emotions: []
# Segment: zjYEBwXGD8I[13], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[13] -> Emotions: []
# Segment: zjYEBwXGD8I[14], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[14] -> Emotions: []
# Segment: zjYEBwXGD8I[15], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[15] -> Emotions: []
# Segment: zjYEBwXGD8I[16], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[16] -> Emotions: []
# Segment: zjYEBwXGD8I[17], Emotion Data Shape: (1, 7)
# Segment: zjYEBwXGD8I[17] -> Emotions: []
# Segment: zk2jTlAtvSU[0], Emotion Data Shape: (1, 7)
# Segment: zk2jTlAtvSU[0] -> Emotions: []
# Segment: zk2jTlAtvSU[1], Emotion Data Shape: (1, 7)
# Segment: zk2jTlAtvSU[1] -> Emotions: []
# Segment: zknhrUs7-lI[0], Emotion Data Shape: (1, 7)
# Segment: zknhrUs7-lI[0] -> Emotions: []
# Segment: zknhrUs7-lI[1], Emotion Data Shape: (1, 7)
# Segment: zknhrUs7-lI[1] -> Emotions: []
# Segment: zknhrUs7-lI[2], Emotion Data Shape: (1, 7)
# Segment: zknhrUs7-lI[2] -> Emotions: []
# Segment: zknhrUs7-lI[3], Emotion Data Shape: (1, 7)
# Segment: zknhrUs7-lI[3] -> Emotions: []
# Segment: znNt--6itO4[0], Emotion Data Shape: (1, 7)
# Segment: znNt--6itO4[0] -> Emotions: ['happy']
# Segment: znNt--6itO4[1], Emotion Data Shape: (1, 7)
# Segment: znNt--6itO4[1] -> Emotions: []
# Segment: znNt--6itO4[2], Emotion Data Shape: (1, 7)
# Segment: znNt--6itO4[2] -> Emotions: []
# Segment: znNt--6itO4[3], Emotion Data Shape: (1, 7)
# Segment: znNt--6itO4[3] -> Emotions: []
# Segment: znNt--6itO4[4], Emotion Data Shape: (1, 7)
# Segment: znNt--6itO4[4] -> Emotions: []
# Segment: znNt--6itO4[5], Emotion Data Shape: (1, 7)
# Segment: znNt--6itO4[5] -> Emotions: []
# Segment: zoPOeViAdOo[0], Emotion Data Shape: (1, 7)
# Segment: zoPOeViAdOo[0] -> Emotions: []
# Segment: zqkawTdHN5s[0], Emotion Data Shape: (1, 7)
# Segment: zqkawTdHN5s[0] -> Emotions: []
# Segment: zqkawTdHN5s[1], Emotion Data Shape: (1, 7)
# Segment: zqkawTdHN5s[1] -> Emotions: ['happy']
# Segment: zrFZAofNGi4[0], Emotion Data Shape: (1, 7)
# Segment: zrFZAofNGi4[0] -> Emotions: []
# Segment: zrFZAofNGi4[1], Emotion Data Shape: (1, 7)
# Segment: zrFZAofNGi4[1] -> Emotions: []
# Segment: zrFZAofNGi4[2], Emotion Data Shape: (1, 7)
# Segment: zrFZAofNGi4[2] -> Emotions: []
# Segment: zrFZAofNGi4[3], Emotion Data Shape: (1, 7)
# Segment: zrFZAofNGi4[3] -> Emotions: []
# Segment: zrFZAofNGi4[4], Emotion Data Shape: (1, 7)
# Segment: zrFZAofNGi4[4] -> Emotions: []
# Segment: zrFZAofNGi4[5], Emotion Data Shape: (1, 7)
# Segment: zrFZAofNGi4[5] -> Emotions: []
# Segment: zrFZAofNGi4[6], Emotion Data Shape: (1, 7)
# Segment: zrFZAofNGi4[6] -> Emotions: []
# Segment: zrFZAofNGi4[7], Emotion Data Shape: (1, 7)
# Segment: zrFZAofNGi4[7] -> Emotions: ['surprise', 'fear']
# Segment: zsRTbbKlsEg[0], Emotion Data Shape: (1, 7)
# Segment: zsRTbbKlsEg[0] -> Emotions: ['surprise', 'fear']
# Segment: zsRTbbKlsEg[1], Emotion Data Shape: (1, 7)
# Segment: zsRTbbKlsEg[1] -> Emotions: []
# Segment: zuc7vUhZNfY[0], Emotion Data Shape: (1, 7)
# Segment: zuc7vUhZNfY[0] -> Emotions: []
# Segment: zuc7vUhZNfY[1], Emotion Data Shape: (1, 7)
# Segment: zuc7vUhZNfY[1] -> Emotions: []
# Segment: zv0Jl4TIQDc[0], Emotion Data Shape: (1, 7)
# Segment: zv0Jl4TIQDc[0] -> Emotions: []
# Segment: zv0Jl4TIQDc[1], Emotion Data Shape: (1, 7)
# Segment: zv0Jl4TIQDc[1] -> Emotions: ['happy']
# Segment: zv0Jl4TIQDc[2], Emotion Data Shape: (1, 7)
# Segment: zv0Jl4TIQDc[2] -> Emotions: []
# Segment: zvZd3V5D5Ik[0], Emotion Data Shape: (1, 7)
# Segment: zvZd3V5D5Ik[0] -> Emotions: []
# Segment: zvZd3V5D5Ik[1], Emotion Data Shape: (1, 7)
# Segment: zvZd3V5D5Ik[1] -> Emotions: ['happy']
# Segment: zwRBZisdpQ0[0], Emotion Data Shape: (1, 7)
# Segment: zwRBZisdpQ0[0] -> Emotions: []
# Segment: zwRBZisdpQ0[1], Emotion Data Shape: (1, 7)
# Segment: zwRBZisdpQ0[1] -> Emotions: ['sad']
# Segment: zwRBZisdpQ0[2], Emotion Data Shape: (1, 7)
# Segment: zwRBZisdpQ0[2] -> Emotions: []
# Segment: zwRBZisdpQ0[3], Emotion Data Shape: (1, 7)
# Segment: zwRBZisdpQ0[3] -> Emotions: []
# Segment: zwRBZisdpQ0[4], Emotion Data Shape: (1, 7)
# Segment: zwRBZisdpQ0[4] -> Emotions: ['happy', 'sad']
# Segment: zwTrXwi54us[0], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[0] -> Emotions: []
# Segment: zwTrXwi54us[1], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[1] -> Emotions: []
# Segment: zwTrXwi54us[2], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[2] -> Emotions: []
# Segment: zwTrXwi54us[3], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[3] -> Emotions: []
# Segment: zwTrXwi54us[4], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[4] -> Emotions: ['sad']
# Segment: zwTrXwi54us[5], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[5] -> Emotions: []
# Segment: zwTrXwi54us[6], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[6] -> Emotions: []
# Segment: zwTrXwi54us[7], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[7] -> Emotions: []
# Segment: zwTrXwi54us[8], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[8] -> Emotions: []
# Segment: zwTrXwi54us[9], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[9] -> Emotions: []
# Segment: zwTrXwi54us[10], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[10] -> Emotions: []
# Segment: zwTrXwi54us[11], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[11] -> Emotions: ['happy', 'sad']
# Segment: zwTrXwi54us[12], Emotion Data Shape: (1, 7)
# Segment: zwTrXwi54us[12] -> Emotions: []
# Segment: zx4W0Vuus-I[0], Emotion Data Shape: (1, 7)
# Segment: zx4W0Vuus-I[0] -> Emotions: ['happy', 'sad']
#
# Emotion Distribution in Dataset: {'happy': 1923, 'sad': 1802, 'anger': 741, 'surprise': 1052, 'disgust': 137, 'fear': 564}

# %% [markdown]
# ## Train Test Split

# %%
# obtain the train/dev/test splits - these splits are based on video IDs
train_split = DATASET.standard_folds.standard_train_fold
dev_split = DATASET.standard_folds.standard_valid_fold
test_split = DATASET.standard_folds.standard_test_fold

# inspect the splits: they only contain video IDs
print(test_split)
# Out:
# ['7l3BNtSE0xc', 'dZFV0lyedX4', '286943', '126872', 'qgC8_emxSIU', 'kld9r0iFkWM', 'rC29Qub0U7A', '4YfyP0uIqw0', 'FMenDv3y8jc', '4wLP4elp1uM', 'KYQTwFVBzME', '27v7Blr0vjw', 'DnBHq5I52LM', 'HR18U0yAlTc', 'x266rUJQC_8', 'd1CDP6sMuLA', 'xSCvspXYU9k', '4EDblUpJieU', '4o4ilPK9rl8', '53609', 'SZ7HK5ns6mE', '243981', 'ySblgk7T7eQ', 'MYEyQUpMe3k', 'EujJ0SwiCRE', '3HyAaqre_Fk', 'iQDB_OkAQWs', 'gE7kUqMqQ9g', 'eFV7iFPYZB4', 'IRSxo_XXArg', '3hOlJf_JQDs', 'BRSyH6yfDLk', '1jogeKX0wGw', '3At-BKm9eYk', 'NVLPURuAVLU', 'pZye4zFzk3o', 'l1jW3OMXUzs', 'XKyumlBmix8', 'eKQKEi2-0Ws', 'WgI8IbJtXHw', 'tnWmVXZ87h0', 'YCEllKyaCrc', 'W1CWpktWtTs', '8wQhzezNcUY', '0bxhZ-LIfZY', 'lrjm6F3JJgg', 'Vdf1McvE9ao', 'eQc5uI7FKCU', '2QXHdu2zlQY', 'YCI-ZzclIPQ', '2Ky9DBSl49w', 'SKTyBOhDX6U', 'b86B3hP8ARM', '23656', 'kpS4BXif_Sw', 'dR68gbeOWOc', 'tC2KicUHB9Q', 'absh1hsZeF0', 'c5zxqITn3ZM', 'uogwnZGb-iE', '46495', 'Sq6DIhFxPqQ', 'PexNiFbPTYM', 'z441aDJvAcU', 'OORklkFql3k', 'WbtsuXkaGeg', 'grsV1YN1z5s', 'Gc_zIjqqUys', '424SXFTCFsA', 'P17tYiqMGRU', 'UweZVaFqruU', 'mzAu5gxjE-w', '8TDAP0KNIIw', 'u9ZV8jb_-U0', 'iPPp6MCythU', 'lwL4hjhkid4', '102389', 'frCWtiam4tE', 'pSxte-ms0t8', 'c9hE1ghElrM', 'WfNiQBXmPw8', '_q7DM8WkzAQ', '257534', 'fU5AYkq0m9k', 'q17gSr9kNww', 'AgH84SNRx5s', '206585', 'yzCHa2qchpg', 'GmpDbIstUdc', 'eREud0qYR3s', 'NoOt0oU843M', 'svsbGQn389o', 'ZsLrKF7_Oos', 'Kyz32PTyP4I', '7idU7rR77Ss', '8lfS97s2AKc', 'X2Hs89fZ2-c', '5vwXp27bCLw', 'tZDNinnrGf8', 'KB5hSnV1emg', 'TxRtSItpGMo', 'eJfT7-dDqzA', 'x2n19Cn96aw', 'XDVit9ASVUg', '6brtMLkjjYk', '-rxZxtG0xmY', 'JATMzuV6sUE', 'LueQT0vY1zI', '267466', 'm-7yRWZLwLY', 'OWWHjP3pX9o', 'QnYlpSeVOYo', 'V7OFSHYcQD0', 'GK-Pprzh0t0', 'yLo-Jl8nBXU', '200941', '61531', 'ezuWKsxPRSM', 'ehZrOdw6PhA', '-6rXp3zJ3kc', 'Z4iYSMMMycQ', 'MtIklGnIMGo', '116213', '3XShFTBsp_Q', 'YQZPnHZRp1w', 'fsd1qPLA3kY', '208322', 'uVM4JWjfGgQ', 'QWll4lS1qqI', 'Vlas-mPydcg', 'teQqaAmqqx0', 'AQ4Pktv4-Gc', 'yCpHmPSshKY', 'pDRdCSIyjkA', 'sIusv36VoBY', '8jY_RhOS89o', 'GKsjv42t284', 'HA2AiTz-qxc', 'GXIfrEUJ5d4', '0Fqav67TDEw', '10219', 'wHeZHLv9wGI', 'qDfSYz0PX9g', '180971', 'qBanrqkzobg', 'NgENhhXf0LE', 'SH0OYx3fR7s', 'lc5bSoGlQwY', 'XrNaL-MTjXg', '8i7u3fl-hP8', 'N-NnCI6U52c', 'r46amqjpWgg', 'QVyxySAaehE', 'JKueLneBoik', '110565', 'TqQgIxR7thU', '267694', 'ZKErPftd--w', 'GMa0cIAltnw', 'MSHBEntSDjU', 'AB1PbMaW03s', 'oBS-IW-BO00', '5fKPJPFqPho', '8NPaDkOiXw4', '104741', '2ItiGjefTRA', 'LFOwCSiGOvw', 'YLK58srjhNI', '233939', '5xa0Ac2krGs', 'CbRexsp1HKw', '112425', 'bCBMKwafZKY', '_0efYOjQYRc', 'O2ShYliS3CU', 'Oa2xVjzAMFc', 'bnzVR2ETQQ8', 'yBtMwyQFXwA', 'TtAyUQtmTLk', 'yXE_XZUb8qE', '3wHE78v9zr4', 'cml9rShionM', 'rePYTlT5_AY', '9TAGpMywQyE', 'ryE9VBiR3p8', '238063', 'NlrCjfHELLE', 'oGFDE-6nd7Q', 'bWmrrWQOVCM', '29751', '11UtTaDYgII', 'jZe-2w7pkd8', '275267', 'tymso_pAxhk', 'PcqKFt1p3UQ', 'sfaWfZ2-4c0', 'kLAXmTx2xOA', '3OYY5Tsz_2k', 'wk5lFk5kFjY', 'hE-sA5umuCk', '3IUVpwx23cY', '92291', '102213', '236442', 'nbru7qLot04', 'zhNksSReaQk', '8VhVf0TbjDA', '35694', '20LfN8ENbhM', '257277', 'VsXGwSZazwA', 'EyoMU2yoJPY', 'E1r0FrFyNTw', 'CO2YoTZbUr0', 'wC_1M7KIv9s', '24196', '194299', 'R9xTBw3MCWI', 'cY8DcaHXNNs', 'SwT0gh0V8fI', 'UiurP5k-f1A', 'N0d2JL7JC1s', '208592', 'GAVpYuhMZAw', 'pvIQWWiT4-0', 'namehdJxRIM', 'tNd3--lvSXE', 'NaWmaHwjElo', 'mfpR4CN9LZo', 'U6IqFbpM-VM', 'XLjpZUsFEXo', 'YUNxD04EvfE', 'hI7ObFqn9Bg', 'CO6n-skQJss', 'RsE2gYghZ2s', '2ze94yo2aPo', '254427', 'MHyW857u_X8', 'Xa086gxLJ3Y', 'Uu_XyXyKHAk', 'TsfyeZ8hgwE', 'vI5JH0daNsM', 'mmg_eTDHjkk', 'lD4xtQ6NpDY', 'XWIp0zH3qDM', '259470', '0eTibWQdO5M', 'fcxbB7ybUfs', '5pxFqJ5hKMU', '245582', 'WQFRctNL8AA', '2m58ShI1QSI', 'cn0WZ8-0Z1Y', '25640', 'huzEsVEJPaY', 'UTErYLpdAY0', 'F2hc2FLOdhI', 'vGxqVh_kJdo', 'F_YaG_pvZrA', 'UNLD7eYPzfQ', '0K7dCp80n9c', 'xBE9YWYGjtk', 'nTZSH0EwpnY', 'mZ_8em_-CGc', 'fdc7iyzKvFQ', '221137', 'QBc7X5jj8oA', 'pnpFPX34Agk', '63951', 'veA6ECsGFxI', 'XbkYA-iXUwA', '1LkYxsqRPZM', 'qAip3lZRj-g', 'gR3igiwaeyc', 'pIaEcqnzI-s', 'oHff2W51wZ8', 'XlTYSOaZ_vM', '3WZ6R9B0PcU', 'IOpWjKAHG8Q', '53766', '19074 ...

# %%
# we can see they are in the format of 'video_id[segment_no]', but the splits was specified with video_id only
# we need to use regex or something to match the video IDs...
import re
import torch
import torch.nn as nn

from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm_notebook
from collections import defaultdict

# a sentinel epsilon for safe division, without it we will replace illegal values with a constant
EPS = 0

# construct a word2id mapping that automatically takes increment when new words are encountered
word2id = defaultdict(lambda: len(word2id))
UNK = word2id['<unk>']
PAD = word2id['<pad>']

# place holders for the final train/dev/test dataset
train = []
dev = []
test = []

# define a regular expression to extract the video ID out of the keys
pattern = re.compile('(.*)\[.*\]')
num_drop = 0 # a counter to count how many data points went into some processing issues

problematic_segments = {"HuIKyKkEL0Q[0]","JGEEA_JVriE[0]","JGEEA_JVriE[1]","JGEEA_JVriE[2]","JGEEA_JVriE[3]","aa0J1AXSseY[4]","aa0J1AXSseY[5]","aa0J1AXSseY[6]","zsRTbbKlsEg[0]"}

for segment in dataset[label_field].keys():
    
    if segment in problematic_segments:
        print(f"Skipping problematic segment: {segment}")
        num_drop += 1
        continue
    
    # get the video ID and the features out of the aligned dataset
    vid = re.search(pattern, segment).group(1)
    label = dataset[label_field][segment]['features']
    _words = dataset[word_field][segment]['features']
    _visual = dataset[visual_field][segment]['features']
    _acoustic = dataset[acoustic_field][segment]['features']

    # if the sequences are not same length after alignment, there must be some problem with some modalities
    # we should drop it or inspect the data again
    if not _words.shape[0] == _visual.shape[0] == _acoustic.shape[0]:
        print(f"Encountered datapoint {vid} with text shape {_words.shape}, visual shape {_visual.shape}, acoustic shape {_acoustic.shape}")
        num_drop += 1
        continue

    # remove nan values
    label = np.nan_to_num(label)
    _visual = np.nan_to_num(_visual)
    _acoustic = np.nan_to_num(_acoustic)

    # remove speech pause tokens - this is in general helpful
    # we should remove speech pauses and corresponding visual/acoustic features together
    # otherwise modalities would no longer be aligned
    words = []
    visual = []
    acoustic = []
    for i, word in enumerate(_words):
        if word[0] != b'sp':
            words.append(word2id[word[0].decode('utf-8')]) # SDK stores strings as bytes, decode into strings here
            visual.append(_visual[i, :])
            acoustic.append(_acoustic[i, :])

    words = np.asarray(words)
    visual = np.asarray(visual)
    acoustic = np.asarray(acoustic)

    # z-normalization per instance and remove nan/infs
    visual = np.nan_to_num((visual - visual.mean(0, keepdims=True)) / (EPS + np.std(visual, axis=0, keepdims=True)))
    acoustic = np.nan_to_num((acoustic - acoustic.mean(0, keepdims=True)) / (EPS + np.std(acoustic, axis=0, keepdims=True)))

    if vid in train_split:
        train.append(((words, visual, acoustic), label, segment))
    elif vid in dev_split:
        dev.append(((words, visual, acoustic), label, segment))
    elif vid in test_split:
        test.append(((words, visual, acoustic), label, segment))
    else:
        print(f"Found video that doesn't belong to any splits: {vid}")

print(f"Total number of {num_drop} datapoints have been dropped.")

# turn off the word2id - define a named function here to allow for pickling
def return_unk():
    return UNK
word2id.default_factory = return_unk
# Out:
# C:\Users\Saahil\AppData\Local\Temp\ipykernel_29780\156966448.py:75: RuntimeWarning: invalid value encountered in divide
#   acoustic = np.nan_to_num((acoustic - acoustic.mean(0, keepdims=True)) / (EPS + np.std(acoustic, axis=0, keepdims=True)))
# c:\Users\Saahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\Users\Saahil\AppData\Local\Temp\ipykernel_29780\156966448.py:74: RuntimeWarning: invalid value encountered in divide
#   visual = np.nan_to_num((visual - visual.mean(0, keepdims=True)) / (EPS + np.std(visual, axis=0, keepdims=True)))
# c:\Users\Saahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\_methods.py:118: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# c:\Users\Saahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\_methods.py:152: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# Found video that doesn't belong to any splits: -9YyBTjo1zo
# Found video that doesn't belong to any splits: -9YyBTjo1zo
# Found video that doesn't belong to any splits: -9YyBTjo1zo
# Found video that doesn't belong to any splits: -9YyBTjo1zo
# Found video that doesn't belong to any splits: -9YyBTjo1zo
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Alixo7euuU
# Found video that doesn't belong to any splits: -Eqdz5y4pEY
# Found video that doesn't belong to any splits: -HvKLjmsO5U
# Found video that doesn't belong to any splits: -HvKLjmsO5U
# Found video that doesn't belong to any splits: -IUUR2yyNbw
# Found video that doesn't belong to any splits: -IUUR2yyNbw
# Found video that doesn't belong to any splits: -IUUR2yyNbw
# Found video that doesn't belong to any splits: -IUUR2yyNbw
# Found video that doesn't belong to any splits: -IUUR2yyNbw
# Found video that doesn't belong to any splits: -IqSFQePnpU
# Found video that doesn't belong to any splits: -KCahx2qBOI
# Found video that doesn't belong to any splits: -KCahx2qBOI
# Found video that doesn't belong to any splits: -KCahx2qBOI
# Found video that doesn't belong to any splits: -LnuDPiuuZw
# Found video that doesn't belong to any splits: -LnuDPiuuZw
# Found video that doesn't belong to any splits: -LnuDPiuuZw
# Found video that doesn't belong to any splits: -LnuDPiuuZw
# Found video that doesn't belong to any splits: -NFrJFQijFE
# Found video that doesn't belong to any splits: -NFrJFQijFE
# Found video that doesn't belong to any splits: -NFrJFQijFE
# Found video that doesn't belong to any splits: -NFrJFQijFE
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -RpZEe4w4fY
# Found video that doesn't belong to any splits: -SYSVSQnTnA
# Found video that doesn't belong to any splits: -SYSVSQnTnA
# Found video that doesn't belong to any splits: -SYSVSQnTnA
# Found video that doesn't belong to any splits: -VmheDA92mM
# Found video that doesn't belong to any splits: -VmheDA92mM
# Found video that doesn't belong to any splits: -VmheDA92mM
# Found video that doesn't belong to any splits: -VmheDA92mM
# Found video that doesn't belong to any splits: -VmheDA92mM
# Encountered datapoint -ZgjBOA1Yhw with text shape (38, 1), visual shape (37, 35), acoustic shape (38, 74)
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -bl5PfNIYrk
# Found video that doesn't belong to any splits: -cmk6cfUeMs
# Found video that doesn't belong to any splits: -cmk6cfUeMs
# Found video that doesn't belong to any splits: -dZ1TCboxcQ
# Found video that doesn't belong to any splits: -dZ1TCboxcQ
# Found video that doesn't belong to any splits: -dZ1TCboxcQ
# Found video that doesn't belong to any splits: -dZ1TCboxcQ
# Found video that doesn't belong to any splits: -hPfPhUIzfA
# Found video that doesn't belong to any splits: -hPfPhUIzfA
# Found video that doesn't belong to any splits: -hPfPhUIzfA
# Found video that doesn't belong to any splits: -hPfPhUIzfA
# Found video that doesn't belong to any splits: -l_53IwQoj0
# Found video that doesn't belong to any splits: -m9KtvCk_L8
# Found video that doesn't belong to any splits: -m9KtvCk_L8
# Found video that doesn't belong to any splits: -m9KtvCk_L8
# Found video that doesn't belong to any splits: -o_667Ny7RM
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -qMhGeJkp5o
# Found video that doesn't belong to any splits: -wdUIwjDMfg
# Encountered datapoint 0hCOCt6fWas with text shape (18, 1), visual shape (17, 35), acoustic shape (18, 74)
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1S4p-Lfhbp4
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Found video that doesn't belong to any splits: 1knHBRVPoYQ
# Encountered datapoint 1zXAYdPdzy8 with text shape (36, 1), visual shape (35, 35), acoustic shape (36, 74)
# Found video that doesn't belong to any splits: 4Y8ROYezksQ
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Found video that doesn't belong to any splits: 5OUcvUDMMWE
# Encountered datapoint 69824 with text shape (7, 1), visual shape (6, 35), acoustic shape (7, 74)
# Found video that doesn't belong to any splits: 6ywl-j2-e-s
# Found video that doesn't belong to any splits: 6ywl-j2-e-s
# Found video that doesn't belong to any splits: 7BFhRPlSOf0
# Found video that doesn't belong to any splits: 7BFhRPlSOf0
# Found video that doesn't belong to any splits: 7BFhRPlSOf0
# Found video that doesn't belong to any splits: 7BFhRPlSOf0
# Found video that doesn't belong to any splits: 7BFhRPlSOf0
# Encountered datapoint 8f_lBxZgDb0 with text shape (55, 1), visual shape (54, 35), acoustic shape (55, 74)
# Found video that doesn't belong to any splits: 8vpoQ5UVpXE
# Found video that doesn't belong to any splits: 8vpoQ5UVpXE
# Found video that doesn't belong to any splits: 8vpoQ5UVpXE
# Found video that doesn't belong to any splits: 8vpoQ5UVpXE
# Found video that doesn't belong to any splits: 8vpoQ5UVpXE
# Encountered datapoint 92221 with text shape (8, 1), visual shape (7, 35), acoustic shape (8, 74)
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9OY3NU2ycVw
# Found video that doesn't belong to any splits: 9kLNVTm3Z90
# Found video that doesn't belong to any splits: 9kLNVTm3Z90
# Found video that doesn't belong to any splits: 9kLNVTm3Z90
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AHXwnFvqYDk
# Found video that doesn't belong to any splits: AcoRjVPIVmQ
# Found video that doesn't belong to any splits: AcoRjVPIVmQ
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: BgXqrxum5G4
# Found video that doesn't belong to any splits: CXvUdCdKTJY
# Found video that doesn't belong to any splits: CXvUdCdKTJY
# Found video that doesn't belong to any splits: CXvUdCdKTJY
# Found video that doesn't belong to any splits: CXvUdCdKTJY
# Found video that doesn't belong to any splits: EWYivXUavOY
# Found video that doesn't belong to any splits: EWYivXUavOY
# Found video that doesn't belong to any splits: EWYivXUavOY
# Found video that doesn't belong to any splits: EWYivXUavOY
# Found video that doesn't belong to any splits: EWYivXUavOY
# Found video that doesn't belong to any splits: EuSp1pkX9i8
# Found video that doesn't belong to any splits: EuSp1pkX9i8
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Found video that doesn't belong to any splits: FzxmeVRTjwU
# Skipping problematic segment: HuIKyKkEL0Q[0]
# Encountered datapoint Iemw8vqt-54 with text shape (19, 1), visual shape (18, 35), acoustic shape (19, 74)
# Skipping problematic segment: JGEEA_JVriE[0]
# Skipping problematic segment: JGEEA_JVriE[1]
# Skipping problematic segment: JGEEA_JVriE[2]
# Skipping problematic segment: JGEEA_JVriE[3]
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Found video that doesn't belong to any splits: JNt1k3ohkbs
# Encountered datapoint JXYot3NDQn0 with text shape (43, 1), visual shape (42, 35), acoustic shape (43, 74)
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: MIqL9OXszRw
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Found video that doesn't belong to any splits: NVlxq3jxlAk
# Encountered datapoint Q5uYByRyswI with text shape (76, 1), visual shape (75, 35), acoustic shape (76, 74)
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TdCfpMRiA1c
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: TwFl4epL244
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: UcINGGuysBE
# Found video that doesn't belong to any splits: XnPnlRQXSkM
# Found video that doesn't belong to any splits: XnPnlRQXSkM
# Found video that doesn't belong to any splits: XnPnlRQXSkM
# Found video that doesn't belong to any splits: XnPnlRQXSkM
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Found video that doesn't belong to any splits: ZXQkyX6prBQ
# Encountered datapoint aa0J1AXSseY with text shape (32, 1), visual shape (23, 35), acoustic shape (32, 74)
# Skipping problematic segment: aa0J1AXSseY[4]
# Skipping problematic segment: aa0J1AXSseY[5]
# Skipping problematic segment: aa0J1AXSseY[6]
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: aa2MEQ6FL7k
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: bDwAuRFciJM
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: cuR-l2qCxBc
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: dYgmvmFegkQ
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fMUmdlzuc94
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: fiXZqpbRYKk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: flv4by3RYVk
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: foXArPhK0xY
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: hytnfm-AVaA
# Found video that doesn't belong to any splits: mLZZ174bqws
# Found video that doesn't belong to any splits: mLZZ174bqws
# Found video that doesn't belong to any splits: mLZZ174bqws
# Found video that doesn't belong to any splits: mLZZ174bqws
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: nMCCLB9gOag
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o5OsO6Aq9pA
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: o6Cd9RmqdBc
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: oNnoN0bxVnA
# Found video that doesn't belong to any splits: ptp-kfn4vWY
# Found video that doesn't belong to any splits: ptp-kfn4vWY
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: qYC3gN1AkOA
# Found video that doesn't belong to any splits: rKyXU0ls5aQ
# Found video that doesn't belong to any splits: rKyXU0ls5aQ
# Found video that doesn't belong to any splits: rKyXU0ls5aQ
# Found video that doesn't belong to any splits: rKyXU0ls5aQ
# Found video that doesn't belong to any splits: rKyXU0ls5aQ
# Found video that doesn't belong to any splits: slz8pd0Wzxs
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Found video that doesn't belong to any splits: tkzdanzsA0A
# Encountered datapoint vM3YB7LmMq4 with text shape (13, 1), visual shape (12, 35), acoustic shape (13, 74)
# Found video that doesn't belong to any splits: vn0CFvUK5D0
# Found video that doesn't belong to any splits: vn0CFvUK5D0
# Found video that doesn't belong to any splits: vn0CFvUK5D0
# Found video that doesn't belong to any splits: vn0CFvUK5D0
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: x-oexIBWwR4
# Found video that doesn't belong to any splits: zShw-E-yBqU
# Found video that doesn't belong to any splits: zShw-E-yBqU
# Found video that doesn't belong to any splits: zShw-E-yBqU
# Found video that doesn't belong to any splits: zShw-E-yBqU
# Found video that doesn't belong to any splits: zShw-E-yBqU
# Skipping problematic segment: zsRTbbKlsEg[0]
# Total number of 20 datapoints have been dropped.

# %%
# let's see the size of each set and shape of data
print(len(train))
print(len(dev))
print(len(test))

print(train[0][0][1].shape)
print(train[0][1].shape)
print(train[0][1])

print(f"Total vocab size: {len(word2id)}")
# Out:
# 16315
# 1871
# 4654
# (42, 35)
# (1, 7)
# [[1.        0.6666667 0.6666667 0.        0.        0.        0.6666667]]
# Total vocab size: 16819

# %% [markdown]
# Collate function in PyTorch
#
# Collate functions are functions used by PyTorch dataloader to gather batched data from dataset. It loads multiple data points from an iterable dataset object and put them in a certain format. Here we just use the lists we've constructed as the dataset and assume PyTorch dataloader will operate on that.

# %%
def multi_collate(batch):
    '''
    Collate functions assume batch = [Dataset[i] for i in index_set]
    '''
    # for later use we sort the batch in descending order of length
    batch = sorted(batch, key=lambda x: x[0][0].shape[0], reverse=True)
    
    # get the data out of the batch - use pad sequence util functions from PyTorch to pad things
    labels = torch.cat([torch.from_numpy(sample[1]) for sample in batch], dim=0)
    sentences = pad_sequence([torch.LongTensor(sample[0][0]) for sample in batch], padding_value=PAD)
    visual = pad_sequence([torch.FloatTensor(sample[0][1]) for sample in batch])
    acoustic = pad_sequence([torch.FloatTensor(sample[0][2]) for sample in batch])
    
    # lengths are useful later in using RNNs
    lengths = torch.LongTensor([sample[0][0].shape[0] for sample in batch])
    return sentences, visual, acoustic, labels, lengths

# construct dataloaders, dev and test could use around ~X3 times batch size since no_grad is used during eval
batch_sz = 56
train_loader = DataLoader(train, shuffle=True, batch_size=batch_sz, collate_fn=multi_collate)
dev_loader = DataLoader(dev, shuffle=False, batch_size=batch_sz*3, collate_fn=multi_collate)
test_loader = DataLoader(test, shuffle=False, batch_size=batch_sz*3, collate_fn=multi_collate)

# let's create a temporary dataloader just to see how the batch looks like
temp_loader = iter(DataLoader(test, shuffle=True, batch_size=8, collate_fn=multi_collate))
batch = next(temp_loader)

print(batch[0].shape) # word vectors, padded to maxlen
print(batch[1].shape) # visual features
print(batch[2].shape) # acoustic features
print(batch[3]) # labels
print(batch[4]) # lengths
# Out:
# torch.Size([40, 8])
# torch.Size([40, 8, 35])
# torch.Size([40, 8, 74])
# tensor([[ 0.6667,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.6667,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 0.3333,  1.0000,  0.0000,  0.0000,  0.0000,  0.3333,  0.0000],
#         [-0.3333,  0.0000,  0.3333,  0.3333,  0.0000,  0.0000,  0.0000],
#         [-2.6667,  0.0000,  0.3333,  0.6667,  0.0000,  1.3333,  0.0000],
#         [ 1.3333,  0.3333,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 1.6667,  1.6667,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000],
#         [ 2.6667,  2.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000]])
# tensor([40, 34, 34, 28, 24, 22, 19, 14])

# %%
# Let's actually inspect the transcripts to ensure it's correct
id2word = {v:k for k, v in word2id.items()}
examine_target = train
idx = np.random.randint(0, len(examine_target))
print(' '.join(list(map(lambda x: id2word[x], examine_target[idx][0][0].tolist()))))
# print(' '.join(examine_target[idx][0]))
print(examine_target[idx][1])
print(examine_target[idx][2])
# Out:
# behavior and any marketer that wants to be successful needs to consider these and be able to adapt their programs to the changing needs of the consumer consumer
# [[0.33333334 0.33333334 0.         0.         0.         0.
#   0.        ]]
# Ha7DMd_iKyM[0]

# %% [markdown]
# ## Defining Multimodal model

# %%
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

class LFLSTM(nn.Module):
    def __init__(self, input_sizes, hidden_sizes, fc1_size, output_size, dropout_rate):
        super(LFLSTM, self).__init__()
        self.input_size = input_sizes
        self.hidden_size = hidden_sizes
        self.fc1_size = fc1_size
        self.output_size = output_size
        self.dropout_rate = dropout_rate

        # Define the RNN layers for each modality
        self.embed = nn.Embedding(len(word2id), input_sizes[0])
        self.trnn1 = nn.LSTM(input_sizes[0], hidden_sizes[0], bidirectional=True)
        self.trnn2 = nn.LSTM(2 * hidden_sizes[0], hidden_sizes[0], bidirectional=True)
        
        self.vrnn1 = nn.LSTM(input_sizes[1], hidden_sizes[1], bidirectional=True)
        self.vrnn2 = nn.LSTM(2 * hidden_sizes[1], hidden_sizes[1], bidirectional=True)
        
        self.arnn1 = nn.LSTM(input_sizes[2], hidden_sizes[2], bidirectional=True)
        self.arnn2 = nn.LSTM(2 * hidden_sizes[2], hidden_sizes[2], bidirectional=True)

        # Define fully connected layers for fusion and classification
        self.fc1 = nn.Linear(sum(hidden_sizes) * 4, fc1_size)
        self.fc2 = nn.Linear(fc1_size, output_size)  # Output layer with 6 classes for MOSEI
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.tlayer_norm = nn.LayerNorm((hidden_sizes[0] * 2,))
        self.vlayer_norm = nn.LayerNorm((hidden_sizes[1] * 2,))
        self.alayer_norm = nn.LayerNorm((hidden_sizes[2] * 2,))
        self.bn = nn.BatchNorm1d(sum(hidden_sizes) * 4)

    def extract_features(self, sequence, lengths, rnn1, rnn2, layer_norm):
        packed_sequence = pack_padded_sequence(sequence, lengths, enforce_sorted=False)
        packed_h1, (final_h1, _) = rnn1(packed_sequence)
        padded_h1, _ = pad_packed_sequence(packed_h1)
        normed_h1 = layer_norm(padded_h1)
        packed_normed_h1 = pack_padded_sequence(normed_h1, lengths, enforce_sorted=False)
        _, (final_h2, _) = rnn2(packed_normed_h1)
        return final_h1, final_h2

    def fusion(self, sentences, visual, acoustic, lengths):
        batch_size = lengths.size(0)
        sentences = self.embed(sentences)

        # Extract features from each modality
        final_h1t, final_h2t = self.extract_features(sentences, lengths, self.trnn1, self.trnn2, self.tlayer_norm)
        final_h1v, final_h2v = self.extract_features(visual, lengths, self.vrnn1, self.vrnn2, self.vlayer_norm)
        final_h1a, final_h2a = self.extract_features(acoustic, lengths, self.arnn1, self.arnn2, self.alayer_norm)

        # Late fusion by concatenating modality outputs
        h = torch.cat((final_h1t, final_h2t, final_h1v, final_h2v, final_h1a, final_h2a),
                      dim=2).permute(1, 0, 2).contiguous().view(batch_size, -1)
        return self.bn(h)

    def forward(self, sentences, visual, acoustic, lengths):
        batch_size = lengths.size(0)
        h = self.fusion(sentences, visual, acoustic, lengths)
        h = self.fc1(h)
        h = self.dropout(h)
        h = self.relu(h)
        o = self.fc2(h)  # Final output layer with six classes
        return o

# %% [markdown]
# - Load pretrained embeddings
#
# We define a function for loading pretrained word embeddings stored in GloVe-style file. Contextualized embeddings obviously cannot be stored and loaded this way, though.

# %%
def load_emb(w2i, path_to_embedding, embedding_size=300, embedding_vocab=2196017, init_emb=None):
    if init_emb is None:
        emb_mat = np.random.randn(len(w2i), embedding_size)
    else:
        emb_mat = init_emb
    f = open(path_to_embedding, 'r')
    found = 0
    for line in tqdm_notebook(f, total=embedding_vocab):
        content = line.strip().split()
        vector = np.asarray(list(map(lambda x: float(x), content[-300:])))
        word = ' '.join(content[:-300])
        if word in w2i:
            idx = w2i[word]
            emb_mat[idx, :] = vector
            found += 1
    print(f"Found {found} words in the embedding file.")
    return torch.tensor(emb_mat).float()

# %%
# from tqdm import tqdm_notebook
# from torch.optim import Adam, SGD
# from sklearn.metrics import accuracy_score

# torch.manual_seed(123)
# torch.cuda.manual_seed_all(123)

# CUDA = torch.cuda.is_available()
# MAX_EPOCH = 1000

# text_size = 300
# visual_size = 47
# acoustic_size = 74

# # define some model settings and hyper-parameters
# input_sizes = [text_size, visual_size, acoustic_size]
# hidden_sizes = [int(text_size * 1.5), int(visual_size * 1.5), int(acoustic_size * 1.5)]
# fc1_size = sum(hidden_sizes) // 2
# dropout = 0.25
# output_size = 1
# curr_patience = patience = 8
# num_trials = 3
# grad_clip_value = 1.0
# weight_decay = 0.1

# if os.path.exists(CACHE_PATH):
#     pretrained_emb, word2id = torch.load(CACHE_PATH)
# elif WORD_EMB_PATH is not None:
#     pretrained_emb = load_emb(word2id, WORD_EMB_PATH)
#     torch.save((pretrained_emb, word2id), CACHE_PATH)
# else:
#     pretrained_emb = None

# model = LFLSTM(input_sizes, hidden_sizes, fc1_size, output_size, dropout)
# if pretrained_emb is not None:
#     model.embed.weight.data = pretrained_emb
# model.embed.requires_grad = False
# optimizer = Adam([param for param in model.parameters() if param.requires_grad], weight_decay=weight_decay)

# if CUDA:
#     model.cuda()
# criterion = nn.L1Loss(reduction='sum')
# criterion_test = nn.L1Loss(reduction='sum')
# best_valid_loss = float('inf')
# lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.1)
# lr_scheduler.step() # for some reason it seems the StepLR needs to be stepped once first
# train_losses = []
# valid_losses = []
# for e in range(MAX_EPOCH):
#     model.train()
#     train_iter = tqdm_notebook(train_loader)
#     train_loss = 0.0
#     for batch in train_iter:
#         model.zero_grad()
#         t, v, a, y, l = batch
#         batch_size = t.size(0)
#         if CUDA:
#             t = t.cuda()
#             v = v.cuda()
#             a = a.cuda()
#             y = y.cuda()
#             l = l.cuda()
#         y_tilde = model(t, v, a, l)
#         loss = criterion(y_tilde, y)
#         loss.backward()
#         torch.nn.utils.clip_grad_value_([param for param in model.parameters() if param.requires_grad], grad_clip_value)
#         optimizer.step()
#         train_iter.set_description(f"Epoch {e}/{MAX_EPOCH}, current batch loss: {round(loss.item()/batch_size, 4)}")
#         train_loss += loss.item()
#     train_loss = train_loss / len(train)
#     train_losses.append(train_loss)
#     print(f"Training loss: {round(train_loss, 4)}")

#     model.eval()
#     with torch.no_grad():
#         valid_loss = 0.0
#         for batch in dev_loader:
#             model.zero_grad()
#             t, v, a, y, l = batch
#             if CUDA:
#                 t = t.cuda()
#                 v = v.cuda()
#                 a = a.cuda()
#                 y = y.cuda()
#                 l = l.cuda()
#             y_tilde = model(t, v, a, l)
#             loss = criterion(y_tilde, y)
#             valid_loss += loss.item()
    
#     valid_loss = valid_loss/len(dev)
#     valid_losses.append(valid_loss)
#     print(f"Validation loss: {round(valid_loss, 4)}")
#     print(f"Current patience: {curr_patience}, current trial: {num_trials}.")
#     if valid_loss <= best_valid_loss:
#         best_valid_loss = valid_loss
#         print("Found new best model on dev set!")
#         torch.save(model.state_dict(), 'model.std')
#         torch.save(optimizer.state_dict(), 'optim.std')
#         curr_patience = patience
#     else:
#         curr_patience -= 1
#         if curr_patience <= -1:
#             print("Running out of patience, loading previous best model.")
#             num_trials -= 1
#             curr_patience = patience
#             model.load_state_dict(torch.load('model.std'))
#             optimizer.load_state_dict(torch.load('optim.std'))
#             lr_scheduler.step()
#             print(f"Current learning rate: {optimizer.state_dict()['param_groups'][0]['lr']}")
    
#     if num_trials <= 0:
#         print("Running out of patience, early stopping.")
#         break

# model.load_state_dict(torch.load('model.std'))
# y_true = []
# y_pred = []
# model.eval()
# with torch.no_grad():
#     test_loss = 0.0
#     for batch in test_loader:
#         model.zero_grad()
#         t, v, a, y, l = batch
#         if CUDA:
#             t = t.cuda()
#             v = v.cuda()
#             a = a.cuda()
#             y = y.cuda()
#             l = l.cuda()
#         y_tilde = model(t, v, a, l)
#         loss = criterion_test(y_tilde, y)
#         y_true.append(y_tilde.detach().cpu().numpy())
#         y_pred.append(y.detach().cpu().numpy())
#         test_loss += loss.item()
# print(f"Test set performance: {test_loss/len(test)}")
# y_true = np.concatenate(y_true, axis=0)
# y_pred = np.concatenate(y_pred, axis=0)
                  
# y_true_bin = y_true >= 0
# y_pred_bin = y_pred >= 0
# bin_acc = accuracy_score(y_true_bin, y_pred_bin)
# print(f"Test set accuracy is {bin_acc}")

# %%
# from tqdm import tqdm_notebook
# from torch.optim import Adam, SGD
# from sklearn.metrics import accuracy_score
# import torch
# import torch.nn as nn
# import numpy as np
# import os

# torch.manual_seed(123)

# MAX_EPOCH = 1000
# text_size = 300
# visual_size = 35
# acoustic_size = 74

# # Define model settings and hyper-parameters
# input_sizes = [text_size, visual_size, acoustic_size]
# hidden_sizes = [int(text_size * 1.5), int(visual_size * 1.5), int(acoustic_size * 1.5)]
# fc1_size = sum(hidden_sizes) // 2
# dropout = 0.25
# output_size = 1
# curr_patience = patience = 8
# num_trials = 3
# grad_clip_value = 1.0
# weight_decay = 0.1

# # Load embeddings if available
# if os.path.exists(CACHE_PATH):
#     pretrained_emb, word2id = torch.load(CACHE_PATH)
# elif WORD_EMB_PATH is not None:
#     pretrained_emb = load_emb(word2id, WORD_EMB_PATH)
#     torch.save((pretrained_emb, word2id), CACHE_PATH)
# else:
#     pretrained_emb = None

# # Initialize model
# model = LFLSTM(input_sizes, hidden_sizes, fc1_size, output_size, dropout)
# if pretrained_emb is not None:
#     model.embed.weight.data = pretrained_emb
# model.embed.requires_grad = False
# optimizer = Adam([param for param in model.parameters() if param.requires_grad], weight_decay=weight_decay)

# criterion = nn.L1Loss(reduction='sum')
# criterion_test = nn.L1Loss(reduction='sum')
# best_valid_loss = float('inf')
# lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.1)
# lr_scheduler.step()  # Step once initially to set up scheduler
# train_losses = []
# valid_losses = []

# # Training loop
# for e in range(MAX_EPOCH):
#     model.train()
#     train_iter = tqdm_notebook(train_loader)
#     train_loss = 0.0
#     for batch in train_iter:
#         model.zero_grad()
#         t, v, a, y, l = batch
#         batch_size = t.size(0)

#         y_tilde = model(t, v, a, l)
#         loss = criterion(y_tilde, y)
#         loss.backward()
#         torch.nn.utils.clip_grad_value_([param for param in model.parameters() if param.requires_grad], grad_clip_value)
#         optimizer.step()
#         train_iter.set_description(f"Epoch {e}/{MAX_EPOCH}, current batch loss: {round(loss.item() / batch_size, 4)}")
#         train_loss += loss.item()

#     train_loss = train_loss / len(train_loader)
#     train_losses.append(train_loss)
#     print(f"Training loss: {round(train_loss, 4)}")

#     # Validation
#     model.eval()
#     with torch.no_grad():
#         valid_loss = 0.0
#         for batch in dev_loader:
#             t, v, a, y, l = batch
#             y_tilde = model(t, v, a, l)
#             loss = criterion(y_tilde, y)
#             valid_loss += loss.item()
    
#     valid_loss = valid_loss / len(dev_loader)
#     valid_losses.append(valid_loss)
#     print(f"Validation loss: {round(valid_loss, 4)}")
#     print(f"Current patience: {curr_patience}, current trial: {num_trials}.")
    
#     if valid_loss <= best_valid_loss:
#         best_valid_loss = valid_loss
#         print("Found new best model on dev set!")
#         torch.save(model.state_dict(), 'model.std')
#         torch.save(optimizer.state_dict(), 'optim.std')
#         curr_patience = patience
#     else:
#         curr_patience -= 1
#         if curr_patience <= -1:
#             print("Running out of patience, loading previous best model.")
#             num_trials -= 1
#             curr_patience = patience
#             model.load_state_dict(torch.load('model.std'))
#             optimizer.load_state_dict(torch.load('optim.std'))
#             lr_scheduler.step()
#             print(f"Current learning rate: {optimizer.state_dict()['param_groups'][0]['lr']}")

#     if num_trials <= 0:
#         print("Running out of patience, early stopping.")
#         break

# # Load best model for testing
# model.load_state_dict(torch.load('model.std'))
# y_true = []
# y_pred = []
# model.eval()
# with torch.no_grad():
#     test_loss = 0.0
#     for batch in test_loader:
#         t, v, a, y, l = batch
#         y_tilde = model(t, v, a, l)
#         loss = criterion_test(y_tilde, y)
#         y_true.append(y_tilde.detach().cpu().numpy())
#         y_pred.append(y.detach().cpu().numpy())
#         test_loss += loss.item()

# print(f"Test set performance: {test_loss / len(test_loader)}")
# y_true = np.concatenate(y_true, axis=0)
# y_pred = np.concatenate(y_pred, axis=0)

# y_true_bin = y_true >= 0
# y_pred_bin = y_pred >= 0
# bin_acc = accuracy_score(y_true_bin, y_pred_bin)
# print(f"Test set accuracy is {bin_acc}")
# Out:
# C:\Users\Saahil\AppData\Local\Temp\ipykernel_29780\1789770977.py:54: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   train_iter = tqdm_notebook(train_loader)
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 139.9862
# Validation loss: 326.0772
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 131.0943
# Validation loss: 306.0521
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 121.8259
# Validation loss: 291.0132
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 114.6997
# Validation loss: 278.8834
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 109.3622
# Validation loss: 269.3297
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 105.7305
# Validation loss: 264.6006
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.6286
# Validation loss: 264.0867
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.5212
# Validation loss: 263.8559
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.4826
# Validation loss: 263.9465
# Current patience: 8, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.4547
# Validation loss: 263.7984
# Current patience: 7, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.4314
# Validation loss: 263.7466
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.4266
# Validation loss: 263.7829
# Current patience: 8, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.4131
# Validation loss: 263.8425
# Current patience: 7, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3979
# Validation loss: 263.6789
# Current patience: 6, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3967
# Validation loss: 263.7393
# Current patience: 8, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3764
# Validation loss: 263.6493
# Current patience: 7, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3641
# Validation loss: 263.6223
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3571
# Validation loss: 263.5821
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3454
# Validation loss: 263.5686
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.335
# Validation loss: 263.5586
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3291
# Validation loss: 263.5496
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3246
# Validation loss: 263.5305
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3158
# Validation loss: 263.5481
# Current patience: 8, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3127
# Validation loss: 263.5044
# Current patience: 7, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3077
# Validation loss: 263.4877
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.3025
# Validation loss: 263.5
# Current patience: 8, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2969
# Validation loss: 263.4667
# Current patience: 7, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.293
# Validation loss: 263.4631
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2902
# Validation loss: 263.4557
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2888
# Validation loss: 263.4474
# Current patience: 8, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2878
# Validation loss: 263.4483
# Current patience: 8, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2877
# Validation loss: 263.4554
# Current patience: 7, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2881
# Validation loss: 263.4721
# Current patience: 6, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2891
# Validation loss: 263.4534
# Current patience: 5, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2889
# Validation loss: 263.4461
# Current patience: 4, current trial: 3.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2907
# Validation loss: 263.4634
# Current patience: 8, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2895
# Validation loss: 263.459
# Current patience: 7, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.291
# Validation loss: 263.4535
# Current patience: 6, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2883
# Validation loss: 263.447
# Current patience: 5, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2898
# Validation loss: 263.4565
# Current patience: 4, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2898
# Validation loss: 263.4677
# Current patience: 3, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2894
# Validation loss: 263.4485
# Current patience: 2, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2893
# Validation loss: 263.4492
# Current patience: 1, current trial: 3.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2897
# Validation loss: 263.4488
# Current patience: 0, current trial: 3.
# Running out of patience, loading previous best model.
# Current learning rate: 1e-05
# C:\Users\Saahil\AppData\Local\Temp\ipykernel_29780\1789770977.py:100: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('model.std'))
# C:\Users\Saahil\AppData\Local\Temp\ipykernel_29780\1789770977.py:101: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   optimizer.load_state_dict(torch.load('optim.std'))
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2864
# Validation loss: 263.4464
# Current patience: 8, current trial: 2.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2857
# Validation loss: 263.4455
# Current patience: 7, current trial: 2.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2857
# Validation loss: 263.4453
# Current patience: 8, current trial: 2.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2858
# Validation loss: 263.4454
# Current patience: 8, current trial: 2.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.286
# Validation loss: 263.445
# Current patience: 7, current trial: 2.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.286
# Validation loss: 263.4446
# Current patience: 8, current trial: 2.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.286
# Validation loss: 263.4459
# Current patience: 8, current trial: 2.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2858
# Validation loss: 263.4445
# Current patience: 7, current trial: 2.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2858
# Validation loss: 263.4455
# Current patience: 8, current trial: 2.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2859
# Validation loss: 263.4453
# Current patience: 7, current trial: 2.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2859
# Validation loss: 263.4469
# Current patience: 6, current trial: 2.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2859
# Validation loss: 263.4456
# Current patience: 5, current trial: 2.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2857
# Validation loss: 263.4453
# Current patience: 4, current trial: 2.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2861
# Validation loss: 263.4447
# Current patience: 3, current trial: 2.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2861
# Validation loss: 263.4451
# Current patience: 2, current trial: 2.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2859
# Validation loss: 263.4462
# Current patience: 1, current trial: 2.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2861
# Validation loss: 263.4455
# Current patience: 0, current trial: 2.
# Running out of patience, loading previous best model.
# Current learning rate: 1.0000000000000002e-06
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2856
# Validation loss: 263.4445
# Current patience: 8, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2855
# Validation loss: 263.4445
# Current patience: 7, current trial: 1.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2855
# Validation loss: 263.4445
# Current patience: 8, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2855
# Validation loss: 263.4445
# Current patience: 7, current trial: 1.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4445
# Current patience: 8, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4446
# Current patience: 7, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4445
# Current patience: 6, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4445
# Current patience: 5, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4447
# Current patience: 4, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4445
# Current patience: 3, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4445
# Current patience: 2, current trial: 1.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4445
# Current patience: 8, current trial: 1.
# Found new best model on dev set!
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4445
# Current patience: 8, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4447
# Current patience: 7, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2855
# Validation loss: 263.4447
# Current patience: 6, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2855
# Validation loss: 263.4445
# Current patience: 5, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4445
# Current patience: 4, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4445
# Current patience: 3, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4445
# Current patience: 2, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4445
# Current patience: 1, current trial: 1.
#   0%|          | 0/292 [00:00<?, ?it/s]
# Training loss: 104.2854
# Validation loss: 263.4446
# Current patience: 0, current trial: 1.
# Running out of patience, loading previous best model.
# Current learning rate: 1.0000000000000002e-07
# Running out of patience, early stopping.
# C:\Users\Saahil\AppData\Local\Temp\ipykernel_29780\1789770977.py:110: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('model.std'))
# c:\Users\Saahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\loss.py:101: UserWarning: Using a target size (torch.Size([118, 7])) that is different to the input size (torch.Size([118, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# Test set performance: 302.27976771763394
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 130
#     128 y_true_bin = y_true >= 0
#     129 y_pred_bin = y_pred >= 0
# --> 130 bin_acc = accuracy_score(y_true_bin, y_pred_bin)
#     131 print(f"Test set accuracy is {bin_acc}")
#
# File c:\Users\Saahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\Saahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:213, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     147 """Accuracy classification score.
#     148
#     149 In multilabel classification, this function computes subset accuracy:
#    (...)
#     209 0.5
#     210 """
#     212 # Compute accuracy for each possible representation
# --> 213 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     214 check_consistent_length(y_true, y_pred, sample_weight)
#     215 if y_type.startswith("multilabel"):
#
# File c:\Users\Saahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:94, in _check_targets(y_true, y_pred)
#      91     y_type = {"multiclass"}
#      93 if len(y_type) > 1:
# ---> 94     raise ValueError(
#      95         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      96             type_true, type_pred
#      97         )
#      98     )
#     100 # We can't have more than one value on y_type => The set is no more needed
#     101 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of binary and multilabel-indicator targets

# %%
# from torch.optim import Adam
# from sklearn.metrics import accuracy_score

# torch.manual_seed(123)
# torch.cuda.manual_seed_all(123)

# # Model settings and hyperparameters
# CUDA = torch.cuda.is_available()
# MAX_EPOCH = 1000
# output_size = 7  # Six classes for MOSEI
# model = LFLSTM(input_sizes, hidden_sizes, fc1_size, output_size, dropout)
# if CUDA:
#     model.cuda()

# # Define loss, optimizer, and scheduler
# criterion = nn.CrossEntropyLoss()
# optimizer = Adam(model.parameters(), weight_decay=weight_decay)
# best_valid_loss = float('inf')
# patience = 8
# num_trials = 3
# curr_patience = patience

# for e in range(MAX_EPOCH):
#     model.train()
#     train_loss = 0.0
#     for batch in tqdm_notebook(train_loader):
#         t, v, a, y, l = batch
#         if CUDA:
#             t, v, a, y, l = t.cuda(), v.cuda(), a.cuda(), y.cuda(), l.cuda()

#         optimizer.zero_grad()
#         y_pred = model(t, v, a, l)
#         loss = criterion(y_pred, y.squeeze())  # Cross-entropy expects target in the form [N]
#         loss.backward()
#         optimizer.step()
#         train_loss += loss.item()
#     print(f"Epoch {e}, Training loss: {train_loss / len(train_loader)}")

#     # Validation
#     model.eval()
#     valid_loss = 0.0
#     with torch.no_grad():
#         for batch in dev_loader:
#             t, v, a, y, l = batch
#             if CUDA:
#                 t, v, a, y, l = t.cuda(), v.cuda(), a.cuda(), y.cuda(), l.cuda()

#             y_pred = model(t, v, a, l)
#             y = torch.argmax(y, dim=1).long()
#             loss = criterion(y_pred, y.squeeze())
#             valid_loss += loss.item()
#     valid_loss /= len(dev_loader)
#     print(f"Validation loss: {valid_loss}")

#     # Early stopping
#     if valid_loss < best_valid_loss:
#         best_valid_loss = valid_loss
#         torch.save(model.state_dict(), 'model_best.pt')
#         curr_patience = patience
#     else:
#         curr_patience -= 1
#         if curr_patience <= 0:
#             num_trials -= 1
#             curr_patience = patience
#             model.load_state_dict(torch.load('model_best.pt'))

#     if num_trials <= 0:
#         print("Early stopping.")
#         break

# # Test Evaluation
# model.load_state_dict(torch.load('model_best.pt'))
# model.eval()
# y_true, y_pred = [], []
# with torch.no_grad():
#     for batch in test_loader:
#         t, v, a, y, l = batch
#         if CUDA:
#             t, v, a, y, l = t.cuda(), v.cuda(), a.cuda(), y.cuda(), l.cuda()

#         logits = model(t, v, a, l)
#         predictions = torch.argmax(logits, dim=1).cpu().numpy()  # Predicted class labels
#         y_pred.extend(predictions)
#         y_true.extend(y.cpu().numpy().squeeze())

# # Calculate accuracy
# accuracy = accuracy_score(y_true, y_pred)
# print(f"Test set accuracy: {accuracy}")

# # Print sample predictions
# labels = {0: "Happy", 1: "Sad", 2: "Anger", 3: "Surprise", 4: "Disgust", 5: "Fear"}
# for i, pred in enumerate(y_pred[:5]):  # Print a few sample predictions
#     print(f"Predicted Label: {pred}, Corresponding Class: {labels[pred]}")

# %%
from torch.optim import Adam
from sklearn.metrics import accuracy_score

torch.manual_seed(123)

# Model settings and hyperparameters
MAX_EPOCH = 1000
output_size = 7  
model = LFLSTM(input_sizes, hidden_sizes, fc1_size, output_size, dropout)

# Define loss, optimizer, and scheduler
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), weight_decay=weight_decay)
best_valid_loss = float('inf')
patience = 8
num_trials = 3
curr_patience = patience

for e in range(MAX_EPOCH):
    model.train()
    train_loss = 0.0
    for batch in tqdm_notebook(train_loader):
        t, v, a, y, l = batch
        if CUDA:
            t, v, a, y, l = t.cuda(), v.cuda(), a.cuda(), y.cuda(), l.cuda()

        optimizer.zero_grad()
        y_pred = model(t, v, a, l)

        # Ensure `y` is a 1D tensor with integer class labels
        y = torch.argmax(y, dim=1).long()
        
        loss = criterion(y_pred, y)  # CrossEntropyLoss expects target as [batch_size]
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    print(f"Epoch {e}, Training loss: {train_loss / len(train_loader)}")


    # Validation
    model.eval()
    valid_loss = 0.0
    with torch.no_grad():
        for batch in dev_loader:
            t, v, a, y, l = batch

            y_pred = model(t, v, a, l)
            loss = criterion(y_pred, y.squeeze())
            valid_loss += loss.item()
    valid_loss /= len(dev_loader)
    print(f"Validation loss: {valid_loss}")

    # Early stopping
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'model_best.pt')
        curr_patience = patience
    else:
        curr_patience -= 1
        if curr_patience <= 0:
            num_trials -= 1
            curr_patience = patience
            model.load_state_dict(torch.load('model_best.pt'))

    if num_trials <= 0:
        print("Early stopping.")
        break

# Test Evaluation
model.load_state_dict(torch.load('model_best.pt'))
model.eval()
y_true, y_pred = [], []
with torch.no_grad():
    for batch in test_loader:
        t, v, a, y, l = batch

        logits = model(t, v, a, l)
        predictions = torch.argmax(logits, dim=1).numpy()  # Predicted class labels
        y_pred.extend(predictions)
        y_true.extend(y.numpy().squeeze())

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"Test set accuracy: {accuracy}")

# Print sample predictions
labels = {0: "Happy", 1: "Sad", 2: "Anger", 3: "Surprise", 4: "Disgust", 5: "Fear"}
for i, pred in enumerate(y_pred[:5]):  # Print a few sample predictions
    print(f"Predicted Label: {pred}, Corresponding Class: {labels[pred]}")
# Out:
# C:\Users\Saahil\AppData\Local\Temp\ipykernel_29780\3499872413.py:22: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for batch in tqdm_notebook(train_loader):
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 0, Training loss: 1.5417299005266738
# Validation loss: 1.9466325640678406
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 1, Training loss: 1.5254446737570306
# Validation loss: 1.9445278942584991
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 2, Training loss: 1.5261231146446645
# Validation loss: 1.9785599410533905
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 3, Training loss: 1.5370414644888002
# Validation loss: 1.9277793268362682
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 4, Training loss: 1.5420455430468467
# Validation loss: 1.910531481107076
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 5, Training loss: 1.5411946291792882
# Validation loss: 1.9197011987368267
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 6, Training loss: 1.5301286496528208
# Validation loss: 1.9315890272458394
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 7, Training loss: 1.5385510223369077
# Validation loss: 1.939244528611501
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 8, Training loss: 1.5495178711740938
# Validation loss: 1.9653646349906921
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 9, Training loss: 1.5604674228250164
# Validation loss: 1.9671567976474762
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 10, Training loss: 1.5626854569944617
# Validation loss: 1.9730343619982402
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 11, Training loss: 1.5615409335044965
# Validation loss: 1.9723345736662548
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 12, Training loss: 1.5625904516814506
# Validation loss: 1.9648740788300831
# C:\Users\Saahil\AppData\Local\Temp\ipykernel_29780\3499872413.py:63: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('model_best.pt'))
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 13, Training loss: 1.5564843612174466
# Validation loss: 1.9739822149276733
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 14, Training loss: 1.5615766252556893
# Validation loss: 1.9720546404520671
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 15, Training loss: 1.5622159291620124
# Validation loss: 1.9646567503611247
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 16, Training loss: 1.5614457697901007
# Validation loss: 1.9769028723239899
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 17, Training loss: 1.562521610766241
# Validation loss: 1.9622259140014648
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 18, Training loss: 1.5627142909454972
# Validation loss: 1.9781807561715443
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 19, Training loss: 1.562657409334836
# Validation loss: 1.9646568695704143
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 20, Training loss: 1.5630605257537267
# Validation loss: 1.9689100881417592
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 21, Training loss: 1.5634722142186883
# Validation loss: 1.9828787843386333
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 22, Training loss: 1.5616856809348276
# Validation loss: 1.989474594593048
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 23, Training loss: 1.5627455952232832
# Validation loss: 1.969591091076533
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 24, Training loss: 1.5618079394510347
# Validation loss: 1.9742011725902557
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 25, Training loss: 1.5621826828342595
# Validation loss: 1.9806284805138905
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 26, Training loss: 1.5630036714958817
# Validation loss: 1.9829756617546082
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 27, Training loss: 1.5623362321559697
# Validation loss: 1.9831279913584392
#   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 28, Training loss: 1.5624813992683202
# Validation loss: 1.969900220632553
# Early stopping.
# C:\Users\Saahil\AppData\Local\Temp\ipykernel_29780\3499872413.py:70: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('model_best.pt'))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 83
#      80         y_true.extend(y.numpy().squeeze())
#      82 # Calculate accuracy
# ---> 83 accuracy = accuracy_score(y_true, y_pred)
#      84 print(f"Test set accuracy: {accuracy}")
#      86 # Print sample predictions
#
# File c:\Users\Saahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\Saahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:213, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     147 """Accuracy classification score.
#     148
#     149 In multilabel classification, this function computes subset accuracy:
#    (...)
#     209 0.5
#     210 """
#     212 # Compute accuracy for each possible representation
# --> 213 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     214 check_consistent_length(y_true, y_pred, sample_weight)
#     215 if y_type.startswith("multilabel"):
#
# File c:\Users\Saahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:94, in _check_targets(y_true, y_pred)
#      91     y_type = {"multiclass"}
#      93 if len(y_type) > 1:
# ---> 94     raise ValueError(
#      95         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      96             type_true, type_pred
#      97         )
#      98     )
#     100 # We can't have more than one value on y_type => The set is no more needed
#     101 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of continuous-multioutput and binary targets

# %%
print(f"y_pred shape: {y_pred.shape}")  # Should be [batch_size, num_classes]
print(f"y shape after squeeze: {y.squeeze().shape}")  # Should be [batch_size]
print("Min label:", y.min().item(), "Max label:", y.max().item())
# Out:
# y_pred shape: torch.Size([56, 6])
# y shape after squeeze: torch.Size([56])
# Min label: 0 Max label: 6

# %%
# Test Evaluation
model.load_state_dict(torch.load('model_best.pt'))
model.eval()
y_true, y_pred = [], []

with torch.no_grad():
    for batch in test_loader:
        t, v, a, y, l = batch
        if CUDA:
            t, v, a, y, l = t.cuda(), v.cuda(), a.cuda(), y.cuda(), l.cuda()

        logits = model(t, v, a, l)
        predictions = torch.argmax(logits, dim=1).cpu().numpy()  # Predicted class labels

        # Convert `y` to 1D and ensure it's integer labels only
        y_true_labels = torch.argmax(y, dim=1).cpu().numpy() if y.dim() > 1 else y.cpu().numpy()

        y_pred.extend(predictions)
        y_true.extend(y_true_labels)

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"Test set accuracy: {accuracy}")

# Print sample predictions with class mapping
labels = {0: "Happy", 1: "Sad", 2: "Anger", 3: "Surprise", 4: "Disgust", 5: "Fear", 6: "Neutral"}
for i, pred in enumerate(y_pred[:5]):  # Print a few sample predictions
    print(f"Predicted Label: {pred}, Corresponding Class: {labels[pred]}")
# Out:
# C:\Users\Saahil\AppData\Local\Temp\ipykernel_29780\710645046.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('model_best.pt'))
# Test set accuracy: 0.4351095831542759
# Predicted Label: 0, Corresponding Class: Happy
# Predicted Label: 0, Corresponding Class: Happy
# Predicted Label: 0, Corresponding Class: Happy
# Predicted Label: 0, Corresponding Class: Happy
# Predicted Label: 0, Corresponding Class: Happy

# %% [markdown]
# ## Enhanced LSTM

# %%
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

class EnhancedLFLSTM(nn.Module):
    def __init__(self, input_sizes, hidden_sizes, fc1_size, output_size, dropout_rate):
        super(EnhancedLFLSTM, self).__init__()
        self.input_size = input_sizes
        self.hidden_size = hidden_sizes
        self.fc1_size = fc1_size
        self.output_size = output_size
        self.dropout_rate = dropout_rate

        # Define the RNN layers for each modality
        self.embed = nn.Embedding(len(word2id), input_sizes[0])
        self.trnn1 = nn.LSTM(input_sizes[0], hidden_sizes[0], bidirectional=True)
        self.trnn2 = nn.LSTM(2 * hidden_sizes[0], hidden_sizes[0], bidirectional=True)
        
        self.vrnn1 = nn.LSTM(input_sizes[1], hidden_sizes[1], bidirectional=True)
        self.vrnn2 = nn.LSTM(2 * hidden_sizes[1], hidden_sizes[1], bidirectional=True)
        
        self.arnn1 = nn.LSTM(input_sizes[2], hidden_sizes[2], bidirectional=True)
        self.arnn2 = nn.LSTM(2 * hidden_sizes[2], hidden_sizes[2], bidirectional=True)

        # Define fully connected layers for fusion and classification
        self.fc1 = None  # Initialized dynamically based on fusion_size in fusion()
        self.fc2 = nn.Linear(fc1_size, output_size)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)

        # Layer normalization for each modality
        self.tlayer_norm = nn.LayerNorm(hidden_sizes[0] * 2)
        self.vlayer_norm = nn.LayerNorm(hidden_sizes[1] * 2)
        self.alayer_norm = nn.LayerNorm(hidden_sizes[2] * 2)
        
        # Initialize BatchNorm1d to None - we'll set it dynamically in `fusion`
        self.bn = None

    def extract_features(self, sequence, lengths, rnn1, rnn2, layer_norm):
        packed_sequence = pack_padded_sequence(sequence, lengths, enforce_sorted=False)
        packed_h1, (final_h1, _) = rnn1(packed_sequence)
        padded_h1, _ = pad_packed_sequence(packed_h1)
        normed_h1 = layer_norm(padded_h1)
        packed_normed_h1 = pack_padded_sequence(normed_h1, lengths, enforce_sorted=False)
        _, (final_h2, _) = rnn2(packed_normed_h1)
        return final_h1, final_h2

    def fusion(self, sentences, visual, acoustic, lengths):
        batch_size = lengths.size(0)
        sentences = self.embed(sentences)

        # Extract features from each modality
        final_h1t, final_h2t = self.extract_features(sentences, lengths, self.trnn1, self.trnn2, self.tlayer_norm)
        final_h1v, final_h2v = self.extract_features(visual, lengths, self.vrnn1, self.vrnn2, self.vlayer_norm)
        final_h1a, final_h2a = self.extract_features(acoustic, lengths, self.arnn1, self.arnn2, self.alayer_norm)

        # Concatenate modality outputs and print sizes to verify
        h = torch.cat((final_h1t, final_h2t, final_h1v, final_h2v, final_h1a, final_h2a), dim=2).permute(1, 0, 2).contiguous().view(batch_size, -1)
        fusion_size = h.size(1)  # Dynamically calculate fusion size
        # print(f"Concatenated feature size (batch_size, fusion_size): {h.size()}")  # Debugging print

        # Dynamically initialize BatchNorm1d based on fusion size, if not already initialized
        if self.bn is None or self.bn.num_features != fusion_size:
            self.bn = nn.BatchNorm1d(fusion_size).to(h.device)
            # print(f"BatchNorm initialized with num_features={fusion_size}")  # Debugging print

        # Dynamically initialize fc1 layer based on fusion_size
        if self.fc1 is None or self.fc1.in_features != fusion_size:
            self.fc1 = nn.Linear(fusion_size, self.fc1_size).to(h.device)
            # print(f"fc1 initialized with in_features={fusion_size}, out_features={self.fc1_size}")  # Debugging print

        h = self.bn(h)  # Apply batch normalization
        return h

    def forward(self, sentences, visual, acoustic, lengths):
        batch_size = lengths.size(0)
        h = self.fusion(sentences, visual, acoustic, lengths)
        h = self.fc1(h)
        h = self.dropout(h)
        h = self.relu(h)
        o = self.fc2(h)  # Final output layer with seven classes
        return o

# %%
from torch.optim import Adam
from sklearn.metrics import accuracy_score
import torch

torch.manual_seed(123)

text_size = 300
visual_size = 35
acoustic_size = 74

# Define model settings and hyper-parameters
input_sizes = [text_size, visual_size, acoustic_size]
hidden_sizes = [int(text_size * 1.5), int(visual_size * 1.5), int(acoustic_size * 1.5)]
fc1_size = sum(hidden_sizes) // 2
dropout = 0.25
curr_patience = patience = 8
num_trials = 3
grad_clip_value = 1.0
weight_decay = 0.1

# Load embeddings if available
if os.path.exists(CACHE_PATH):
    pretrained_emb, word2id = torch.load(CACHE_PATH)
elif WORD_EMB_PATH is not None:
    pretrained_emb = load_emb(word2id, WORD_EMB_PATH)
    torch.save((pretrained_emb, word2id), CACHE_PATH)
else:
    pretrained_emb = None

# Model settings and hyperparameters
MAX_EPOCH = 1000
output_size = 7  
model = EnhancedLFLSTM(input_sizes, hidden_sizes, fc1_size, output_size, dropout)

# Move model to CUDA if available
if CUDA:
    model.cuda()

# Define loss, optimizer, and scheduler
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=0.0005, weight_decay=0.01)
best_valid_loss = float('inf')
patience = 8
num_trials = 3
curr_patience = patience

for epoch in range(MAX_EPOCH):
    model.train()
    train_loss = 0.0
    for batch in tqdm_notebook(train_loader, desc=f"Epoch {epoch+1}/{MAX_EPOCH}"):
        t, v, a, y, l = batch
        if CUDA:
            t, v, a, y, l = t.cuda(), v.cuda(), a.cuda(), y.cuda(), l.cuda()

        optimizer.zero_grad()
        y_pred = model(t, v, a, l)

        # Ensure `y` is a 1D tensor with integer class labels
        y = torch.argmax(y, dim=1).long()
        
        loss = criterion(y_pred, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    print(f"Epoch {epoch+1}, Training Loss: {train_loss:.4f}")

    # Validation
    model.eval()
    valid_loss = 0.0
    with torch.no_grad():
        for batch in dev_loader:
            t, v, a, y, l = batch
            if CUDA:
                t, v, a, y, l = t.cuda(), v.cuda(), a.cuda(), y.cuda(), l.cuda()

            y_pred = model(t, v, a, l)
            y = torch.argmax(y, dim=1).long()  # Convert labels to 1D
            loss = criterion(y_pred, y)
            valid_loss += loss.item()
    valid_loss /= len(dev_loader)
    print(f"Validation Loss: {valid_loss:.4f}")
    print(f"Current Patience: {curr_patience}, Trials Left: {num_trials}")

    # Early stopping
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'model_best_enhanced.pt')
        curr_patience = patience
        print("New best model found and saved.")
    else:
        curr_patience -= 1
        if curr_patience <= 0:
            num_trials -= 1
            curr_patience = patience
            model.load_state_dict(torch.load('model_best_enhanced.pt'))
            print("Patience exhausted. Loading best model and reducing learning rate.")
            for g in optimizer.param_groups:
                g['lr'] = g['lr'] * 0.5  # Halve learning rate

    if num_trials <= 0:
        print("Early stopping triggered. Ending training.")
        break

# Test Evaluation
model.load_state_dict(torch.load('model_best_enhanced.pt'))
model.eval()
y_true, y_pred = [], []
with torch.no_grad():
    for batch in test_loader:
        t, v, a, y, l = batch
        if CUDA:
            t, v, a, y, l = t.cuda(), v.cuda(), a.cuda(), y.cuda(), l.cuda()

        logits = model(t, v, a, l)
        predictions = torch.argmax(logits, dim=1).cpu().numpy()  # Predicted class labels
        y_pred.extend(predictions)
        y_true.extend(y.cpu().numpy().squeeze())

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"Test Set Accuracy: {accuracy:.4f}")

# Print sample predictions
labels = {0: "Happy", 1: "Sad", 2: "Anger", 3: "Surprise", 4: "Disgust", 5: "Fear", 6: "Neutral"}
for i, pred in enumerate(y_pred[:5]):  # Print a few sample predictions
    print(f"Predicted Label: {pred}, Corresponding Class: {labels[pred]}")
# Out:
# C:\Users\Saahil\AppData\Local\Temp\ipykernel_29780\2434773897.py:50: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for batch in tqdm_notebook(train_loader, desc=f"Epoch {epoch+1}/{MAX_EPOCH}"):
# Epoch 1/1000:   0%|          | 0/292 [00:00<?, ?it/s]
