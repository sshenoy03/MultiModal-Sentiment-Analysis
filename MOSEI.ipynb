# %%
from constants import SDK_PATH, DATA_PATH, WORD_EMB_PATH, CACHE_PATH
import sys
import os
import requests
import numpy as np
from mmsdk import mmdatasdk as md

# Append the SDK path
if SDK_PATH is None:
    print("SDK path is not specified! Please specify first in constants/paths.py")
    exit(0)
else:
    sys.path.append(SDK_PATH)

# Create folder for storing data if it doesn't exist
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH, exist_ok=True)

# Helper function to download a file from a URL
def download_file(url, dest):
    try:
        print(f"Downloading from {url}...")
        response = requests.get(url, stream=True)
        response.raise_for_status()
        with open(dest, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"Downloaded: {dest}")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading {url}: {e}")

# Function to get the filename from the URL (last segment)
def get_filename_from_url(url):
    return url.split('/')[-1]  # Extract the last part of the URL

# Download function that iterates over dataset features
def download_dataset_features(feature_dict, feature_type):
    for feature_name, url in feature_dict.items():
        print(f"\nProcessing {feature_type} feature: {feature_name}")
        
        # Use the filename derived from the URL instead of the dictionary key
        filename = get_filename_from_url(url)
        dest_path = os.path.join(DATA_PATH, filename)

        if not os.path.exists(dest_path):
            download_file(url, dest_path)
        else:
            print(f"{feature_type} feature '{feature_name}' already downloaded at {dest_path}")

# Dataset initialization
DATASET = md.cmu_mosei

# Process high-level, raw, and label features
try:
    print("\nStarting download of high-level features...")
    download_dataset_features(DATASET.highlevel, "High-level")
except Exception as e:
    print(f"Error downloading high-level features: {e}")

try:
    print("\nStarting download of raw features...")
    download_dataset_features(DATASET.raw, "Raw")
except Exception as e:
    print(f"Error downloading raw features: {e}")

try:
    print("\nStarting download of labels...")
    download_dataset_features(DATASET.labels, "Label")
except Exception as e:
    print(f"Error downloading labels: {e}")
# Out:
# Starting download of high-level features...
#
# Processing High-level feature: glove_vectors
# High-level feature 'glove_vectors' already downloaded at ./data/CMU_MOSEI_TimestampedWordVectors.csd
#
# Processing High-level feature: COVAREP
# High-level feature 'COVAREP' already downloaded at ./data/CMU_MOSEI_COVAREP.csd
#
# Processing High-level feature: OpenFace_2
# High-level feature 'OpenFace_2' already downloaded at ./data/CMU_MOSEI_VisualOpenFace2.csd
#
# Processing High-level feature: FACET 4.2
# High-level feature 'FACET 4.2' already downloaded at ./data/CMU_MOSEI_VisualFacet42.csd
#
# Starting download of raw features...
#
# Processing Raw feature: words
# Raw feature 'words' already downloaded at ./data/CMU_MOSEI_TimestampedWords.csd
#
# Processing Raw feature: phones
# Raw feature 'phones' already downloaded at ./data/CMU_MOSEI_TimestampedPhones.csd
#
# Starting download of labels...
#
# Processing Label feature: All Labels
# Label feature 'All Labels' already downloaded at ./data/CMU_MOSEI_Labels.csd

# %%
# list the directory contents... let's see what features there are
data_files = os.listdir(DATA_PATH)
print('\n'.join(data_files))
# Out:
# CMU_MOSEI_COVAREP.csd
# CMU_MOSEI_Labels.csd
# CMU_MOSEI_TimestampedPhones.csd
# CMU_MOSEI_TimestampedWords.csd
# CMU_MOSEI_TimestampedWordVectors.csd
# CMU_MOSEI_VisualFacet42.csd
# CMU_MOSEI_VisualOpenFace2.csd

# %% [markdown]
# We have multiple files which can be broadly classified into three categories, highlevel, raw and labels.
#
# <strong>Highlevel</strong> contains the extracted features for each modality (e.g OpenFace facial landmarks, openSMILE acoustic features) while <strong>raw</strong> contains the raw transctripts, phonemes.
#
# We have multiple files with the .csd extension. This stands for <strong>computational sequences</strong>, which is the underlying data structure for all features in the SDK.
#
# <strong> Highlevel features: </strong>
# - CMU_MOSEI_VisualFacet42.csd (Video modality)
# - CMU_MOSEI_VisualOpenFace2.csd (Video Modality)
# - CMU_MOSEI_COVAREP.csd (Audio Modality)
# - CMU_MOSEI_TimestampedWordVectors.csd (Text Modality)

# %% [markdown]
# ## Loading the data

# %%
visual_field = 'CMU_MOSEI_VisualFacet42'
acoustic_field = 'CMU_MOSEI_COVAREP'
text_field = 'CMU_MOSEI_TimestampedWordVectors'

features = [
    text_field, 
    visual_field, 
    acoustic_field
]

recipe = {feat: os.path.join(DATA_PATH, feat) + '.csd' for feat in features}
dataset = md.mmdataset(recipe)
# Out:
# [2024-10-31 13:31:01.470] | Success | Computational sequence read from file ./data/CMU_MOSEI_TimestampedWordVectors.csd ...
# [2024-10-31 13:31:01.577] | Status  | Checking the integrity of the <glove_vectors> computational sequence ...
# [2024-10-31 13:31:01.577] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2024-10-31 13:31:02.695] | Success | <glove_vectors> computational sequence data in correct format.
# [2024-10-31 13:31:02.695] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2024-10-31 13:31:02.695] | Warning | <glove_vectors> computational sequence does not have all the required metadata ... continuing
# [2024-10-31 13:31:02.696] | Success | Computational sequence read from file ./data/CMU_MOSEI_VisualFacet42.csd ...
# [2024-10-31 13:31:02.775] | Status  | Checking the integrity of the <FACET 4.2> computational sequence ...
# [2024-10-31 13:31:02.775] | Status  | Checking the format of the data in <FACET 4.2> computational sequence ...
# [2024-10-31 13:31:03.897] | Success | <FACET 4.2> computational sequence data in correct format.
# [2024-10-31 13:31:03.897] | Status  | Checking the format of the metadata in <FACET 4.2> computational sequence ...
# [2024-10-31 13:31:03.898] | Warning | <FACET 4.2> computational sequence does not have all the required metadata ... continuing
# [2024-10-31 13:31:03.898] | Success | Computational sequence read from file ./data/CMU_MOSEI_COVAREP.csd ...
# [2024-10-31 13:31:03.968] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2024-10-31 13:31:03.968] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2024-10-31 13:31:05.092] | Success | <COVAREP> computational sequence data in correct format.
# [2024-10-31 13:31:05.092] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2024-10-31 13:31:05.092] | Warning | <COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-10-31 13:31:05.093] | Success | Dataset initialized successfully ...

# %% [markdown]
# To load the dataset, we need to tell the SDK which features we need and where they exist. Thus, we construct a dictionary with format {feature_name: csd_path} and feed it to mmdataset object in the SDK.
#
# From the highlevel features, VisualFacet is used for video modality since this file stores facial expression data extracted using the FACET tool. FACET analyzes microexpressions, including movements of facial muscles (like eyebrow raises or smiles) and emotional states (e.g., joy, anger). Thus, making it more suitable for emotion detection than openFace since it
# tracks facial landmarks, head poses, and eye gaze, offering detailed spatial and motion-related facial features across video frames.
#
# COVAREP is used for audio related features and TimeStampedWordVectors provides Pre-trained embeddings using GLoVe capture semantic relationships and contextual meaning between words.

# %%
print(list(dataset.keys()))
print("=" * 80)

print(list(dataset[visual_field].keys())[:10])
print("=" * 80)

some_id = list(dataset[visual_field].keys())[15]
print(list(dataset[visual_field][some_id].keys()))
print("=" * 80)

print(list(dataset[visual_field][some_id]['intervals'].shape))
print("=" * 80)

print(list(dataset[visual_field][some_id]['features'].shape))
print(list(dataset[text_field][some_id]['features'].shape))
print(list(dataset[acoustic_field][some_id]['features'].shape))
print("Different modalities have different number of time steps!")
# Out:
# ['CMU_MOSEI_TimestampedWordVectors', 'CMU_MOSEI_VisualFacet42', 'CMU_MOSEI_COVAREP']
# ================================================================================
# ['--qXJuDtHPw', '-3g5yACwYnA', '-3nNcZdcdvU', '-571d8cVauQ', '-6rXp3zJ3kc', '-9YyBTjo1zo', '-9y-fZ3swSY', '-AUZQgSxyPQ', '-Alixo7euuU', '-Eqdz5y4pEY']
# ================================================================================
# ['features', 'intervals']
# ================================================================================
# [3658, 2]
# ================================================================================
# [3658, 35]
# [321, 300]
# [12209, 74]
# Different modalities have different number of time steps!

# %%
# we define a simple averaging function that does not depend on intervals
def avg(intervals: np.array, features: np.array) -> np.array:
    try:
        return np.average(features, axis=0)
    except:
        return features

# first we align to words with averaging, collapse_function receives a list of functions
dataset.align(text_field, collapse_functions=[avg])
# Out:
# [2024-10-31 13:31:39.088] | Status  | Unify was called ...
# [2024-10-31 13:31:39.091] | Warning | PEBwwe0PLZ8 entry is not shared among all sequences, removing it ...
# [2024-10-31 13:31:39.094] | Success | Unify completed ...
# [2024-10-31 13:31:39.094] | Status  | Pre-alignment based on <CMU_MOSEI_TimestampedWordVectors> computational sequence started ...
# [2024-10-31 13:38:03.268] | Status  | Pre-alignment done for <CMU_MOSEI_COVAREP> ...
# [2024-10-31 13:40:58.221] | Status  | Pre-alignment done for <CMU_MOSEI_VisualFacet42> ...
# [2024-10-31 13:43:30.298] | Status  | Alignment starting ...
# [2024-10-31 15:25:37.358] | Success | Alignment to <CMU_MOSEI_TimestampedWordVectors> complete.
# [2024-10-31 15:25:37.359] | Status  | Replacing dataset content with aligned computational sequences
# [2024-10-31 15:25:41.778] | Success | Initialized empty <CMU_MOSEI_TimestampedWordVectors> computational sequence.
# [2024-10-31 15:25:41.779] | Status  | Checking the format of the data in <CMU_MOSEI_TimestampedWordVectors> computational sequence ...
# [2024-10-31 15:25:46.417] | Success | <CMU_MOSEI_TimestampedWordVectors> computational sequence data in correct format.
# [2024-10-31 15:25:46.417] | Status  | Checking the format of the metadata in <CMU_MOSEI_TimestampedWordVectors> computational sequence ...
# [2024-10-31 15:25:46.417] | Warning | <CMU_MOSEI_TimestampedWordVectors> computational sequence does not have all the required metadata ... continuing
# [2024-10-31 15:25:46.417] | Success | Initialized empty <CMU_MOSEI_VisualFacet42> computational sequence.
# [2024-10-31 15:25:46.417] | Status  | Checking the format of the data in <CMU_MOSEI_VisualFacet42> computational sequence ...
# [2024-10-31 15:25:47.704] | Success | <CMU_MOSEI_VisualFacet42> computational sequence data in correct format.
# [2024-10-31 15:25:47.704] | Status  | Checking the format of the metadata in <CMU_MOSEI_VisualFacet42> computational sequence ...
# [2024-10-31 15:25:47.704] | Warning | <CMU_MOSEI_VisualFacet42> computational sequence does not have all the required metadata ... continuing
# [2024-10-31 15:25:47.704] | Success | Initialized empty <CMU_MOSEI_COVAREP> computational sequence.
# [2024-10-31 15:25:47.704] | Status  | Checking the format of the data in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-10-31 15:25:48.884] | Success | <CMU_MOSEI_COVAREP> computational sequence data in correct format.
# [2024-10-31 15:25:48.886] | Status  | Checking the format of the metadata in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-10-31 15:25:48.886] | Warning | <CMU_MOSEI_COVAREP> computational sequence does not have all the required metadata ... continuing

# %%
label_field = 'CMU_MOSEI_Labels'

# we add and align to lables to obtain labeled segments
# this time we don't apply collapse functions so that the temporal sequences are preserved
label_recipe = {label_field: os.path.join(DATA_PATH, label_field + '.csd')}
dataset.add_computational_sequences(label_recipe, destination=None)
dataset.align(label_field)
# Out:
# [2024-10-31 15:49:20.385] | Success | Computational sequence read from file ./data/CMU_MOSEI_Labels.csd ...
# [2024-10-31 15:49:21.093] | Status  | Checking the integrity of the <All Labels> computational sequence ...
# [2024-10-31 15:49:21.094] | Status  | Checking the format of the data in <All Labels> computational sequence ...
# [2024-10-31 15:49:22.615] | Success | <All Labels> computational sequence data in correct format.
# [2024-10-31 15:49:22.615] | Status  | Checking the format of the metadata in <All Labels> computational sequence ...
# [2024-10-31 15:49:22.615] | Warning | <All Labels> computational sequence does not have all the required metadata ... continuing
# [2024-10-31 15:49:22.615] | Status  | Unify was called ...
# [2024-10-31 15:49:23.914] | Warning | 84670 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:24.375] | Warning | 246117 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:24.825] | Warning | 201980 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:25.274] | Warning | PEBwwe0PLZ8 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:25.707] | Warning | eLjNLHkvxH4 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:26.140] | Warning | 282985 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:26.605] | Warning | 120342 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:27.055] | Warning | 160225 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:27.513] | Warning | 199227 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:27.962] | Warning | 243797 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:28.412] | Warning | 111734 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:28.861] | Warning | 69268 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:29.307] | Warning | 215343 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:29.756] | Warning | 204792 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:30.207] | Warning | 76104 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:30.651] | Warning | 239180 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:31.100] | Warning | 204519 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:31.555] | Warning | 216831 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:32.008] | Warning | 223333 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:32.457] | Warning | 48300 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:32.904] | Warning | 104739 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:33.352] | Warning | 113491 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:33.795] | Warning | 224325 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:34.246] | Warning | 201497 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:34.693] | Warning | 69234 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:35.138] | Warning | 254488 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:35.583] | Warning | 58795 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:36.026] | Warning | dZFV0lyedX4 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:36.455] | Warning | 41026 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:36.901] | Warning | 95887 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:37.352] | Warning | 137455 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:37.798] | Warning | 172050 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:38.242] | Warning | 239242 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:38.686] | Warning | 178941 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:39.136] | Warning | 193924 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:39.578] | Warning | 102534 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:40.026] | Warning | 18938 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:40.470] | Warning | 89184 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:40.908] | Warning | 238567 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:41.359] | Warning | 81707 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:41.804] | Warning | 219350 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:42.251] | Warning | 113162 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:42.702] | Warning | 82666 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:43.149] | Warning | 116221 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:43.592] | Warning | 32459 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:44.032] | Warning | 66505 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:44.472] | Warning | 236108 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:44.924] | Warning | 30646 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:45.365] | Warning | 100232 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:45.810] | Warning | 60405 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:46.252] | Warning | 134298 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:46.698] | Warning | 61035 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:47.133] | Warning | 90667 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:47.573] | Warning | 125868 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:48.013] | Warning | 111363 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:48.457] | Warning | 207118 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:48.896] | Warning | 137920 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:49.339] | Warning | 30858 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:49.785] | Warning | 220832 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:50.229] | Warning | 127622 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:50.664] | Warning | 188815 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:51.111] | Warning | 237385 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:51.558] | Warning | 88077 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:52.003] | Warning | 49029 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:52.458] | Warning | 233405 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:52.907] | Warning | 43342 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:53.350] | Warning | 101880 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:53.792] | Warning | 76819 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:54.226] | Warning | 71987 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:54.662] | Warning | 36116 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:55.101] | Warning | 40129 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:55.549] | Warning | 245207 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:55.996] | Warning | 101708 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:56.437] | Warning | 91252 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:56.869] | Warning | 42426 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:57.306] | Warning | 90008 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:57.745] | Warning | 61557 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:58.179] | Warning | 79203 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:58.646] | Warning | 266861 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:59.095] | Warning | 199215 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:59.533] | Warning | 28191 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:49:59.975] | Warning | 132476 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:00.426] | Warning | 59712 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:00.859] | Warning | 28182 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:01.293] | Warning | 183364 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:01.734] | Warning | 44457 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:02.176] | Warning | 17622 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:02.616] | Warning | 251251 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:03.063] | Warning | 114016 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:03.505] | Warning | 158855 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:03.944] | Warning | 95147 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:04.373] | Warning | 30762 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:04.818] | Warning | 22277 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:05.250] | Warning | 107182 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:05.697] | Warning | 224472 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:06.144] | Warning | 258672 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:06.588] | Warning | 88881 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:07.037] | Warning | 275603 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:07.483] | Warning | 27857 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:07.923] | Warning | 228925 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:08.373] | Warning | 535523 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:08.814] | Warning | 187033 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:09.254] | Warning | 61277 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:09.693] | Warning | 290062 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:10.127] | Warning | 36060 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:10.567] | Warning | 250343 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:11.001] | Warning | 74115 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:11.430] | Warning | 270771 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:11.868] | Warning | 226602 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:12.311] | Warning | 116202 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:12.760] | Warning | 172075 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:13.198] | Warning | 176266 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:13.628] | Warning | 27863 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:14.064] | Warning | 193921 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:14.510] | Warning | 112674 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:14.940] | Warning | 50444 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:15.371] | Warning | 110209 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:15.820] | Warning | 98636 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:16.249] | Warning | 22719 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:16.681] | Warning | 96377 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:17.111] | Warning | 97908 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:17.537] | Warning | 268536 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:17.974] | Warning | 224649 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:18.407] | Warning | 97076 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:18.841] | Warning | 323217 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:19.286] | Warning | 101733 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:19.724] | Warning | 48019 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:20.180] | Warning | 21844 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:20.624] | Warning | 96595 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:21.067] | Warning | 265811 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:21.521] | Warning | 105537 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:21.958] | Warning | 234406 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:22.423] | Warning | 30171 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:22.859] | Warning | 299754 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:23.298] | Warning | 98155 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:23.730] | Warning | 60402 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:24.159] | Warning | 95388 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:24.586] | Warning | 58151 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:25.014] | Warning | 262341 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:25.449] | Warning | 187775 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:25.889] | Warning | 279373 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:26.323] | Warning | 101635 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:26.762] | Warning | 58097 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:27.190] | Warning | 265302 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:27.630] | Warning | 108573 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:28.064] | Warning | 106973 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:28.499] | Warning | 16530 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:28.931] | Warning | 30036 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:29.360] | Warning | 298459 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:29.792] | Warning | 98513 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:30.212] | Warning | 193514 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:30.649] | Warning | 276771 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:31.082] | Warning | 224271 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:31.521] | Warning | 98562 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:31.949] | Warning | 74447 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:32.381] | Warning | 46808 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:32.820] | Warning | 42946 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:33.244] | Warning | 223338 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:33.679] | Warning | 50302 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:34.103] | Warning | 274917 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:34.531] | Warning | 84772 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:34.960] | Warning | 172044 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:35.402] | Warning | 29758 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:35.833] | Warning | 190599 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:36.266] | Warning | 46860 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:36.691] | Warning | 78752 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:37.122] | Warning | 158832 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:37.549] | Warning | 109524 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:37.988] | Warning | 221104 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:38.426] | Warning | 280794 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:38.863] | Warning | 46826 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:39.289] | Warning | 103311 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:39.721] | Warning | 191616 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:40.162] | Warning | 207977 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:40.582] | Warning | 50306 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:41.009] | Warning | 35692 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:41.451] | Warning | 74197 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:41.877] | Warning | 247764 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:42.316] | Warning | 208465 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:42.750] | Warning | 229296 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:43.183] | Warning | 222510 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:43.608] | Warning | 21727 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:44.033] | Warning | 113369 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:44.463] | Warning | 81563 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:44.888] | Warning | 98649 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:45.309] | Warning | 181978 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:45.738] | Warning | 246789 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:46.184] | Warning | 46663 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:46.609] | Warning | 140315 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:47.039] | Warning | 109909 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:47.465] | Warning | 56853 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:47.891] | Warning | 97289 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:48.312] | Warning | 93807 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:48.738] | Warning | 327282 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:49.169] | Warning | 210098 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:49.607] | Warning | 97463 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:50.028] | Warning | 196665 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:50.461] | Warning | 58554 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:50.887] | Warning | 255205 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:51.327] | Warning | 196364 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:51.758] | Warning | 111104 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:52.187] | Warning | 267092 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:52.619] | Warning | 89266 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:53.048] | Warning | 96700 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:53.467] | Warning | 34989 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:53.897] | Warning | 247108 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:54.319] | Warning | 238858 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:54.748] | Warning | 219620 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:55.171] | Warning | 263889 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:55.607] | Warning | 245926 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:56.034] | Warning | 93119 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:56.451] | Warning | 232464 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:56.880] | Warning | 33436 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:57.300] | Warning | 230692 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:57.726] | Warning | 254216 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:58.152] | Warning | 219614 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:58.582] | Warning | 114845 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:59.006] | Warning | 47939 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:59.431] | Warning | 112029 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:50:59.856] | Warning | 136647 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:00.281] | Warning | 218912 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:00.705] | Warning | 187566 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:01.135] | Warning | 65068 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:01.566] | Warning | 241124 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:01.987] | Warning | 74204 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:02.412] | Warning | 136234 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:02.837] | Warning | 23343 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:03.271] | Warning | 341983 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:03.694] | Warning | 120363 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:04.120] | Warning | 280951 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:04.553] | Warning | 118354 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:04.972] | Warning | 17769 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:05.391] | Warning | 179797 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:05.810] | Warning | 220550 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:06.244] | Warning | 49264 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:06.660] | Warning | 301321 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:07.084] | Warning | 238042 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:07.519] | Warning | 133201 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:07.947] | Warning | 209869 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:08.381] | Warning | 243056 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:08.802] | Warning | 342197 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:09.228] | Warning | 101747 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:09.652] | Warning | 26690 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:10.074] | Warning | 370404 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:10.502] | Warning | 236306 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:10.929] | Warning | 62438 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:11.348] | Warning | 47797 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:11.772] | Warning | 219605 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:12.196] | Warning | 106037 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:12.612] | Warning | 178163 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:13.035] | Warning | 272817 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:13.470] | Warning | 268127 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:13.896] | Warning | 116481 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:14.316] | Warning | 95205 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:14.727] | Warning | 40266 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:15.156] | Warning | 24508 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:15.569] | Warning | 57295 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:15.986] | Warning | 19915 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:16.404] | Warning | 59302 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:16.819] | Warning | 100446 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:17.236] | Warning | 248400 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:17.652] | Warning | 238803 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:18.074] | Warning | 7l3BNtSE0xc entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:18.498] | Warning | 192827 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:18.922] | Warning | 74532 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:19.336] | Warning | 203806 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:19.762] | Warning | vi0FsBCqfRE entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:20.174] | Warning | 26110 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:20.591] | Warning | 159031 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:21.008] | Warning | 23289 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:21.427] | Warning | 306700 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:21.842] | Warning | 294226 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:22.261] | Warning | 10124 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:22.674] | Warning | 114945 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:23.085] | Warning | 219600 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:23.502] | Warning | 68828 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:23.918] | Warning | 238545 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:24.337] | Warning | 63956 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:24.755] | Warning | 213375 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:25.170] | Warning | 186643 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:25.597] | Warning | 100367 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:26.008] | Warning | 210240 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:26.432] | Warning | 74268 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:26.849] | Warning | 127490 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:27.261] | Warning | 22344 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:27.672] | Warning | 129728 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:28.083] | Warning | 188004 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:28.508] | Warning | 43444 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:28.919] | Warning | 210555 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:29.332] | Warning | 197232 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:29.747] | Warning | 114006 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:30.160] | Warning | 341763 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:30.585] | Warning | 206148 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:31.006] | Warning | 268258 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:31.418] | Warning | 10397 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:31.838] | Warning | 219460 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:32.254] | Warning | 16145 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:32.670] | Warning | 96106 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:33.081] | Warning | 35684 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:33.487] | Warning | 69307 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:33.901] | Warning | 229808 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:34.322] | Warning | 78398 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:34.750] | Warning | 52160 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:35.156] | Warning | 84924 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:35.571] | Warning | 7155 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:35.981] | Warning | 125698 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:36.397] | Warning | 88792 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:36.805] | Warning | 231412 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:37.242] | Warning | FrS-6P6FdCM entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:37.639] | Warning | 230422 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:38.057] | Warning | 94439 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:38.470] | Warning | 41032 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:38.880] | Warning | 121117 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:39.290] | Warning | 224648 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:39.701] | Warning | 24814 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:40.113] | Warning | 22335 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:40.525] | Warning | 79925 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:40.947] | Warning | 103114 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:41.360] | Warning | 217395 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:41.772] | Warning | 49903 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:42.194] | Warning | 65939 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:42.605] | Warning | 94525 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:43.006] | Warning | 49962 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:43.419] | Warning | HK0U0bIN-cw entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:43.820] | Warning | 233880 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:44.233] | Warning | 122581 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:44.643] | Warning | 188825 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:45.047] | Warning | 17874 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:45.454] | Warning | 101281 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:45.872] | Warning | 60428 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:46.278] | Warning | 93845 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:46.690] | Warning | 49073 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:47.092] | Warning | 252919 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:47.508] | Warning | 124190 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:47.927] | Warning | 5jGUBcStsZs entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:48.332] | Warning | 341382 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:48.734] | Warning | 118573 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:49.154] | Warning | 105507 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:49.564] | Warning | 34984 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:49.971] | Warning | 22884 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:50.375] | Warning | 123986 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:50.787] | Warning | 224498 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:51.200] | Warning | 301320 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:51.611] | Warning | 50307 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:52.025] | Warning | 22305 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:52.427] | Warning | 60351 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:52.840] | Warning | 263444 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:53.261] | Warning | 274073 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:53.671] | Warning | 112172 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:54.080] | Warning | 246216 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:54.486] | Warning | 242166 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:54.901] | Warning | 53233 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:55.309] | Warning | 222605 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:55.728] | Warning | 40247 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:56.145] | Warning | 21285 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:56.549] | Warning | 75393 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:56.959] | Warning | 370050 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:57.367] | Warning | 29920 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:57.774] | Warning | 58096 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:58.189] | Warning | 66623 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:58.593] | Warning | 22649 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:59.001] | Warning | 110794 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:59.410] | Warning | 91284 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:51:59.813] | Warning | 121584 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:00.215] | Warning | 93828 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:00.613] | Warning | 48219 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:01.020] | Warning | 80640 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:01.423] | Warning | 126505 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:01.834] | Warning | 231453 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:02.243] | Warning | 267354 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:02.660] | Warning | 57294 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:03.064] | Warning | 110983 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:03.466] | Warning | 368460 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:03.875] | Warning | 204378 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:04.288] | Warning | 223377 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:04.689] | Warning | Jv4CxSgWP2k entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:05.079] | Warning | 1nXhAjuICTA entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:05.488] | Warning | 22798 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:05.887] | Warning | 33272 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:06.281] | Warning | 119397 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:06.692] | Warning | 69870 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:07.085] | Warning | 206179 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:07.491] | Warning | 100961 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:07.898] | Warning | 224285 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:08.303] | Warning | 110543 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:08.707] | Warning | 24602 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:09.117] | Warning | 273510 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:09.528] | Warning | 29771 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:09.947] | Warning | 233431 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:10.338] | Warning | 52067 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:10.748] | Warning | 213207 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:11.149] | Warning | 135658 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:11.562] | Warning | jHB9kiH6Vas entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:11.949] | Warning | 99331 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:12.351] | Warning | 260199 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:12.763] | Warning | 60308 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:13.161] | Warning | 71459 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:13.559] | Warning | 223883 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:13.968] | Warning | 61247 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:14.373] | Warning | 115134 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:14.773] | Warning | 107456 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:15.171] | Warning | 71736 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:15.568] | Warning | 207867 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:15.967] | Warning | 50479 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:16.363] | Warning | 60983 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:16.770] | Warning | 21696 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:17.167] | Warning | 224292 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:17.575] | Warning | 57231 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:17.971] | Warning | 75441 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:18.368] | Warning | 233940 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:18.775] | Warning | 26113 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:19.174] | Warning | 105553 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:19.576] | Warning | 60328 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:19.971] | Warning | 91574 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:20.367] | Warning | 81371 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:20.766] | Warning | 102424 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:21.170] | Warning | 259857 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:21.564] | Warning | 220809 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:21.966] | Warning | 253709 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:22.372] | Warning | 91996 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:22.762] | Warning | 228561 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:23.158] | Warning | 98505 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:23.550] | Warning | 43428 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:23.951] | Warning | 207958 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:24.348] | Warning | 91292 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:24.746] | Warning | 63841 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:25.146] | Warning | 7156 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:25.551] | Warning | 34684 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:25.957] | Warning | 105963 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:26.361] | Warning | 27880 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:26.762] | Warning | 91002 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:27.155] | Warning | 19664 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:27.550] | Warning | 70299 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:27.955] | Warning | 79019 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:28.345] | Warning | 188062 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:28.747] | Warning | 227556 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:29.161] | Warning | 27881 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:29.550] | Warning | 49417 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:29.968] | Warning | 48724 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:30.373] | Warning | 110824 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:30.769] | Warning | 75892 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:31.165] | Warning | 121427 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:31.567] | Warning | 136416 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:31.973] | Warning | 246798 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:32.373] | Warning | 46503 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:32.791] | Warning | 218757 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:33.203] | Warning | 35934 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:33.602] | Warning | 247538 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:33.994] | Warning | 127908 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:34.391] | Warning | 172060 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:34.779] | Warning | 193894 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:35.178] | Warning | 274185 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:35.586] | Warning | 101513 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:35.989] | Warning | 26808 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:36.380] | Warning | 34640 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:36.783] | Warning | 87434 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:37.181] | Warning | 248024 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:37.581] | Warning | 43469 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:37.987] | Warning | 24157 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:38.390] | Warning | 193093 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:38.780] | Warning | 121759 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:39.176] | Warning | 234641 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:39.572] | Warning | 133888 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:39.971] | Warning | 68721 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:40.358] | Warning | 192978 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:40.756] | Warning | 73360 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:41.150] | Warning | 118639 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:41.541] | Warning | 28412 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:41.937] | Warning | 116219 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:42.336] | Warning | 22360 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:42.731] | Warning | 261052 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:43.131] | Warning | 224238 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:43.525] | Warning | 37462 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:43.920] | Warning | 19573 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:44.314] | Warning | 27888 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:44.710] | Warning | 19850 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:45.104] | Warning | 258802 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:45.507] | Warning | 40367 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:45.905] | Warning | 46592 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:46.302] | Warning | 179875 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:46.706] | Warning | 270993 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:47.106] | Warning | 219627 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:47.499] | Warning | 280584 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:47.888] | Warning | 91166 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:48.290] | Warning | 302220 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:48.693] | Warning | 33089 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:49.092] | Warning | 22785 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:49.486] | Warning | 27886 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:49.875] | Warning | 38154 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:50.260] | Warning | 105906 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:50.658] | Warning | 128600 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:51.050] | Warning | 125726 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:51.447] | Warning | 270439 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:51.834] | Warning | 223885 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:52.230] | Warning | 45860 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:52.616] | Warning | 132570 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:53.019] | Warning | 195575 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:53.411] | Warning | 50478 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:53.805] | Warning | 191941 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:54.198] | Warning | rLNY4-FWt5c entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:54.574] | Warning | 87163 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:54.973] | Warning | 203466 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:55.360] | Warning | 114419 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:55.749] | Warning | 83119 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:56.132] | Warning | 93843 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:56.522] | Warning | 57598 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:56.928] | Warning | 93116 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:57.308] | Warning | 22901 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:57.701] | Warning | 31544 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:58.087] | Warning | 28142 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:58.473] | Warning | 207964 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:58.864] | Warning | 26115 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:59.256] | Warning | 224622 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:52:59.652] | Warning | 79858 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:00.046] | Warning | 204085 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:00.440] | Warning | 36164 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:00.832] | Warning | 116461 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:01.229] | Warning | 241178 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:01.622] | Warning | 47056 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:02.011] | Warning | 342407 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:02.408] | Warning | 40970 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:02.801] | Warning | 38387 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:03.185] | Warning | 238597 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:03.582] | Warning | 193322 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:03.969] | Warning | 190726 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:04.367] | Warning | 176541 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:04.747] | Warning | 96337 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:05.138] | Warning | 206621 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:05.528] | Warning | 31392 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:05.918] | Warning | 118583 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:06.309] | Warning | 189856 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:06.705] | Warning | 21735 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:07.088] | Warning | 205268 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:07.490] | Warning | 110690 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:07.880] | Warning | 238624 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:08.277] | Warning | 273032 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:08.675] | Warning | 94532 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:09.052] | Warning | 211611 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:09.439] | Warning | OPuu8EknNqk entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:09.815] | Warning | 229637 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:10.207] | Warning | 110003 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:10.597] | Warning | 17811 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:10.990] | Warning | 86494 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:11.385] | Warning | 172048 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:11.769] | Warning | 96694 entry is not shared among all sequences, removing it ...
# [2024-10-31 15:53:12.155] | Success | Unify completed ...
# [2024-10-31 15:53:12.195] | Status  | Pre-alignment based on <CMU_MOSEI_Labels> computational sequence started ...
# [2024-10-31 15:53:22.411] | Status  | Pre-alignment done for <CMU_MOSEI_TimestampedWordVectors> ...
# [2024-10-31 15:53:26.385] | Status  | Pre-alignment done for <CMU_MOSEI_COVAREP> ...
# [2024-10-31 15:53:29.025] | Status  | Pre-alignment done for <CMU_MOSEI_VisualFacet42> ...
# [2024-10-31 15:53:29.093] | Status  | Alignment starting ...
# [2024-10-31 15:54:29.433] | Success | Alignment to <CMU_MOSEI_Labels> complete.
# [2024-10-31 15:54:29.433] | Status  | Replacing dataset content with aligned computational sequences
# [2024-10-31 15:54:37.325] | Success | Initialized empty <CMU_MOSEI_TimestampedWordVectors> computational sequence.
# [2024-10-31 15:54:37.325] | Status  | Checking the format of the data in <CMU_MOSEI_TimestampedWordVectors> computational sequence ...
# [2024-10-31 15:54:37.356] | Success | <CMU_MOSEI_TimestampedWordVectors> computational sequence data in correct format.
# [2024-10-31 15:54:37.356] | Status  | Checking the format of the metadata in <CMU_MOSEI_TimestampedWordVectors> computational sequence ...
# [2024-10-31 15:54:37.356] | Warning | <CMU_MOSEI_TimestampedWordVectors> computational sequence does not have all the required metadata ... continuing
# [2024-10-31 15:54:37.356] | Success | Initialized empty <CMU_MOSEI_VisualFacet42> computational sequence.
# [2024-10-31 15:54:37.356] | Status  | Checking the format of the data in <CMU_MOSEI_VisualFacet42> computational sequence ...
# [2024-10-31 15:54:37.385] | Success | <CMU_MOSEI_VisualFacet42> computational sequence data in correct format.
# [2024-10-31 15:54:37.385] | Status  | Checking the format of the metadata in <CMU_MOSEI_VisualFacet42> computational sequence ...
# [2024-10-31 15:54:37.385] | Warning | <CMU_MOSEI_VisualFacet42> computational sequence does not have all the required metadata ... continuing
# [2024-10-31 15:54:37.385] | Success | Initialized empty <CMU_MOSEI_COVAREP> computational sequence.
# [2024-10-31 15:54:37.385] | Status  | Checking the format of the data in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-10-31 15:54:37.417] | Success | <CMU_MOSEI_COVAREP> computational sequence data in correct format.
# [2024-10-31 15:54:37.417] | Status  | Checking the format of the metadata in <CMU_MOSEI_COVAREP> computational sequence ...
# [2024-10-31 15:54:37.417] | Warning | <CMU_MOSEI_COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-10-31 15:54:37.417] | Success | Initialized empty <CMU_MOSEI_Labels> computational sequence.
# [2024-10-31 15:54:37.417] | Status  | Checking the format of the data in <CMU_MOSEI_Labels> computational sequence ...
# [2024-10-31 15:54:37.449] | Success | <CMU_MOSEI_Labels> computational sequence data in correct format.
# [2024-10-31 15:54:37.449] | Status  | Checking the format of the metadata in <CMU_MOSEI_Labels> computational sequence ...
# [2024-10-31 15:54:37.449] | Warning | <CMU_MOSEI_Labels> computational sequence does not have all the required metadata ... continuing

# %%
# Print some keys to see the segmentation structure
print(list(dataset[label_field].keys())[:10])

# Pick a specific segmented key to explore further
some_segmented_key = list(dataset[label_field].keys())[0]

# Check the aligned features and intervals for this segment
print("Label intervals:", dataset[label_field][some_segmented_key]['intervals'].shape)
print("Label features:", dataset[label_field][some_segmented_key]['features'].shape)

print("Text features:", dataset[text_field][some_segmented_key]['features'].shape)
print("Visual features:", dataset[visual_field][some_segmented_key]['features'].shape)
print("Acoustic features:", dataset[acoustic_field][some_segmented_key]['features'].shape)
# Out:
# ['--qXJuDtHPw[0]', '-3g5yACwYnA[0]', '-3g5yACwYnA[1]', '-3g5yACwYnA[2]', '-3g5yACwYnA[3]', '-3g5yACwYnA[4]', '-3g5yACwYnA[5]', '-3nNcZdcdvU[0]', '-3nNcZdcdvU[1]', '-3nNcZdcdvU[2]']
# Label intervals: (1, 2)
# Label features: (1, 7)
# Text features: (22, 300)
# Visual features: (22, 35)
# Acoustic features: (22, 74)

# %%
# check out what the keys look like now
print(list(dataset[text_field].keys())[55])
# Out:
# -HwX2H8Z4hY[4]

# %% [markdown]
# ## Train Test Split

# %%
# obtain the train/dev/test splits - these splits are based on video IDs
train_split = DATASET.standard_folds.standard_train_fold
dev_split = DATASET.standard_folds.standard_valid_fold
test_split = DATASET.standard_folds.standard_test_fold

# inspect the splits: they only contain video IDs
print(test_split)
# Out:
# ['7l3BNtSE0xc', 'dZFV0lyedX4', '286943', '126872', 'qgC8_emxSIU', 'kld9r0iFkWM', 'rC29Qub0U7A', '4YfyP0uIqw0', 'FMenDv3y8jc', '4wLP4elp1uM', 'KYQTwFVBzME', '27v7Blr0vjw', 'DnBHq5I52LM', 'HR18U0yAlTc', 'x266rUJQC_8', 'd1CDP6sMuLA', 'xSCvspXYU9k', '4EDblUpJieU', '4o4ilPK9rl8', '53609', 'SZ7HK5ns6mE', '243981', 'ySblgk7T7eQ', 'MYEyQUpMe3k', 'EujJ0SwiCRE', '3HyAaqre_Fk', 'iQDB_OkAQWs', 'gE7kUqMqQ9g', 'eFV7iFPYZB4', 'IRSxo_XXArg', '3hOlJf_JQDs', 'BRSyH6yfDLk', '1jogeKX0wGw', '3At-BKm9eYk', 'NVLPURuAVLU', 'pZye4zFzk3o', 'l1jW3OMXUzs', 'XKyumlBmix8', 'eKQKEi2-0Ws', 'WgI8IbJtXHw', 'tnWmVXZ87h0', 'YCEllKyaCrc', 'W1CWpktWtTs', '8wQhzezNcUY', '0bxhZ-LIfZY', 'lrjm6F3JJgg', 'Vdf1McvE9ao', 'eQc5uI7FKCU', '2QXHdu2zlQY', 'YCI-ZzclIPQ', '2Ky9DBSl49w', 'SKTyBOhDX6U', 'b86B3hP8ARM', '23656', 'kpS4BXif_Sw', 'dR68gbeOWOc', 'tC2KicUHB9Q', 'absh1hsZeF0', 'c5zxqITn3ZM', 'uogwnZGb-iE', '46495', 'Sq6DIhFxPqQ', 'PexNiFbPTYM', 'z441aDJvAcU', 'OORklkFql3k', 'WbtsuXkaGeg', 'grsV1YN1z5s', 'Gc_zIjqqUys', '424SXFTCFsA', 'P17tYiqMGRU', 'UweZVaFqruU', 'mzAu5gxjE-w', '8TDAP0KNIIw', 'u9ZV8jb_-U0', 'iPPp6MCythU', 'lwL4hjhkid4', '102389', 'frCWtiam4tE', 'pSxte-ms0t8', 'c9hE1ghElrM', 'WfNiQBXmPw8', '_q7DM8WkzAQ', '257534', 'fU5AYkq0m9k', 'q17gSr9kNww', 'AgH84SNRx5s', '206585', 'yzCHa2qchpg', 'GmpDbIstUdc', 'eREud0qYR3s', 'NoOt0oU843M', 'svsbGQn389o', 'ZsLrKF7_Oos', 'Kyz32PTyP4I', '7idU7rR77Ss', '8lfS97s2AKc', 'X2Hs89fZ2-c', '5vwXp27bCLw', 'tZDNinnrGf8', 'KB5hSnV1emg', 'TxRtSItpGMo', 'eJfT7-dDqzA', 'x2n19Cn96aw', 'XDVit9ASVUg', '6brtMLkjjYk', '-rxZxtG0xmY', 'JATMzuV6sUE', 'LueQT0vY1zI', '267466', 'm-7yRWZLwLY', 'OWWHjP3pX9o', 'QnYlpSeVOYo', 'V7OFSHYcQD0', 'GK-Pprzh0t0', 'yLo-Jl8nBXU', '200941', '61531', 'ezuWKsxPRSM', 'ehZrOdw6PhA', '-6rXp3zJ3kc', 'Z4iYSMMMycQ', 'MtIklGnIMGo', '116213', '3XShFTBsp_Q', 'YQZPnHZRp1w', 'fsd1qPLA3kY', '208322', 'uVM4JWjfGgQ', 'QWll4lS1qqI', 'Vlas-mPydcg', 'teQqaAmqqx0', 'AQ4Pktv4-Gc', 'yCpHmPSshKY', 'pDRdCSIyjkA', 'sIusv36VoBY', '8jY_RhOS89o', 'GKsjv42t284', 'HA2AiTz-qxc', 'GXIfrEUJ5d4', '0Fqav67TDEw', '10219', 'wHeZHLv9wGI', 'qDfSYz0PX9g', '180971', 'qBanrqkzobg', 'NgENhhXf0LE', 'SH0OYx3fR7s', 'lc5bSoGlQwY', 'XrNaL-MTjXg', '8i7u3fl-hP8', 'N-NnCI6U52c', 'r46amqjpWgg', 'QVyxySAaehE', 'JKueLneBoik', '110565', 'TqQgIxR7thU', '267694', 'ZKErPftd--w', 'GMa0cIAltnw', 'MSHBEntSDjU', 'AB1PbMaW03s', 'oBS-IW-BO00', '5fKPJPFqPho', '8NPaDkOiXw4', '104741', '2ItiGjefTRA', 'LFOwCSiGOvw', 'YLK58srjhNI', '233939', '5xa0Ac2krGs', 'CbRexsp1HKw', '112425', 'bCBMKwafZKY', '_0efYOjQYRc', 'O2ShYliS3CU', 'Oa2xVjzAMFc', 'bnzVR2ETQQ8', 'yBtMwyQFXwA', 'TtAyUQtmTLk', 'yXE_XZUb8qE', '3wHE78v9zr4', 'cml9rShionM', 'rePYTlT5_AY', '9TAGpMywQyE', 'ryE9VBiR3p8', '238063', 'NlrCjfHELLE', 'oGFDE-6nd7Q', 'bWmrrWQOVCM', '29751', '11UtTaDYgII', 'jZe-2w7pkd8', '275267', 'tymso_pAxhk', 'PcqKFt1p3UQ', 'sfaWfZ2-4c0', 'kLAXmTx2xOA', '3OYY5Tsz_2k', 'wk5lFk5kFjY', 'hE-sA5umuCk', '3IUVpwx23cY', '92291', '102213', '236442', 'nbru7qLot04', 'zhNksSReaQk', '8VhVf0TbjDA', '35694', '20LfN8ENbhM', '257277', 'VsXGwSZazwA', 'EyoMU2yoJPY', 'E1r0FrFyNTw', 'CO2YoTZbUr0', 'wC_1M7KIv9s', '24196', '194299', 'R9xTBw3MCWI', 'cY8DcaHXNNs', 'SwT0gh0V8fI', 'UiurP5k-f1A', 'N0d2JL7JC1s', '208592', 'GAVpYuhMZAw', 'pvIQWWiT4-0', 'namehdJxRIM', 'tNd3--lvSXE', 'NaWmaHwjElo', 'mfpR4CN9LZo', 'U6IqFbpM-VM', 'XLjpZUsFEXo', 'YUNxD04EvfE', 'hI7ObFqn9Bg', 'CO6n-skQJss', 'RsE2gYghZ2s', '2ze94yo2aPo', '254427', 'MHyW857u_X8', 'Xa086gxLJ3Y', 'Uu_XyXyKHAk', 'TsfyeZ8hgwE', 'vI5JH0daNsM', 'mmg_eTDHjkk', 'lD4xtQ6NpDY', 'XWIp0zH3qDM', '259470', '0eTibWQdO5M', 'fcxbB7ybUfs', '5pxFqJ5hKMU', '245582', 'WQFRctNL8AA', '2m58ShI1QSI', 'cn0WZ8-0Z1Y', '25640', 'huzEsVEJPaY', 'UTErYLpdAY0', 'F2hc2FLOdhI', 'vGxqVh_kJdo', 'F_YaG_pvZrA', 'UNLD7eYPzfQ', '0K7dCp80n9c', 'xBE9YWYGjtk', 'nTZSH0EwpnY', 'mZ_8em_-CGc', 'fdc7iyzKvFQ', '221137', 'QBc7X5jj8oA', 'pnpFPX34Agk', '63951', 'veA6ECsGFxI', 'XbkYA-iXUwA', '1LkYxsqRPZM', 'qAip3lZRj-g', 'gR3igiwaeyc', 'pIaEcqnzI-s', 'oHff2W51wZ8', 'XlTYSOaZ_vM', '3WZ6R9B0PcU', 'IOpWjKAHG8Q', '53766', '19074 ...

# %%
# we can see they are in the format of 'video_id[segment_no]', but the splits was specified with video_id only
# we need to use regex or something to match the video IDs...
import torch
import torch.nn as nn

from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm_notebook
from collections import defaultdict

# a sentinel epsilon for safe division, without it we will replace illegal values with a constant
EPS = 0

# construct a word2id mapping that automatically takes increment when new words are encountered
word2id = defaultdict(lambda: len(word2id))
UNK = word2id['<unk>']
PAD = word2id['<pad>']

# place holders for the final train/dev/test dataset
train = []
dev = []
test = []

# define a regular expression to extract the video ID out of the keys
pattern = re.compile('(.*)\[.*\]')
num_drop = 0 # a counter to count how many data points went into some processing issues

for segment in dataset[label_field].keys():
    
    # get the video ID and the features out of the aligned dataset
    vid = re.search(pattern, segment).group(1)
    label = dataset[label_field][segment]['features']
    _words = dataset[text_field][segment]['features']
    _visual = dataset[visual_field][segment]['features']
    _acoustic = dataset[acoustic_field][segment]['features']

    # if the sequences are not same length after alignment, there must be some problem with some modalities
    # we should drop it or inspect the data again
    if not _words.shape[0] == _visual.shape[0] == _acoustic.shape[0]:
        print(f"Encountered datapoint {vid} with text shape {_words.shape}, visual shape {_visual.shape}, acoustic shape {_acoustic.shape}")
        num_drop += 1
        continue

    # remove nan values
    label = np.nan_to_num(label)
    _visual = np.nan_to_num(_visual)
    _acoustic = np.nan_to_num(_acoustic)

    # remove speech pause tokens - this is in general helpful
    # we should remove speech pauses and corresponding visual/acoustic features together
    # otherwise modalities would no longer be aligned
    words = []
    visual = []
    acoustic = []
    for i, word in enumerate(_words):
        if word[0] != b'sp':
            words.append(word2id[word[0].decode('utf-8')]) # SDK stores strings as bytes, decode into strings here
            visual.append(_visual[i, :])
            acoustic.append(_acoustic[i, :])

    words = np.asarray(words)
    visual = np.asarray(visual)
    acoustic = np.asarray(acoustic)

    # z-normalization per instance and remove nan/infs
    visual = np.nan_to_num((visual - visual.mean(0, keepdims=True)) / (EPS + np.std(visual, axis=0, keepdims=True)))
    acoustic = np.nan_to_num((acoustic - acoustic.mean(0, keepdims=True)) / (EPS + np.std(acoustic, axis=0, keepdims=True)))

    if vid in train_split:
        train.append(((words, visual, acoustic), label, segment))
    elif vid in dev_split:
        dev.append(((words, visual, acoustic), label, segment))
    elif vid in test_split:
        test.append(((words, visual, acoustic), label, segment))
    else:
        print(f"Found video that doesn't belong to any splits: {vid}")

print(f"Total number of {num_drop} datapoints have been dropped.")

# turn off the word2id - define a named function here to allow for pickling
def return_unk():
    return UNK
word2id.default_factory = return_unk
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 34
#      31 vid = re.search(pattern, segment).group(1)
#      33 # Ensure that the required modalities are present
# ---> 34 if segment not in dataset[visual_field] or segment not in dataset[acoustic_field] or segment not in dataset[text_field]:
#      35     print(f"Skipping segment {segment} due to missing modality data.")
#      36     num_drop += 1
#
# File c:\Users\Saahil\AppData\Local\Programs\Python\Python311\Lib\site-packages\mmsdk\mmdatasdk\computational_sequence\computational_sequence.py:42, in computational_sequence.__getitem__(self, key)
#      41 def __getitem__(self, key):
# ---> 42 	return self.data[key]
#
# KeyError: 0

# %%
print("Data types in _words:", [type(w[0]) for w in _words])
# Out:
# Data types in _words: [<class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>]
